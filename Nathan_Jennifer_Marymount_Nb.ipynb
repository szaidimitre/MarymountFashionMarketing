# %%
# %ls
# Out:
# AA320 Lesson Planner_Marymount 101119.docx
# Nathan_Jennifer_Marymount_Nb.ipynb
# shoes_v2.xlsx

# %% [markdown]
# ## Importing python libraries which help us speed our coding up.
# #The packages we're importing are below.
# import pandas as pd
# import random
# from pandas.plotting import scatter_matrix
# import scipy as sc
# import numpy as np
# import matplotlib
# import matplotlib.pyplot as plt #Can abbreviate specific parts of the packages so it's easier to type
# import sklearn as sk
# import seaborn as sns
# from sklearn.linear_model import LogisticRegression
# from sklearn import metrics
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.model_selection import train_test_split
# from sklearn import datasets, linear_model

# %%
#Importing python libraries which help us speed our coding up.
#The packages we're importing are below.
import pandas as pd
import random
from pandas.plotting import scatter_matrix
import scipy as sc
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import re
import matplotlib.pyplot as plt #Can abbreviate specific parts of the packages so it's easier to type
import sklearn as sk
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

# %%
#We will now read the data in and store it in a dataframe called dataset
dataset = pd.read_excel('shoes_v2.xlsx', header = 0)

# %% [markdown]
# #### Understanding our data
# Let's run some code and see how many rows and columns we have. Below - you will see the result as (Number of Rows, Number of Columns)

# %%
dataset.shape
# Out:
# (373, 12)

# %% [markdown]
# #### What do the first 10 rows of our data look like?

# %%
dataset.head(10)
# Out:
#   product_asin                                       product_name  \
# 0   B07D3G9ZNG                          Brooks Women's Levitate 2
# 1   B07VKQWZR4                    Nike Women's Viale Running Shoe
# 2   B07X92DWVM         adidas Originals Women's Superstar Sneaker
# 3   B077GB5R7R     ECCO Women?s, Biom Fjuel Blaze Lace up Sneaker
# 4   B01KLTBMLA           adidas Women's W Tech Response Golf Shoe
# 5   B07GSVDPST                    CLARKS Women's Leisa Sadie Clog
# 6   B072F85JCB  Nike Women's Flex Experience RN 7 Black/Black ...
# 7   B00FLO35HU              Clarks Women's Ashland Bubble Slip-On
# 8   B07SD1MSBB  SKOEX Women Rhinestone Ballroom Dance Shoes La...
# 9   B07V69KHHZ    Under Armour Women's Charged Rogue Running Shoe
#
#                                   product_sale_price  \
# 0  $99.80 - $249.95Lower price available on selec...
# 1                                   $33.39 - $133.00
# 2                                   $38.55 - $169.76
# 3  $69.68 - $159.06Lower price available on selec...
# 4  $29.99 - $140.34Lower price available on selec...
# 5  $36.14 - $109.99Lower price available on selec...
# 6                                             $59.94
# 7  $28.22 - $89.97Lower price available on select...
# 8                                    $19.99 - $39.99
# 9  $39.97 - $80.00Lower price available on select...
#
#                                     product_category product_brand  \
# 0  Clothing, Shoes & Jewelry,Women,Shoes,Athletic...           NaN
# 1  Clothing, Shoes & Jewelry,Women,Shoes,Athletic...           NaN
# 2  Clothing, Shoes & Jewelry,Women,Shoes,Fashion ...           NaN
# 3  Clothing, Shoes & Jewelry,Women,Shoes,Athletic...           NaN
# 4  Clothing, Shoes & Jewelry,Women,Shoes,Athletic...        adidas
# 5  Clothing, Shoes & Jewelry,Women,Shoes,Mules & ...           NaN
# 6  Clothing, Shoes & Jewelry,Women,Shoes,Athletic...           NaN
# 7  Clothing, Shoes & Jewelry,Women,Shoes,Loafers ...           NaN
# 8  Clothing, Shoes & Jewelry,Women,Shoes,Athletic...         SKOEX
# 9  Clothing, Shoes & Jewelry,Women,Shoes,Athletic...           NaN
#
#    product_rating num_ratings  \
# 0             4.4         163
# 1             4.0         109
# 2             4.5         392
# 3             4.1          26
# 4             4.4         222
# 5             4.4         481
# 6             4.0           1
# 7             4.5       1,309
# 8             4.4          14
# 9             4.6          40
#
#                                        product_sizes  \
# 0  Select,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,...
# 1  Select,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,1...
# 2  Select,1,1.5,2,2.5,3,5,5.5,6,6.5,7,7.5,8,8.5,9...
# 3  Select,4-4.5,5-5.5,7-7.5,8-8.5,9-9.5,10-10.5,1...
# 4  Select,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11,9.5...
# 5  Select,5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7....
# 6                                                NaN
# 7  Select,5,5.5,6,6 Wide,6 X-Wide,6.5,6.5 Wide,6....
# 8         Select,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5
# 9  Select,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,1...
#
#                                       product_colors  \
# 0  Coral/Blue/Black,Aster/Purple/Blue,Pink/Black/...
# 1  Light Cream/Pure Platinum - White,Wolf Grey/Wh...
# 2  Scarlet/Scarlet/White,White/Ash Green/Silver M...
# 3  Black/Black,Concrete/White,Dark Shadow/Dark Sh...
# 4  Black/Silver Metallic/Grey Five,Clear/Grey,Whi...
# 5  Black Leather,Dark Tan Leather,Navy Leather,Da...
# 6                                                NaN
# 7  Black,Brown Multi,Tan Leather,Black Interest,M...
# 8  Black-2.5inch Heel,Black-3inch Heel,Tan-3inch ...
# 9  Black (002)/White,Blue Heights (400)/Breathtak...
#
#                                     product_features  \
# 0  Fabric,Imported,Rubber sole,The Brooks® Levita...
# 1  100% Leather and Synthetic,Imported,Rubber sol...
# 2  100% full grain leather,Imported,N/A,Rubber so...
# 3  Synthetic,Imported,Rubber sole,The flexible Bi...
# 4  Microfiber Leather/Climastorm,Imported,Synthet...
# 5  100% Leather,Imported,Rubber sole,Heel measure...
# 6  Fabric-And-Synthetic,Rubber sole,Platform meas...
# 7  100% Leather,Imported,Synthetic sole,Heel meas...
# 8  Satin upper,Soft suede sole,Elegant Exterior: ...
# 9  100% Textile,Imported,Synthetic sole,Shaft mea...
#
#                                        product_terms  product_qa
# 0  toe box,second pair,love these shoes,true to s...          22
# 1                                                NaN          13
# 2                                                NaN          81
# 3                                                NaN           5
# 4                                                NaN          21
# 5                                                NaN          13
# 6                                                NaN           0
# 7  clark shoes,well made,toe box,right out of the...          70
# 8                                                NaN           0
# 9                                                NaN          10

# %%
# checking the percentage of missing values in each variable
x = dataset.isnull().sum()/len(dataset)*100
x
# Out:
# product_asin           0.000000
# product_name           0.000000
# product_sale_price     0.000000
# product_category       0.000000
# product_brand         63.806971
# product_rating         0.000000
# num_ratings            0.000000
# product_sizes          1.340483
# product_colors         4.021448
# product_features       0.536193
# product_terms         65.415550
# product_qa             0.000000
# dtype: float64

# %%
dataset.product_category = dataset.product_category.replace({'Clothing, Shoes & Jewelry,':''}, regex=True)

# %%
dataset['num_colors'] = ''

# %%
dataset["num_colors"] = dataset.product_colors.str.count(',') + 1

# %%
dataset['num_colors'].value_counts()
# Out:
# 2.0      56
# 4.0      55
# 3.0      35
# 5.0      27
# 6.0      22
# 1.0      20
# 16.0     17
# 10.0     14
# 7.0      14
# 9.0      13
# 8.0      12
# 15.0      9
# 12.0      9
# 11.0      7
# 13.0      6
# 14.0      4
# 18.0      4
# 24.0      3
# 34.0      3
# 36.0      3
# 22.0      3
# 85.0      2
# 19.0      2
# 33.0      2
# 31.0      2
# 27.0      2
# 17.0      2
# 26.0      1
# 20.0      1
# 44.0      1
# 39.0      1
# 23.0      1
# 21.0      1
# 49.0      1
# 264.0     1
# 37.0      1
# 28.0      1
# Name: num_colors, dtype: int64

# %%
dataset.head()
# Out:
#   product_asin                                    product_name  \
# 0   B07D3G9ZNG                       Brooks Women's Levitate 2
# 1   B07VKQWZR4                 Nike Women's Viale Running Shoe
# 2   B07X92DWVM      adidas Originals Women's Superstar Sneaker
# 3   B077GB5R7R  ECCO Women?s, Biom Fjuel Blaze Lace up Sneaker
# 4   B01KLTBMLA        adidas Women's W Tech Response Golf Shoe
#
#                                   product_sale_price  \
# 0  $99.80 - $249.95Lower price available on selec...
# 1                                   $33.39 - $133.00
# 2                                   $38.55 - $169.76
# 3  $69.68 - $159.06Lower price available on selec...
# 4  $29.99 - $140.34Lower price available on selec...
#
#                             product_category product_brand  product_rating  \
# 0  Women,Shoes,Athletic,Running,Road Running           NaN             4.4
# 1  Women,Shoes,Athletic,Running,Road Running           NaN             4.0
# 2               Women,Shoes,Fashion Sneakers           NaN             4.5
# 3               Women,Shoes,Athletic,Walking           NaN             4.1
# 4                  Women,Shoes,Athletic,Golf        adidas             4.4
#
#   num_ratings                                      product_sizes  \
# 0         163  Select,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,...
# 1         109  Select,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,1...
# 2         392  Select,1,1.5,2,2.5,3,5,5.5,6,6.5,7,7.5,8,8.5,9...
# 3          26  Select,4-4.5,5-5.5,7-7.5,8-8.5,9-9.5,10-10.5,1...
# 4         222  Select,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11,9.5...
#
#                                       product_colors  \
# 0  Coral/Blue/Black,Aster/Purple/Blue,Pink/Black/...
# 1  Light Cream/Pure Platinum - White,Wolf Grey/Wh...
# 2  Scarlet/Scarlet/White,White/Ash Green/Silver M...
# 3  Black/Black,Concrete/White,Dark Shadow/Dark Sh...
# 4  Black/Silver Metallic/Grey Five,Clear/Grey,Whi...
#
#                                     product_features  \
# 0  Fabric,Imported,Rubber sole,The Brooks® Levita...
# 1  100% Leather and Synthetic,Imported,Rubber sol...
# 2  100% full grain leather,Imported,N/A,Rubber so...
# 3  Synthetic,Imported,Rubber sole,The flexible Bi...
# 4  Microfiber Leather/Climastorm,Imported,Synthet...
#
#                                        product_terms  product_qa  num_colors
# 0  toe box,second pair,love these shoes,true to s...          22        11.0
# 1                                                NaN          13        13.0
# 2                                                NaN          81        15.0
# 3                                                NaN           5         3.0
# 4                                                NaN          21         7.0

# %%
dataset["show_low_price"] = ''

# %%
dataset["show_low_price"] = dataset['product_sale_price'].str.split(' ').str[0]

# %%
dataset["show_low_price"] = [x[1:] for x in dataset["show_low_price"]]

# %%
dataset["show_low_price"] = pd.to_numeric(dataset["show_low_price"])

# %%
dataset["show_low_price"].value_counts()
# Out:
# 23.83     9
# 21.99     9
# 29.99     8
# 29.95     8
# 19.99     7
# 39.95     7
# 7.99      6
# 24.99     6
# 17.99     6
# 34.99     5
# 30.00     4
# 32.99     4
# 39.99     4
# 20.00     3
# 37.50     3
# 31.99     3
# 26.99     3
# 25.00     3
# 30.99     3
# 34.95     3
# 14.00     2
# 27.97     2
# 28.99     2
# 19.23     2
# 35.73     2
# 5.99      2
# 47.26     2
# 33.99     2
# 19.01     2
# 27.99     2
#          ..
# 19.79     1
# 76.16     1
# 40.76     1
# 19.40     1
# 29.61     1
# 37.30     1
# 43.41     1
# 22.15     1
# 22.59     1
# 23.90     1
# 41.95     1
# 38.95     1
# 38.55     1
# 43.99     1
# 29.89     1
# 23.48     1
# 27.30     1
# 41.31     1
# 21.03     1
# 39.97     1
# 34.98     1
# 16.02     1
# 16.60     1
# 72.98     1
# 63.18     1
# 34.82     1
# 15.57     1
# 29.16     1
# 89.99     1
# 112.16    1
# Name: show_low_price, Length: 265, dtype: int64

# %%
dataset["show_high_price"] = ''

# %%
dataset["show_high_price"] = dataset['product_sale_price'].str.split(' ').str[2]

# %%
dataset["show_high_price"] = dataset['show_high_price'].fillna("0.00")

# %%
dataset["show_high_price"] = dataset["show_high_price"].apply(lambda x: x.strip('$'))

# %%
dataset["show_high_price"].replace(r'[a-zA-Z%]', '', regex=True, inplace=True)

# %%
dataset["show_high_price"] = pd.to_numeric(dataset["show_high_price"])

# %%
dataset["show_high_price"].value_counts()
# Out:
# 59.99     10
# 24.99      9
# 90.00      7
# 39.99      7
# 0.00       6
# 10.99      6
# 32.99      6
# 85.00      5
# 109.00     5
# 70.00      5
# 65.00      5
# 109.99     4
# 110.93     4
# 99.95      4
# 140.34     4
# 125.63     4
# 79.95      4
# 120.00     3
# 81.51      3
# 89.97      3
# 80.00      3
# 130.91     3
# 118.29     3
# 100.00     3
# 84.00      3
# 89.95      3
# 104.44     3
# 59.95      3
# 69.99      3
# 64.95      3
#           ..
# 61.89      1
# 396.20     1
# 159.06     1
# 162.40     1
# 75.41      1
# 146.24     1
# 273.24     1
# 116.62     1
# 23.88      1
# 54.99      1
# 132.99     1
# 44.95      1
# 9.99       1
# 233.87     1
# 220.09     1
# 99.99      1
# 67.99      1
# 199.98     1
# 108.87     1
# 131.51     1
# 259.99     1
# 110.87     1
# 145.99     1
# 125.65     1
# 87.99      1
# 21.99      1
# 258.14     1
# 116.97     1
# 169.95     1
# 102.28     1
# Name: show_high_price, Length: 230, dtype: int64

# %%
dataset["shoe_gender"] = dataset.product_category

# %%
dataset['shoe_gender'] = dataset['shoe_gender'].str.split(',').str[0]

# %%
dataset['shoe_gender'].value_counts()
# Out:
# Women                366
# Men                    5
# Girls                  1
# Sports & Outdoors      1
# Name: shoe_gender, dtype: int64

# %%
dataset["shoe_category_fixed"] = ""

# %%
dataset["shoe_category_fixed"] = dataset['product_category'].str.split(',').str[1:]

# %%
dataset['shoe_category_fixed'].value_counts()
# Out:
# [Shoes, Fashion Sneakers]                                        63
# [Shoes]                                                          56
# [Shoes, Athletic, Ballet & Dance]                                43
# [Shoes, Athletic, Running, Road Running]                         35
# [Shoes, Flats]                                                   32
# [Shoes, Pumps]                                                   31
# [Shoes, Loafers & Slip-Ons]                                      30
# [Shoes, Athletic, Walking]                                       28
# [Shoes, Mules & Clogs]                                            7
# [Shoes, Oxfords]                                                  5
# [Shoes, Athletic, Fitness & Cross-Training]                       5
# [Shoes, Athletic, Golf]                                           5
# [Uniforms,  Work & Safety, Shoes, Health Care & Food Service]     4
# [Shoes, Sandals, Platforms & Wedges]                              3
# [Shoes, Slippers]                                                 3
# [Shoes, Sandals, Heeled Sandals]                                  2
# [Shoes, Boots, Ankle & Bootie]                                    2
# [Uniforms,  Work & Safety, Shoes, Industrial & Construction]      2
# [Shoes, Athletic, Running]                                        2
# [Shoes, Athletic, Tennis & Racquet Sports]                        1
# [Shoes, Boots]                                                    1
# [Uniforms,  Work & Safety, Shoes, Fire & Safety]                  1
# [Shoes, Athletic, Team Sports, Soccer]                            1
# [Shoes, Outdoor, Rain Footwear]                                   1
# [Shoes, Outdoor, Hiking & Trekking, Hiking Shoes]                 1
# [Contemporary & Designer, Shoes]                                  1
# [Shoes, Sandals, Slides]                                          1
# [Shoes, Athletic, Running, Trail Running]                         1
# [Shoes, Athletic, Skateboarding]                                  1
# [Shoes, Athletic, Team Sports, Volleyball]                        1
# [Shoes, Sandals, Flip-Flops]                                      1
# [Fan Shop, Footwear, Sneakers]                                    1
# [Shoes, Sandals]                                                  1
# [Shoes, Athletic, Water Shoes]                                    1
# Name: shoe_category_fixed, dtype: int64

# %%
dataset["shoe_category_final"] = ""

# %%
dataset["shoe_category_final"] = dataset['product_category'].str.split(',').str[-1]

# %%
dataset['shoe_category_final'].value_counts()
# Out:
# Fashion Sneakers              63
# Shoes                         57
# Ballet & Dance                43
# Road Running                  35
# Flats                         32
# Pumps                         31
# Loafers & Slip-Ons            30
# Walking                       28
# Mules & Clogs                  7
# Oxfords                        5
# Fitness & Cross-Training       5
# Golf                           5
# Health Care & Food Service     4
# Slippers                       3
# Platforms & Wedges             3
# Heeled Sandals                 2
# Industrial & Construction      2
# Running                        2
# Ankle & Bootie                 2
# Skateboarding                  1
# Slides                         1
# Sneakers                       1
# Flip-Flops                     1
# Sandals                        1
# Water Shoes                    1
# Soccer                         1
# Volleyball                     1
# Boots                          1
# Hiking Shoes                   1
# Rain Footwear                  1
# Tennis & Racquet Sports        1
# Trail Running                  1
# Fire & Safety                  1
# Name: shoe_category_final, dtype: int64

# %%
dataset.head()
# Out:
#   product_asin                                    product_name  \
# 0   B07D3G9ZNG                       Brooks Women's Levitate 2
# 1   B07VKQWZR4                 Nike Women's Viale Running Shoe
# 2   B07X92DWVM      adidas Originals Women's Superstar Sneaker
# 3   B077GB5R7R  ECCO Women?s, Biom Fjuel Blaze Lace up Sneaker
# 4   B01KLTBMLA        adidas Women's W Tech Response Golf Shoe
#
#                                   product_sale_price  \
# 0  $99.80 - $249.95Lower price available on selec...
# 1                                   $33.39 - $133.00
# 2                                   $38.55 - $169.76
# 3  $69.68 - $159.06Lower price available on selec...
# 4  $29.99 - $140.34Lower price available on selec...
#
#                             product_category product_brand  product_rating  \
# 0  Women,Shoes,Athletic,Running,Road Running           NaN             4.4
# 1  Women,Shoes,Athletic,Running,Road Running           NaN             4.0
# 2               Women,Shoes,Fashion Sneakers           NaN             4.5
# 3               Women,Shoes,Athletic,Walking           NaN             4.1
# 4                  Women,Shoes,Athletic,Golf        adidas             4.4
#
#   num_ratings                                      product_sizes  \
# 0         163  Select,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,...
# 1         109  Select,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,1...
# 2         392  Select,1,1.5,2,2.5,3,5,5.5,6,6.5,7,7.5,8,8.5,9...
# 3          26  Select,4-4.5,5-5.5,7-7.5,8-8.5,9-9.5,10-10.5,1...
# 4         222  Select,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11,9.5...
#
#                                       product_colors  \
# 0  Coral/Blue/Black,Aster/Purple/Blue,Pink/Black/...
# 1  Light Cream/Pure Platinum - White,Wolf Grey/Wh...
# 2  Scarlet/Scarlet/White,White/Ash Green/Silver M...
# 3  Black/Black,Concrete/White,Dark Shadow/Dark Sh...
# 4  Black/Silver Metallic/Grey Five,Clear/Grey,Whi...
#
#                                     product_features  \
# 0  Fabric,Imported,Rubber sole,The Brooks® Levita...
# 1  100% Leather and Synthetic,Imported,Rubber sol...
# 2  100% full grain leather,Imported,N/A,Rubber so...
# 3  Synthetic,Imported,Rubber sole,The flexible Bi...
# 4  Microfiber Leather/Climastorm,Imported,Synthet...
#
#                                        product_terms  product_qa  num_colors  \
# 0  toe box,second pair,love these shoes,true to s...          22        11.0
# 1                                                NaN          13        13.0
# 2                                                NaN          81        15.0
# 3                                                NaN           5         3.0
# 4                                                NaN          21         7.0
#
#    show_low_price  show_high_price shoe_gender  \
# 0           99.80           249.95       Women
# 1           33.39           133.00       Women
# 2           38.55           169.76       Women
# 3           69.68           159.06       Women
# 4           29.99           140.34       Women
#
#                         shoe_category_fixed shoe_category_final
# 0  [Shoes, Athletic, Running, Road Running]        Road Running
# 1  [Shoes, Athletic, Running, Road Running]        Road Running
# 2                 [Shoes, Fashion Sneakers]    Fashion Sneakers
# 3                [Shoes, Athletic, Walking]             Walking
# 4                   [Shoes, Athletic, Golf]                Golf

# %%
dataset.product_sizes = dataset.product_sizes.replace({'Select,':''}, regex=True)

# %%
dataset.product_sizes
# Out:
# 0         5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 1       5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 2      1,1.5,2,2.5,3,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10...
# 3      4-4.5,5-5.5,7-7.5,8-8.5,9-9.5,10-10.5,11-11.5,...
# 4           5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11,9.5 M US
# 5      5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 6                                                    NaN
# 7      5,5.5,6,6 Wide,6 X-Wide,6.5,6.5 Wide,6.5 X-Wid...
# 8                    5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5
# 9            5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,12
# 10     5,5 Wide,5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,...
# 11     6 Women/4 Men,7 Women/5 Men,8 Women/6 Men,9 Wo...
# 12     5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Narrow,7 Wide,...
# 13      5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 14     4,4.5,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11...
# 15     5,5 Wide,5 X-Wide,5.5,5.5 Wide,5.5 X-Wide,6,6 ...
# 16                   5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11
# 17                           5.5,6,6.5,7,7.5,8,8.5,9,9.5
# 18     5,5.5,6,6.5,7,7 Wide,7.5,7.5 Wide,8,8.5,9,9.5,...
# 19     5,5 Wide,5.5,5.5 W US,5.5 Wide,6,6 Wide,6.5,6....
# 20                5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11
# 21                6,6.5,7,7.5,8,8.5,9,9.5,10,11,9.5 M US
# 22                                   4-5,5-6,6-7,7-8,8-9
# 23                   5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11
# 24     5,5 Wide,5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,...
# 25              5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11
# 26     5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7....
# 27     6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 Wide,8,...
# 28      5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 29        5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,12,13
#                              ...
# 343    5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 344    5 M Women,6 M Women,6.5 M Women,7.5 M Women,8 ...
# 345                                   5,6,7,8,9,10,11,12
# 346    6,6 Wide,6.5,6.5 Wide,7,7.5,7.5 Wide,8,8.5,9,9...
# 347    5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 348    5,5.5,6,6.5,6.5 US,7 M US,7,7.5 M US,7.5,8,8.5...
# 349    5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 350               5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11,12
# 351                  5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11
# 352    4,4 Narrow,4.5,4.5 Narrow,5,5 Narrow,5.5,5.5 N...
# 353                            6,6.5,7,7.5,8,8.5,9,10,11
# 354    5,5 Wide,5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,...
# 355    5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 356                  5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11
# 357    5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12,W...
# 358    5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Narrow,7 Wide,...
# 359    5,5 X-Wide,5.5,5.5 X-Wide,6,6 X-Wide,6-1/2,6.5...
# 360                  5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11
# 361                          5.5,6,6.5,7,7.5,8,8.5,9,9.5
# 362                           Large,Medium,Small,X-Large
# 363                     5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10
# 364    5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 365    5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 366    4-4.5,5-5.5,6-6.5,7-7.5,8-8.5,9-9.5,10-10.5,11...
# 367    5,5.5,6,6 Wide,6 X-Wide,6.5,6.5 Wide,6.5 X-Wid...
# 368    5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Narrow,7 Wide,...
# 369    5,5 Wide,5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,...
# 370    5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 371    5,5 Wide,5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,...
# 372    5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Narrow,7 Wide,...
# Name: product_sizes, Length: 373, dtype: object

# %%
dataset["num_sizes"] = ""

# %%
dataset["num_sizes"] = dataset.product_sizes.str.count(',') + 1

# %%
dataset['num_sizes'].value_counts()
# Out:
# 12.0    44
# 13.0    30
# 14.0    27
# 11.0    25
# 10.0    22
# 24.0    22
# 15.0    20
# 9.0     19
# 22.0    15
# 25.0    11
# 20.0    11
# 23.0     8
# 33.0     8
# 28.0     8
# 5.0      8
# 19.0     7
# 43.0     7
# 30.0     7
# 31.0     6
# 27.0     6
# 32.0     5
# 26.0     5
# 4.0      5
# 8.0      5
# 16.0     4
# 29.0     4
# 37.0     4
# 18.0     3
# 51.0     3
# 39.0     2
# 21.0     2
# 17.0     2
# 34.0     2
# 58.0     2
# 45.0     1
# 75.0     1
# 7.0      1
# 49.0     1
# 42.0     1
# 55.0     1
# 47.0     1
# 6.0      1
# 54.0     1
# Name: num_sizes, dtype: int64

# %%
dataset.head()
# Out:
#   product_asin                                    product_name  \
# 0   B07D3G9ZNG                       Brooks Women's Levitate 2
# 1   B07VKQWZR4                 Nike Women's Viale Running Shoe
# 2   B07X92DWVM      adidas Originals Women's Superstar Sneaker
# 3   B077GB5R7R  ECCO Women?s, Biom Fjuel Blaze Lace up Sneaker
# 4   B01KLTBMLA        adidas Women's W Tech Response Golf Shoe
#
#                                   product_sale_price  \
# 0  $99.80 - $249.95Lower price available on selec...
# 1                                   $33.39 - $133.00
# 2                                   $38.55 - $169.76
# 3  $69.68 - $159.06Lower price available on selec...
# 4  $29.99 - $140.34Lower price available on selec...
#
#                             product_category product_brand  product_rating  \
# 0  Women,Shoes,Athletic,Running,Road Running           NaN             4.4
# 1  Women,Shoes,Athletic,Running,Road Running           NaN             4.0
# 2               Women,Shoes,Fashion Sneakers           NaN             4.5
# 3               Women,Shoes,Athletic,Walking           NaN             4.1
# 4                  Women,Shoes,Athletic,Golf        adidas             4.4
#
#   num_ratings                                      product_sizes  \
# 0         163     5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 1         109   5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 2         392  1,1.5,2,2.5,3,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10...
# 3          26  4-4.5,5-5.5,7-7.5,8-8.5,9-9.5,10-10.5,11-11.5,...
# 4         222       5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11,9.5 M US
#
#                                       product_colors  \
# 0  Coral/Blue/Black,Aster/Purple/Blue,Pink/Black/...
# 1  Light Cream/Pure Platinum - White,Wolf Grey/Wh...
# 2  Scarlet/Scarlet/White,White/Ash Green/Silver M...
# 3  Black/Black,Concrete/White,Dark Shadow/Dark Sh...
# 4  Black/Silver Metallic/Grey Five,Clear/Grey,Whi...
#
#                                     product_features  \
# 0  Fabric,Imported,Rubber sole,The Brooks® Levita...
# 1  100% Leather and Synthetic,Imported,Rubber sol...
# 2  100% full grain leather,Imported,N/A,Rubber so...
# 3  Synthetic,Imported,Rubber sole,The flexible Bi...
# 4  Microfiber Leather/Climastorm,Imported,Synthet...
#
#                                        product_terms  product_qa  num_colors  \
# 0  toe box,second pair,love these shoes,true to s...          22        11.0
# 1                                                NaN          13        13.0
# 2                                                NaN          81        15.0
# 3                                                NaN           5         3.0
# 4                                                NaN          21         7.0
#
#    show_low_price  show_high_price shoe_gender  \
# 0           99.80           249.95       Women
# 1           33.39           133.00       Women
# 2           38.55           169.76       Women
# 3           69.68           159.06       Women
# 4           29.99           140.34       Women
#
#                         shoe_category_fixed shoe_category_final  num_sizes
# 0  [Shoes, Athletic, Running, Road Running]        Road Running       14.0
# 1  [Shoes, Athletic, Running, Road Running]        Road Running       15.0
# 2                 [Shoes, Fashion Sneakers]    Fashion Sneakers       25.0
# 3                [Shoes, Athletic, Walking]             Walking        8.0
# 4                   [Shoes, Athletic, Golf]                Golf       13.0

# %%
dataset['product_terms'].value_counts()
# Out:
# like walking,another pair,half size,second pair,shoes ever,highly recommend,memory foam,without socks,lightweight,plantar fasciitis,feel like,walking on air,walking on clouds,normally wear,true to size,everyday,extremely comfortable,super comfortable,different colors,wide width,across the top,easy to slip,third pair,high instep,toe box                                                 2
# new balance,lightweight,half size,memory foam,arch support,true to size,second pair,another pair,super cute,super comfortable,shoes i have ever,usually wear,ever owned,feel like,order a half,toe box,highly recommend,size larger,wide feet,like walking,without socks,wide width,super light,everyday,plantar fasciitis                                                                        2
# arch support,half size,fit perfectly,wide feet,bit snug,grey and pink,another pair,cute and comfortable,super cute,nice looking,black laces,ordered a half,pink laces,narrow feet,good quality,love love,great shoe,true to size,tight toes,best arch,comfortable and stylish,bit narrow,black with white,super comfy,felt great                                                                  2
# lightweight,another pair,second pair,shoes ever,like walking,highly recommend,true to size,feel like,without socks,different colors,half size,around the house,ever owned,walking on air,memory foam,every day,easy to slip,love love love,shoes are so comfortable,plantar fasciitis,comfortable shoe,like wearing,every color,best shoes,feet all day                                           2
# memory foam,half size,true to size,arch support,super comfortable,another pair,wide feet,second pair,super cute,super comfy,normally wear,highly recommend,right out of the box,comfortable and stylish,usually wear,lot of walking,toe box,without socks,easy to slip,every day,absolutely love,look like,comfortable and cute,cute and comfortable,slip ons                                     2
# memory foam,wide width,arch support,half size,size smaller,true to size,narrow feet,padded sole,toe area,fit fine,around the house,waste of money,toe box,ballet flats,toe cleavage,across the top,another pair,really like,shoes fit,scholl ballet flats,ordered the wide,ordered a half,usual size,top of my foot,flats always                                                                  2
# clark shoes,really like,love these shoes,highly recommend,shoes that fit,medium width,everlay heidi,heidi slip-on,slip-on loafer,like a glove,nice looking,fit perfectly,black ones,another pair,true to size,several pair,fit well,arch support,look nice,navy blue,wide width,comfortable shoe,excellent quality,fit perfect,well made                                                          2
# clark shoes,well made,toe box,right out of the box,true to size,arch support,second pair,hard to find,ashland bubble,another pair,highly recommend,nice looking,half size,love clark,fit perfect,shoes fit,every day,little tight,normally wear,bit large,great quality,bubble slip-on,many years,nice shoe,extremely comfortable                                                                 2
# love these shoes,true to size,like walking,super comfortable,another pair,memory foam,little big,lightweight,ever worn,usually wear,shoes i have ever,upcoming trip,look and feel,second pair,feel like,around the house,size larger,ever owned,fit well,fit perfectly,walking around,half size,size smaller,walking on clouds,cloudfoam                                                          1
# flip flops,like walking,another pair,highly recommend,second pair,arch support,plantar fasciitis,true to size,super comfortable,ever worn,flops ever,walking on clouds,different colors,extremely comfortable,ever owned,comfortable flip,arla glison,cloudsteppers,super comfy,absolutely love,worth the money,walking on air,love these flip,fit perfect,around the house                       1
# new balance,balance shoes,half size,toe box,plantar fasciitis,love new,another pair,well made,highly recommend,second pair,memory foam,good support,true to size,cross trainers,every day,wide width,even though,long time,shoes fit,toe area,feet all day,perfect fit,hard to find,really like,walk 3 miles                                                                                      1
# wear them without,love the look,super comfortable,shoe,heel,feet,apart,narrow,walking,slips,sneakers,stylish,scholl,slightly,socks,soles,trip                                                                                                                                                                                                                                                     1
# memory foam,half size,another pair,true to size,love bobs,different colors,second pair,everyday,super comfy,normally wear,super comfortable,wide feet,highly recommend,shoes are comfortable,little snug,usually wear,little bit,fit perfect,without socks,super cute,toe box,shoes because i love,good quality,really like,extremely comfortable                                                 1
# another pair,shoes i have ever,half size,arch support,memory foam,highly recommend,ever owned,lightweight,second pair,different colors,like walking,usually wear,true to size,size smaller,wide feet,feel like,ever worn,plantar fasciitis,love the color,super comfy,easy to slip,size larger,right out of the box,extremely comfortable,even though                                             1
# arch support,toe box,walking shoe,half size,plantar fasciitis,another pair,lightweight,highly recommend,true to size,second pair,shoes i have ever,size larger,devo plus,miles a day,right out of the box,toe area,like walking,ever owned,new balance,feel like,wide width,even though,super comfortable,wide feet,fit perfect                                                                   1
# top of my foot,clark shoes,across the top,good quality,well made,fit well,dark brown,toe box,medium width,emslie warbler,true to size,usually wear,love these shoes,right height,dress pants,dress slacks,right out the box,high arch,tight across,half size,clark brand,run slightly,happy with my purchase,second pair,slightly small                                                           1
# memory foam,half size,another pair,size larger,wide width,true to size,highly recommend,well made,second pair,toe box,normally wear,feet all day,fit perfect,like walking,nice looking,feel like,usually wear,toe area,plantar fasciitis,long time,extra wide,great price,perfect fit,different colors,everyday                                                                                   1
# tap shoes,split sole,half size,street shoe,size larger,toe stands,highly recommend,normally wear,true to size,daughter wears,high quality,super comfortable,year old,love these shoes,full size,size bigger,definitely recommend,tap class,well made,size larger than my street,super comfy,without socks,great sound,right out of the box,ordered a half                                         1
# memory foam,half size,another pair,true to size,second pair,like walking,plantar fasciitis,highly recommend,shoes ever,fit perfectly,light weight,ever owned,size larger,feet all day,hour shifts,feel like,fit perfect,super comfy,ever worn,really like,shoes are very comfortable,size bigger,toe box,long periods,navy blue                                                                   1
# across the top,arch support,end of the day,tight on the top,feet sweat,slip resistant,feet all day,waste your money,true to size,hour shifts,make my feet,tight across,high arches,hours on my feet,super cute,feet get,little tight,wear to work,feel like,hours a day,half size,love these shoes,super comfortable,super comfy,legs ache                                                        1
# slip resistant,memory foam,arch support,half size,work shoes,feet all day,super cute,easy to clean,true to size,size bigger,fit as expected,another pair,super comfy,feel like,hours a week,top of my foot,super comfortable,fit well,shoes are comfortable,days a week,hour shifts,great shoe,full time,little tight,non slips                                                                   1
# second pair,half size,wide width,around the house,arch support,super comfortable,like walking,shoes ever,another pair,memory foam,ever owned,lightweight,disney world,size larger,shoes are very comfortable,highly recommend,fit perfectly,super comfy,without socks,washing machine,size smaller,air dry,walked over 17 miles,comfortable shoe,toe box                                          1
# arch support,true to size,years ago,half size,second pair,another pair,light weight,toe box,different colors,super comfy,feet hurt,retro look,highly recommend,ever owned,love love love,high arches,ever worn,shoes ever,low pro,new pair,original jazz,extremely comfortable,hard to find,right out of the box,size larger                                                                      1
# half size,love these shoes,arch support,super cute,run small,another pair,normally wear,true to size,size larger,fit perfect,second pair,usually wear,order a full size,full size,size bigger,cute and comfy,like wearing,super comfy,lightweight,super comfortable,memory foam,little tight,wear a size,without socks,little small                                                               1
# toe box,clark shoes,half size,good quality,nice looking,cute style,well made,pairs of clark,comfortable and very nice,size too large,shoes are so comfortable,cute shoe,shoe and love the shoe,foot,wide,tight,narrow,heel,toes,sides,usually,flat,leather,smaller,socks                                                                                                                          1
# slip resistant,memory foam,non slip,work shoes,another pair,feet hurt,arch support,true to size,little big,shoes ever,food service,nice looking,resistant shoes,super comfortable,shoes for work,little bit,hour shifts,size smaller,shoes are very comfortable,feel like,started wearing,ever bought,smaller than usual,highly recommend,new pair                                                1
# memory foam,arch support,half size,toe box,true to size,wide feet,super comfy,pointed toe,another pair,super comfortable,feel like,every color,ballet flats,fit well,size larger,fit perfectly,usually wear,toe area,super cute,wearing slippers,second pair,ever owned,like wearing,hard to find,wear to work                                                                                    1
# half size,shoes are very comfortable,super cute,true to size,size smaller,falling apart,run big,heel slips,arch support,ordered a half,normally wear,comfortable and stylish,little bit,super comfortable,amazing shoe,wear all day,loved these shoes,great shoe,comfortable love,shoes are so cute,comfortable shoes,comfy,narrow,sole,foot                                                      1
# super cute,true to size,love these shoes,another pair,toe box,different color,half size,highly recommend,pair in a different,good quality,fit perfect,cute and comfortable,wide feet,little snug,arch support,super comfy,fit perfectly,really cute,usually wear,normally wear,cute and comfy,little small,new favorite,size larger,feels like                                                    1
# half size,toe box,top of the foot,super cute,second pair,clarks shoes,wear heels,cute shoes,work shoes,look great,shoes are super,size smaller,ordered a half,super comfortable,cute and comfortable,size up to fit,love these shoes,shoes are super comfortable,great shoes,shoes for work,shoe,feet,comfy,leather,heel                                                                          1
#                                                                                                                                                                                                                                                                                                                                                                                                  ..
# memory foam,work shoes,slip resistant,falling apart,another pair,half size,extra wide,second pair,hours a day,feet all day,ever worn,feel like,size larger,last long,end of my shift,plantar fasciitis,toe box,shoes ever,already falling,relaxed fit,wide width,feet hurt,wasted my money,non slip,fit great                                                                                     1
# arch support,end of the day,size bigger,shoes i have ever,feet hurt,pair of shoes,feet for 8 hours,feel like,every day,shoes are nice,half size,top of my foot,never buy,hurt my feet,wore them three days,size ordered,wear them with socks,work shoes,fit as expected,uncomfortable shoes,hours a day,support that my feet,shoes are very comfortable,day on my feet,comfortable and my feet    1
# memory foam,arch support,half size,another pair,true to size,fit perfectly,love bobs,second pair,really like,without socks,super cute,size smaller,normally wear,around the house,super comfy,highly recommend,well made,shoes are so comfortable,little big,toe box,wide feet,little tight,shoes ever,usually wear,cute and comfortable                                                          1
# runs large,half size,another pair,man made,absolutely love,feel like,cute and comfy,height is perfect,medium width,size smaller,smaller than my usual,true to size,way to big,work shoes,heel height,shoe is so comfortable,fit as well,runs big,looking shoe,ordered a half,heel area,fit perfect,fit perfectly,great work,nice looking                                                          1
# rocket dog,love these shoes,half size,super cute,wide feet,arch support,size smaller,dog shoes,second pair,run a little,another pair,normally wear,room in the toes,usually wear,whole size,order a half,different color,like clown,true to size,wiggle room,love my rocket,little big,easy to slip,well made,run big                                                                             1
# true to size,half size,love these shoes,highly recommend,like walking,super comfortable,good for walking,love love love,extremely comfortable,great buy,shoes happy,favorite shoes,shoes are so comfy,love the color,love these sneakers,size and love,comfortable shoe,great shoes,shoes great,shoes love,feet,slip,stylish,breathable,comfort                                                   1
# memory foam,half size,another pair,true to size,second pair,super cute,highly recommend,normally wear,normal size,look great,usually wear,little bit,shoes are very comfortable,cute and comfy,really cute,arch support,cute and comfortable,super comfortable,flip flops,different colors,super comfy,little big,extremely comfortable,another color,run small                                   1
# new balance,toe box,half size,balance shoes,wide feet,extra wide,toe area,second pair,true to size,another pair,plenty of room,hard to find,love new,nice looking,really like,good fit,shoes fit,highly recommend,lightweight,every day,size smaller,long walks,good support,years ago,athletic shoes                                                                                             1
# toe box,arch support,half size,second pair,great price,true to size,running shoe,another pair,great shoe,plantar fasciitis,size larger,highly recommend,lightweight,everyday,tennis shoes,love love love,right out of the box,well made,narrow heel,high arches,shoes fit,fit perfect,perfect fit,super comfy,nice looking                                                                        1
# new balance,lightweight,fresh foam,another pair,true to size,half size,toe box,wide feet,second pair,fit as expected,balance shoes,fit well,look nice,feel like,love the color,super cute,even though,toe area,really like,wide width,super comfy,nice looking,enough support,everyday,highly recommend                                                                                           1
# love these shoes,arch support,fit well,super comfortable,fit perfectly,back of heel,really like,super cute,bought a pair,great price,cute and comfortable,tennis shoes,wear to work,ordered 10 w as size,great shoe,fit perfect,shoes are comfortable,walking shoes,shoes and love,comfortable shoe,sketchers,comfy,feet,comfort,heels                                                            1
# air max,rose gold,love these shoes,half size,black and pink,perfect fit,absolutely love,usually wear,fit perfectly,hours a day,tennis shoes,true to size,different colors,foot pain,feel like,fit great,great fit,great support,wear them to work,new shoes,good support,shoes without,wear a 9 and ordered,fit perfect,pair of shoes                                                             1
# true to size,lots of compliments,wide width,perfect fit,shoes are comfortable,look great,comfortable shoe,shoes look,feet,red,stylish,comfort,toe,wore,elegant,gorgeous,narrow,walk,ankle,dresses,feminine,flat,height,length,pairs                                                                                                                                                               1
# half size,highly recommend,another pair,like walking,true to size,arch support,fit perfectly,lightweight,shoes ever,second pair,usually wear,memory foam,every day,wide width,little big,without socks,extremely comfortable,super comfortable,feel like,shoes are so comfortable,different colors,plantar fasciitis,ever owned,easy to slip,smaller size                                         1
# new balance,toe box,fresh foam,lightweight,well made,fit as expected,balance shoes,wide width,half size,extremely comfortable,running shoes,hiking shoes,wear to work,feel great,great shoes,walking shoe,shoes are very comfortable,shoes fit,feet,waterproof,support,laces,brown,heel,wearing                                                                                                   1
# half size,without socks,top of my foot,fit perfectly,second pair,ballet flats,true to size,lightweight,sent them back,ankle bone,toe area,nice looking,everyday,toe box,step lite,super comfy,love love love,size larger,business casual,super comfortable,memory foam,look like,another pair,shoes are comfortable,absolutely love                                                               1
# new balance,half size,memory foam,light weight,size larger,wide width,arch support,cross training,another pair,like walking,cross trainers,usually wear,less than 6 months,toe box,wide feet,ordered wide,nice looking,balance shoes,walking on a cloud,extremely comfortable,second pair,normally wear,ordered a half,run a little,feel like                                                     1
# workout shoe,running shoes,love these shoes,feet,crossfit,metcons,stability,support,lifting,metcon,narrow,comfort,comfy,flat,gym,stable,workouts,exercise,grip,hiit,snug,toe,walking,weightlifting,wider                                                                                                                                                                                          1
# memory foam,work shoes,slip resistant,arch support,lightweight,nursing school,non slip,second pair,feet all day,half size,true to size,feel like,another pair,shoes ever,end of the day,feet for hours,absolutely love,relaxed fit,last long,hour shifts,fit as expected,fit perfect,foam insoles,plantar fasciitis,long hours                                                                    1
# half size,toe box,true to size,highly recommend,another pair,size larger,plantar fasciitis,light weight,second pair,love the color,great shoe,wide width,running shoe,toe area,fit perfect,run small,fit as expected,normally wear,usually wear,times a week,super cute,flat feet,feet all day,everyday,little tight                                                                              1
# half size,true to size,arch support,another pair,super cute,second pair,normally wear,usually wear,around the house,highly recommend,pair of shoes,every day,super comfortable,super comfy,fit perfect,child in need,little tight,fits perfectly,love love love,without socks,shoes ever,feel like,get dirty,little big,next time                                                                 1
# light weight,another pair,second pair,true to size,arch support,half size,memory foam,shoes ever,different colors,super comfy,look good,everyday,highly recommend,without socks,feel like,walk shoes,fit perfect,absolutely love,fit fine,plantar fasciitis,extremely comfortable,fit great,wear socks,plenty of room,great for walking                                                           1
# steel toe,memory foam,half size,work shoes,nice looking,arch support,fit well,size larger,feet didnt hurt,feel like,hours a day,fit great,love these shoes,safety shoes,love sketchers,end of the day,concrete floors,great fit,extremely comfortable,usually wear,another pair,slip resistant,true to size,right shoe,love love                                                                  1
# memory foam,another pair,lightweight,like walking,half size,second pair,true to size,shoes ever,highly recommend,size larger,even though,right out of the box,feel like,super comfortable,normally wear,ever owned,extremely comfortable,wide width,without socks,easy to slip,nice looking,plantar fasciitis,ever worn,fit perfect,end of the day                                                1
# arch support,another pair,right out of the box,ashland spin,high arches,second pair,shoes are very comfortable,clark shoes,toe box,super cute,highly recommend,across the top,top of my foot,normally wear,pair in a different,usually wear,nice shoe,velcro strap,well made,good quality,cute and comfy,love love love love,half size,wide width,cushioned insole                                1
# lightweight,memory foam,half size,another pair,second pair,highly recommend,feel like,feet all day,true to size,ever worn,fit perfect,size bigger,love love love,different colors,super comfortable,disney world,shoes ever,tie laces,look nice,cushion inside,long walks,extremely comfortable,tennis shoe,run small,walking shoe                                                                1
# memory foam,love these shoes,another pair,second pair,half size,shoes ever,light weight,arch support,like walking,highly recommend,feel like,fit perfectly,size larger,different colors,ever worn,around the house,walk impress,true to size,shoes are very comfortable,love sketchers,extremely comfortable,wide width,easy to slip,washing machine,end of the day                               1
# wear heels,heel height,many compliments,ordered the wide,another pair,wide width,wear all day,little tight,true to size,every day,super comfortable,fits me perfectly,right size,wide foot,shoe at a good,comfortable and cute,comfortable love,day wear,great shoe,love these shoe,comfortable for all day,shoes to wear,comfortable shoe,shoes are comfortable,feet                             1
# memory foam,half size,princess lite,many years,lightweight,toe box,love these shoes,nursing school,arch support,highly recommend,usually wear,princess sneakers,ordered the wide,true to size,like the old,old reebok princess,like walking,even though,foam insole,good price,tennis shoes,around the house,exactly like,fit perfectly,walking on air                                            1
# toe box,half size,arch support,another pair,true to size,nike metcons,cross training,wide feet,running shoes,flat feet,weightlifting,box jumps,boot camp,love these shoes,wide toe,fit as expected,great shoe,usually wear,second pair,really like,nike metcon,high arches,much better,crossfit,cross trainer                                                                                     1
# Name: product_terms, Length: 121, dtype: int64

# %%
dataset['if_wide'] = ""

# %%
dataset['if_narrow'] = ""

# %%
dataset['if_wide'] = dataset['product_sizes'].str.contains('Wide')

# %%
dataset['if_narrow'] = dataset['product_sizes'].str.contains('Narrow')

# %%
dataset.head()
# Out:
#   product_asin                                    product_name  \
# 0   B07D3G9ZNG                       Brooks Women's Levitate 2
# 1   B07VKQWZR4                 Nike Women's Viale Running Shoe
# 2   B07X92DWVM      adidas Originals Women's Superstar Sneaker
# 3   B077GB5R7R  ECCO Women?s, Biom Fjuel Blaze Lace up Sneaker
# 4   B01KLTBMLA        adidas Women's W Tech Response Golf Shoe
#
#                                   product_sale_price  \
# 0  $99.80 - $249.95Lower price available on selec...
# 1                                   $33.39 - $133.00
# 2                                   $38.55 - $169.76
# 3  $69.68 - $159.06Lower price available on selec...
# 4  $29.99 - $140.34Lower price available on selec...
#
#                             product_category product_brand  product_rating  \
# 0  Women,Shoes,Athletic,Running,Road Running           NaN             4.4
# 1  Women,Shoes,Athletic,Running,Road Running           NaN             4.0
# 2               Women,Shoes,Fashion Sneakers           NaN             4.5
# 3               Women,Shoes,Athletic,Walking           NaN             4.1
# 4                  Women,Shoes,Athletic,Golf        adidas             4.4
#
#   num_ratings                                      product_sizes  \
# 0         163     5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 1         109   5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 2         392  1,1.5,2,2.5,3,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10...
# 3          26  4-4.5,5-5.5,7-7.5,8-8.5,9-9.5,10-10.5,11-11.5,...
# 4         222       5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11,9.5 M US
#
#                                       product_colors  \
# 0  Coral/Blue/Black,Aster/Purple/Blue,Pink/Black/...
# 1  Light Cream/Pure Platinum - White,Wolf Grey/Wh...
# 2  Scarlet/Scarlet/White,White/Ash Green/Silver M...
# 3  Black/Black,Concrete/White,Dark Shadow/Dark Sh...
# 4  Black/Silver Metallic/Grey Five,Clear/Grey,Whi...
#
#                                     product_features  ... product_qa  \
# 0  Fabric,Imported,Rubber sole,The Brooks® Levita...  ...         22
# 1  100% Leather and Synthetic,Imported,Rubber sol...  ...         13
# 2  100% full grain leather,Imported,N/A,Rubber so...  ...         81
# 3  Synthetic,Imported,Rubber sole,The flexible Bi...  ...          5
# 4  Microfiber Leather/Climastorm,Imported,Synthet...  ...         21
#
#    num_colors  show_low_price  show_high_price  shoe_gender  \
# 0        11.0           99.80           249.95        Women
# 1        13.0           33.39           133.00        Women
# 2        15.0           38.55           169.76        Women
# 3         3.0           69.68           159.06        Women
# 4         7.0           29.99           140.34        Women
#
#                         shoe_category_fixed shoe_category_final num_sizes  \
# 0  [Shoes, Athletic, Running, Road Running]        Road Running      14.0
# 1  [Shoes, Athletic, Running, Road Running]        Road Running      15.0
# 2                 [Shoes, Fashion Sneakers]    Fashion Sneakers      25.0
# 3                [Shoes, Athletic, Walking]             Walking       8.0
# 4                   [Shoes, Athletic, Golf]                Golf      13.0
#
#    if_wide if_narrow
# 0    False     False
# 1    False     False
# 2    False     False
# 3    False     False
# 4    False     False
#
# [5 rows x 21 columns]

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
text = dataset['product_features']

# %%
dataset[['product_features']] = dataset[['product_features']].fillna(value="unknown")

# %%
type(text)
# Out:
# pandas.core.series.Series

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", width = 800, height = 600).generate(' '.join(dataset['product_features']))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.figure( figsize=(20,20) )
plt.imshow(wordcloud)

#WordCloud(width=800, height=400)

# %%
dataset_fashion = dataset.loc[dataset["shoe_category_final"]=='Fashion Sneakers']

# %%
dataset_running = dataset.loc[dataset["shoe_category_final"]=='Road Running']

# %%
dataset_ballet = dataset.loc[dataset["shoe_category_final"]=='Ballet & Dance']

# %%
dataset["shoe_category_final"].value_counts()
# Out:
# Fashion Sneakers              63
# Shoes                         57
# Ballet & Dance                43
# Road Running                  35
# Flats                         32
# Pumps                         31
# Loafers & Slip-Ons            30
# Walking                       28
# Mules & Clogs                  7
# Oxfords                        5
# Fitness & Cross-Training       5
# Golf                           5
# Health Care & Food Service     4
# Slippers                       3
# Platforms & Wedges             3
# Heeled Sandals                 2
# Industrial & Construction      2
# Running                        2
# Ankle & Bootie                 2
# Skateboarding                  1
# Slides                         1
# Sneakers                       1
# Flip-Flops                     1
# Sandals                        1
# Water Shoes                    1
# Soccer                         1
# Volleyball                     1
# Boots                          1
# Hiking Shoes                   1
# Rain Footwear                  1
# Tennis & Racquet Sports        1
# Trail Running                  1
# Fire & Safety                  1
# Name: shoe_category_final, dtype: int64

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", width = 800, height = 600).generate(' '.join(dataset['product_features']))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.figure( figsize=(20,20) )
plt.imshow(wordcloud)

#WordCloud(width=800, height=400)

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", width = 800, height = 600).generate(' '.join(dataset_fashion['product_features']))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.figure( figsize=(20,20) )
plt.imshow(wordcloud)

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", width = 800, height = 600).generate(' '.join(dataset_running['product_features']))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.figure( figsize=(20,20) )
plt.imshow(wordcloud)

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", width = 800, height = 600).generate(' '.join(dataset_ballet['product_features']))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.figure( figsize=(20,20) )
plt.imshow(wordcloud)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))

corr = dataset.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %%
plt.figure(figsize=(10, 10))

corr_small = dataset.corr()
corr_small.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col1 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col2 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col3 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col4 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col0 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col2 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col5 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col1 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col4 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col5 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row3_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row3_col4 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row3_col5 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row4_col0 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row4_col1 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row4_col2 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row4_col3 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row4_col5 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row5_col1 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row5_col2 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row5_col3 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row5_col4 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >product_rating</th>        <th class="col_heading level0 col1" >product_qa</th>        <th class="col_heading level0 col2" >num_colors</th>        <th class="col_heading level0 col3" >show_low_price</th>        <th class="col_heading level0 col4" >show_high_price</th>        <th class="col_heading level0 col5" >num_sizes</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042level0_row0" class="row_heading level0 row0" >product_rating</th>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col1" class="data row0 col1" >0.115252</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col2" class="data row0 col2" >0.0536986</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col3" class="data row0 col3" >0.159727</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col4" class="data row0 col4" >0.125138</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row0_col5" class="data row0 col5" >0.0394069</td>
#             </tr>
#             <tr>
#                         <th id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042level0_row1" class="row_heading level0 row1" >product_qa</th>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col0" class="data row1 col0" >0.115252</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col2" class="data row1 col2" >0.252759</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col3" class="data row1 col3" >-0.0156235</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col4" class="data row1 col4" >0.115355</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row1_col5" class="data row1 col5" >0.366884</td>
#             </tr>
#             <tr>
#                         <th id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042level0_row2" class="row_heading level0 row2" >num_colors</th>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col0" class="data row2 col0" >0.0536986</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col1" class="data row2 col1" >0.252759</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col3" class="data row2 col3" >-0.0762772</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col4" class="data row2 col4" >0.213955</td>
#                         <td id="T_ee62810c_0413_11ea_8ea0_88e9fe6b7042row2_col5" class="data row2 col5" >0.267602</td>
#             </tr>
#             <tr>

# %%
dataset.num_ratings = dataset.num_ratings.replace({",",""}, regex=True)

# %%
dataset['num_ratings'] = dataset['num_ratings'].str.replace(',', '')

# %%
dataset['num_ratings'] = pd.to_numeric(dataset['num_ratings'])

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 15))
ax = sns.scatterplot(x='show_low_price', y = 'show_high_price', data = dataset)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 15))
ax = sns.scatterplot(x='product_qa', y = 'num_sizes', data = dataset)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 15))
ax = sns.scatterplot(x='num_colors', y = 'num_sizes', data = dataset)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 15))
ax = sns.scatterplot(x='num_colors', y = 'show_high_price', data = dataset)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 15))
ax = sns.scatterplot(x='num_sizes', y = 'product_rating', data = dataset)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 15))
ax = sns.scatterplot(x='num_sizes', y = 'show_low_price', data = dataset)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 15))
ax = sns.scatterplot(x='num_colors', y = 'show_low_price', data = dataset)

# %%
dataset.plot.scatter(x='num_ratings', y = 'product_rating')
# Out:
# WARNING:matplotlib.axes._axes:'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
type(dataset.num_ratings[0])
# Out:
# str

# %%
ax1 = dataset.plot.scatter(x='product_rating', y = 'num_ratings')
# Out:
# WARNING:matplotlib.axes._axes:'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
ax1 = dataset.plot.scatter(x='product_qa', y = 'num_ratings')
# Out:
# WARNING:matplotlib.axes._axes:'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
ax2 = dataset.plot.scatter(x = 'num_sizes', y = 'product_rating')
# Out:
# WARNING:matplotlib.axes._axes:'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
ax3 = dataset.plot.scatter(x = 'product_qa', y = 'product_rating')
# Out:
# WARNING:matplotlib.axes._axes:'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
dataset.head()
# Out:
#   product_asin                                    product_name  \
# 0   B07D3G9ZNG                       Brooks Women's Levitate 2
# 1   B07VKQWZR4                 Nike Women's Viale Running Shoe
# 2   B07X92DWVM      adidas Originals Women's Superstar Sneaker
# 3   B077GB5R7R  ECCO Women?s, Biom Fjuel Blaze Lace up Sneaker
# 4   B01KLTBMLA        adidas Women's W Tech Response Golf Shoe
#
#                                   product_sale_price  \
# 0  $99.80 - $249.95Lower price available on selec...
# 1                                   $33.39 - $133.00
# 2                                   $38.55 - $169.76
# 3  $69.68 - $159.06Lower price available on selec...
# 4  $29.99 - $140.34Lower price available on selec...
#
#                             product_category product_brand  product_rating  \
# 0  Women,Shoes,Athletic,Running,Road Running           NaN             4.4
# 1  Women,Shoes,Athletic,Running,Road Running           NaN             4.0
# 2               Women,Shoes,Fashion Sneakers           NaN             4.5
# 3               Women,Shoes,Athletic,Walking           NaN             4.1
# 4                  Women,Shoes,Athletic,Golf        adidas             4.4
#
#   num_ratings                                      product_sizes  \
# 0         163     5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 1         109   5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 2         392  1,1.5,2,2.5,3,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10...
# 3          26  4-4.5,5-5.5,7-7.5,8-8.5,9-9.5,10-10.5,11-11.5,...
# 4         222       5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11,9.5 M US
#
#                                       product_colors  \
# 0  Coral/Blue/Black,Aster/Purple/Blue,Pink/Black/...
# 1  Light Cream/Pure Platinum - White,Wolf Grey/Wh...
# 2  Scarlet/Scarlet/White,White/Ash Green/Silver M...
# 3  Black/Black,Concrete/White,Dark Shadow/Dark Sh...
# 4  Black/Silver Metallic/Grey Five,Clear/Grey,Whi...
#
#                                     product_features  \
# 0  Fabric,Imported,Rubber sole,The Brooks® Levita...
# 1  100% Leather and Synthetic,Imported,Rubber sol...
# 2  100% full grain leather,Imported,N/A,Rubber so...
# 3  Synthetic,Imported,Rubber sole,The flexible Bi...
# 4  Microfiber Leather/Climastorm,Imported,Synthet...
#
#                                        product_terms  product_qa shoe_gender  \
# 0  toe box,second pair,love these shoes,true to s...          22       Women
# 1                                                NaN          13       Women
# 2                                                NaN          81       Women
# 3                                                NaN           5       Women
# 4                                                NaN          21       Women
#
#                         shoe_category_fixed shoe_category_final  num_sizes  \
# 0  [Shoes, Athletic, Running, Road Running]        Road Running       14.0
# 1  [Shoes, Athletic, Running, Road Running]        Road Running       15.0
# 2                 [Shoes, Fashion Sneakers]    Fashion Sneakers       25.0
# 3                [Shoes, Athletic, Walking]             Walking        8.0
# 4                   [Shoes, Athletic, Golf]                Golf       13.0
#
#   if_wide if_narrow  show_low_price  show_high_price
# 0   False     False           99.80           249.95
# 1   False     False           33.39           133.00
# 2   False     False           38.55           169.76
# 3   False     False           69.68           159.06
# 4   False     False           29.99           140.34

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import nltk

# %%
text = ' '.join(dataset['product_features'])

# %%
text
# Out:
# 'Fabric,Imported,Rubber sole,The Brooks® Levitate 2 running shoe is designed with the highest energy return possible so you will rise to every challenge you meet on the road. 100% Leather and Synthetic,Imported,Rubber sole,Shaft measures approximately low-top from arch,Ultra-light design inspired by marathon runners.,Mesh upper allows for breathability.,Outsole lugs surround a hollowed core to optimize stability.,Injected foam (IU) midsole for cushioning and long-lasting comfort,Microbranding on the tongue middle. Hidden branding under the heel tab -- lift up to see a Swoosh design trademark underneath. 100% full grain leather,Imported,N/A,Rubber sole,Shaft measures approximately 3.2" from arch,Boot opening measures approximately 11" around,Retro-styled lace-up fashion sneaker featuring classic three-stripe detailing and heritage shell toe,Removable insole,Mesh lining,Herringbone-pattern rubber cupsole Synthetic,Imported,Rubber sole,The flexible Biom Fjuel Tie gives you the boost to own the track. Microfiber Leather/Climastorm,Imported,Synthetic sole,Microfiber leather upper with climastorm water resistant protection from the elements,Cloud foam insole provides ultra-light cushioning and comfort,6-spike thintech outsole with adiwear for long-lasting abrasion resistance and traction,Tour performance last specifically-designed to be wider in the forefoot for improved fit, feel and overall comfort,New low profile thintech exp cleat offers improved stability, traction, durability, and green friendliness 100% Leather,Imported,Rubber sole,Heel measures approximately 1.5 inches",Platform measures approximately .5 inches,Heel height 1.4",Ortholite footbed,Cushion soft Fabric-And-Synthetic,Rubber sole,Platform measures approximately 1,Lace-up closure,Strategically-placed rubber in the outsole for reliable traction,Hexagonal flex grooves promote a more natural underfoot feel 100% Leather,Imported,Synthetic sole,Heel measures approximately 1.5",Heel height 1.29",Ortholite footbed Satin upper,Soft suede sole,Elegant Exterior: Allure your onlookers when you hit the dance floor in the SKOEX dance shoes; Rhinestones-embellished bring a dazzling element to your dancing ensemble,Comfortable Material: Women dance shoes features high quality satin upper with fine sweat absorption suede insole, High elastic latex midsole with thick durable suede outsole, you will feel flexible and comfort,Classic Design: Simple and generous style design, low-key luxury; open-toe design with ankle strap and buckle closure; stable heel to protect you dance well and aren\'t fall down,Soft Lightweight: 2.5" Heeled ladies dance shoe featuring super lightweight and flexible, make you feel great freedom and comfortable in wearing, keep your amazing dancing,Perfect Occasion: Womens ballroom shoes suitable for Latin, Salsa, Tango, Rumba, amateur and professional dancers ballroom dance, dance class,beginner, practice & performance 100% Textile,Imported,Synthetic sole,Shaft measures approximately low-top from arch,NEUTRAL: For runners who need flexibility, cushioning & versatility,Engineered mesh upper is extremely lightweight & breathable, with strategic support where you need it,Lightweight, external heel counter for additional support that keeps the back of the foot locked in place,Charged Cushioning midsole uses compression molded foam for even greater responsiveness & durability, providing optimal cushioning & energy return,Removable, comfort sockliner provides 100% Textile and Synthetic,Imported,Rubber sole,Shaft measures approximately low-top from arch,Blown Rubber Outsole,Bootie Construction,Nb Response 2.0 Performance Insert,Synthetic/Mesh Upper 100% Synthetic,Imported,Synthetic sole,Shaft measures approximately not_applicable from arch,Incredibly light and fun to wear,Ventilation ports add breathability and help shed water,Easy to clean and quick to dry,Pivoting heel straps for a more secure fit. Customizable with Jibbitz charms,Iconic Crocs Comfort: Lightweight.  ...

# %%
# split into words
tokens = word_tokenize(text)
# convert to lower case
tokens = [w.lower() for w in tokens]
# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]
# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]
# filter out stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print(words[:100])
# Out:
# ['fabric', 'imported', 'rubber', 'sole', 'levitate', 'running', 'shoe', 'designed', 'highest', 'energy', 'return', 'possible', 'rise', 'every', 'challenge', 'meet', 'road', 'leather', 'synthetic', 'imported', 'rubber', 'sole', 'shaft', 'measures', 'approximately', 'lowtop', 'arch', 'ultralight', 'design', 'inspired', 'marathon', 'runners', 'mesh', 'upper', 'allows', 'breathability', 'outsole', 'lugs', 'surround', 'hollowed', 'core', 'optimize', 'stability', 'injected', 'foam', 'iu', 'midsole', 'cushioning', 'longlasting', 'comfort', 'microbranding', 'tongue', 'middle', 'hidden', 'branding', 'heel', 'tab', 'lift', 'see', 'swoosh', 'design', 'trademark', 'underneath', 'full', 'grain', 'leather', 'imported', 'na', 'rubber', 'sole', 'shaft', 'measures', 'approximately', 'arch', 'boot', 'opening', 'measures', 'approximately', 'around', 'retrostyled', 'laceup', 'fashion', 'sneaker', 'featuring', 'classic', 'threestripe', 'detailing', 'heritage', 'shell', 'toe', 'removable', 'insole', 'mesh', 'lining', 'herringbonepattern', 'rubber', 'cupsole', 'synthetic', 'imported', 'rubber']

# %%
from collections import Counter
from pprint import pprint
bigrams = Counter(zip(words,words[1:]))
pprint(bigrams)
# Out:
# Counter({('measures', 'approximately'): 296,
#          ('shaft', 'measures'): 208,
#          ('sole', 'shaft'): 204,
#          ('rubber', 'sole'): 166,
#          ('imported', 'rubber'): 150,
#          ('synthetic', 'sole'): 127,
#          ('imported', 'synthetic'): 125,
#          ('approximately', 'notapplicable'): 105,
#          ('notapplicable', 'arch'): 104,
#          ('approximately', 'lowtop'): 91,
#          ('lowtop', 'arch'): 90,
#          ('textile', 'imported'): 74,
#          ('leather', 'imported'): 67,
#          ('synthetic', 'imported'): 62,
#          ('memory', 'foam'): 58,
#          ('heel', 'measures'): 51,
#          ('approximately', 'inches'): 47,
#          ('dance', 'shoes'): 47,
#          ('heel', 'height'): 43,
#          ('rubber', 'outsole'): 41,
#          ('platform', 'measures'): 36,
#          ('suede', 'sole'): 33,
#          ('mesh', 'upper'): 30,
#          ('satin', 'upper'): 30,
#          ('lightweight', 'flexible'): 30,
#          ('ortholite', 'footbed'): 29,
#          ('cushion', 'soft'): 29,
#          ('suitable', 'latin'): 29,
#          ('latin', 'salsa'): 29,
#          ('salsa', 'tango'): 29,
#          ('tango', 'rumba'): 29,
#          ('high', 'quality'): 28,
#          ('arch', 'heel'): 28,
#          ('fabric', 'imported'): 27,
#          ('stable', 'heel'): 26,
#          ('quality', 'satin'): 24,
#          ('upper', 'soft'): 21,
#          ('arch', 'platform'): 21,
#          ('shoes', 'suitable'): 20,
#          ('arch', 'lightweight'): 19,
#          ('sole', 'heel'): 18,
#          ('shoe', 'featuring'): 18,
#          ('textile', 'synthetic'): 18,
#          ('flexible', 'sole'): 18,
#          ('maximum', 'comfort'): 18,
#          ('man', 'made'): 18,
#          ('style', 'design'): 17,
#          ('ankle', 'strap'): 17,
#          ('super', 'lightweight'): 17,
#          ('feel', 'great'): 17,
#          ('made', 'imported'): 17,
#          ('flexible', 'comfort'): 16,
#          ('strap', 'buckle'): 16,
#          ('buckle', 'closure'): 16,
#          ('ballroom', 'dance'): 16,
#          ('leather', 'sole'): 16,
#          ('textile', 'lining'): 16,
#          ('soft', 'fabric'): 16,
#          ('soft', 'technology'): 16,
#          ('footbed', 'cushion'): 15,
#          ('soft', 'suede'): 15,
#          ('sole', 'elegant'): 15,
#          ('elegant', 'exterior'): 15,
#          ('exterior', 'allure'): 15,
#          ('allure', 'onlookers'): 15,
#          ('onlookers', 'hit'): 15,
#          ('hit', 'dance'): 15,
#          ('dance', 'floor'): 15,
#          ('floor', 'skoex'): 15,
#          ('skoex', 'dance'): 15,
#          ('shoes', 'rhinestonesembellished'): 15,
#          ('rhinestonesembellished', 'bring'): 15,
#          ('bring', 'dazzling'): 15,
#          ('dazzling', 'element'): 15,
#          ('element', 'dancing'): 15,
#          ('dancing', 'ensemble'): 15,
#          ('ensemble', 'comfortable'): 15,
#          ('comfortable', 'material'): 15,
#          ('material', 'women'): 15,
#          ('women', 'dance'): 15,
#          ('shoes', 'features'): 15,
#          ('features', 'high'): 15,
#          ('upper', 'fine'): 15,
#          ('fine', 'sweat'): 15,
#          ('sweat', 'absorption'): 15,
#          ('absorption', 'suede'): 15,
#          ('suede', 'insole'): 15,
#          ('insole', 'high'): 15,
#          ('high', 'elastic'): 15,
#          ('elastic', 'latex'): 15,
#          ('latex', 'midsole'): 15,
#          ('midsole', 'thick'): 15,
#          ('thick', 'durable'): 15,
#          ('durable', 'suede'): 15,
#          ('suede', 'outsole'): 15,
#          ('outsole', 'feel'): 15,
#          ('feel', 'flexible'): 15,
#          ('comfort', 'classic'): 15,
#          ('classic', 'design'): 15,
#          ('design', 'simple'): 15,
#          ('simple', 'generous'): 15,
#          ('generous', 'style'): 15,
#          ('design', 'lowkey'): 15,
#          ('lowkey', 'luxury'): 15,
#          ('luxury', 'opentoe'): 15,
#          ('opentoe', 'design'): 15,
#          ('design', 'ankle'): 15,
#          ('closure', 'stable'): 15,
#          ('heel', 'protect'): 15,
#          ('protect', 'dance'): 15,
#          ('dance', 'well'): 15,
#          ('well', 'nt'): 15,
#          ('nt', 'fall'): 15,
#          ('fall', 'soft'): 15,
#          ('soft', 'lightweight'): 15,
#          ('lightweight', 'heeled'): 15,
#          ('heeled', 'ladies'): 15,
#          ('ladies', 'dance'): 15,
#          ('dance', 'shoe'): 15,
#          ('featuring', 'super'): 15,
#          ('flexible', 'make'): 15,
#          ('make', 'feel'): 15,
#          ('great', 'freedom'): 15,
#          ('freedom', 'comfortable'): 15,
#          ('comfortable', 'wearing'): 15,
#          ('wearing', 'keep'): 15,
#          ('keep', 'amazing'): 15,
#          ('amazing', 'dancing'): 15,
#          ('dancing', 'perfect'): 15,
#          ('perfect', 'occasion'): 15,
#          ('occasion', 'womens'): 15,
#          ('womens', 'ballroom'): 15,
#          ('ballroom', 'shoes'): 15,
#          ('rumba', 'amateur'): 15,
#          ('amateur', 'professional'): 15,
#          ('professional', 'dancers'): 15,
#          ('dancers', 'ballroom'): 15,
#          ('dance', 'dance'): 15,
#          ('dance', 'class'): 15,
#          ('class', 'beginner'): 15,
#          ('beginner', 'practice'): 15,
#          ('practice', 'performance'): 15,
#          ('height', 'inches'): 15,
#          ('rumba', 'chacha'): 14,
#          ('chacha', 'practicing'): 14,
#          ('responsive', 'cushioning'): 14,
#          ('goga', 'max'): 14,
#          ('leather', 'synthetic'): 13,
#          ('imported', 'leather'): 13,
#          ('sole', 'suitable'): 13,
#          ('suitable', 'indoor'): 13,
#          ('good', 'skid'): 13,
#          ('skid', 'resistance'): 13,
#          ('resistance', 'balance'): 13,
#          ('practicing', 'performance'): 13,
#          ('lightweight', 'responsive'): 13,
#          ('flexible', 'lightweight'): 12,
#          ('lightweight', 'comfortable'): 12,
#          ('latin', 'dance'): 12,
#          ('get', 'rid'): 12,
#          ('flexible', 'durable'): 12,
#          ('breathable', 'mesh'): 12,
#          ('knit', 'upper'): 12,
#          ('goga', 'mat'): 12,
#          ('fabric', 'lining'): 12,
#          ('air', 'cooled'): 12,
#          ('foam', 'insole'): 11,
#          ('heel', 'counter'): 11,
#          ('extremely', 'flexible'): 11,
#          ('comfortable', 'situable'): 11,
#          ('nonslip', 'suede'): 11,
#          ('indoor', 'floor'): 11,
#          ('floor', 'good'): 11,
#          ('adjustable', 'buckle'): 11,
#          ('contact', 'us'): 11,
#          ('free', 'energy'): 11,
#          ('energy', 'technology'): 11,
#          ('technology', 'insole'): 11,
#          ('insole', 'distinct'): 11,
#          ('distinct', 'zones'): 11,
#          ('zones', 'designed'): 11,
#          ('designed', 'maximum'): 11,
#          ('cushioning', 'skechers'): 11,
#          ('sole', 'memory'): 11,
#          ('foam', 'cool'): 11,
#          ('cool', 'fit'): 11,
#          ('inches', 'heel'): 10,
#          ('shoes', 'nonslip'): 10,
#          ('arch', 'free'): 10,
#          ('durable', 'sole'): 10,
#          ('high', 'rebound'): 10,
#          ('suede', 'imported'): 10,
#          ('skechers', 'air'): 10,
#          ('cooled', 'goga'): 10,
#          ('fit', 'insole'): 10,
#          ('sole', 'high'): 9,
#          ('satin', 'smooth'): 9,
#          ('smooth', 'exquisite'): 9,
#          ('exquisite', 'extremely'): 9,
#          ('situable', 'professionals'): 9,
#          ('professionals', 'standard'): 9,
#          ('standard', 'latin'): 9,
#          ('balance', 'adjustable'): 9,
#          ('buckle', 'ankle'): 9,
#          ('ankle', 'foot'): 9,
#          ('foot', 'dancing'): 9,
#          ('dancing', 'feel'): 9,
#          ('feel', 'comfortable'): 9,
#          ('comfortable', 'stable'): 9,
#          ('approximately', 'model'): 9,
#          ('model', 'suitable'): 9,
#          ('performance', 'usually'): 9,
#          ('usually', 'shows'): 9,
#          ('shows', 'indoor'): 9,
#          ('indoor', 'wedding'): 9,
#          ('wedding', 'dance'): 9,
#          ('dance', 'performence'): 9,
#          ('performence', 'shipping'): 9,
#          ('shipping', 'time'): 9,
#          ('time', 'usually'): 9,
#          ('usually', 'days'): 9,
#          ('days', 'need'): 9,
#          ('need', 'urgntly'): 9,
#          ('urgntly', 'please'): 9,
#          ('please', 'contact'): 9,
#          ('us', 'choose'): 9,
#          ('choose', 'faster'): 9,
#          ('faster', 'shipping'): 9,
#          ('machine', 'washable'): 9,
#          ('synthetic', 'upper'): 9,
#          ('every', 'step'): 9,
#          ('comfortable', 'fit'): 9,
#          ('mat', 'insole'): 9,
#          ('height', 'ortholite'): 8,
#          ('lightweight', 'breathable'): 8,
#          ('additional', 'support'): 8,
#          ('allday', 'comfort'): 8,
#          ('radically', 'lightweight'): 8,
#          ('quality', 'materials'): 8,
#          ('high', 'heels'): 8,
#          ('pair', 'shoes'): 8,
#          ('max', 'high'): 8,
#          ('approximately', 'platform'): 8,
#          ('mesh', 'fabric'): 8,
#          ('foam', 'midsole'): 8,
#          ('eva', 'midsole'): 8,
#          ('smooth', 'textile'): 8,
#          ('shoes', 'made'): 8,
#          ('split', 'sole'): 8,
#          ('upper', 'rubber'): 8,
#          ('sole', 'leather'): 8,
#          ('running', 'shoe'): 7,
#          ('flex', 'grooves'): 7,
#          ('approximately', 'heel'): 7,
#          ('outsole', 'provides'): 7,
#          ('arch', 'memory'): 7,
#          ('easy', 'care'): 7,
#          ('skechers', 'goga'): 7,
#          ('manmade', 'imported'): 7,
#          ('foot', 'bed'): 7,
#          ('imported', 'heel'): 7,
#          ('toe', 'box'): 7,
#          ('stepin', 'comfort'): 7,
#          ('midsole', 'cushioning'): 6,
#          ('approximately', 'arch'): 6,
#          ('sole', 'platform'): 6,
#          ('engineered', 'mesh'): 6,
#          ('provides', 'excellent'): 6,
#          ('made', 'usa'): 6,
#          ('usa', 'imported'): 6,
#          ('upper', 'textile'): 6,
#          ('tongue', 'collar'): 6,
#          ('materials', 'fine'): 6,
#          ('fine', 'workmanship'): 6,
#          ('workmanship', 'durable'): 6,
#          ('durable', 'silk'): 6,
#          ('silk', 'blends'): 6,
#          ('blends', 'leather'): 6,
#          ('leather', 'shoelace'): 6,
#          ('shoelace', 'design'): 6,
#          ('design', 'get'): 6,
#          ('rid', 'troubles'): 6,
#          ('troubles', 'shoelace'): 6,
#          ('shoelace', 'vamp'): 6,
#          ('vamp', 'cute'): 6,
#          ('cute', 'delicate'): 6,
#          ('delicate', 'bow'): 6,
#          ('bow', 'adds'): 6,
#          ('adds', 'sense'): 6,
#          ('sense', 'wear'): 6,
#          ('wear', 'comfortable'): 6,
#          ('comfortable', 'wear'): 6,
#          ('wear', 'flat'): 6,
#          ('flat', 'heel'): 6,
#          ('heel', 'makes'): 6,
#          ('makes', 'feel'): 6,
#          ('feel', 'stable'): 6,
#          ('stable', 'comfortable'): 6,
#          ('comfortable', 'walk'): 6,
#          ('walk', 'tired'): 6,
#          ('tired', 'put'): 6,
#          ('put', 'pressure'): 6,
#          ('pressure', 'weightthere'): 6,
#          ('weightthere', 'almost'): 6,
#          ('almost', 'noise'): 6,
#          ('noise', 'shoes'): 6,
#          ('shoes', 'nt'): 6,
#          ('nt', 'worry'): 6,
#          ('worry', 'disturbing'): 6,
#          ('disturbing', 'family'): 6,
#          ('family', 'colleagues'): 6,
#          ('colleagues', 'giving'): 6,
#          ('giving', 'quiet'): 6,
#          ('quiet', 'variety'): 6,
#          ('variety', 'occasions'): 6,
#          ('occasions', 'lightweight'): 6,
#          ('flexible', 'nonslip'): 6,
#          ('nonslip', 'durable'): 6,
#          ('durable', 'take'): 6,
#          ('take', 'care'): 6,
#          ('care', 'feetsuitable'): 6,
#          ('feetsuitable', 'daily'): 6,
#          ('daily', 'use'): 6,
#          ('use', 'apartments'): 6,
#          ('apartments', 'bedrooms'): 6,
#          ('bedrooms', 'offices'): 6,
#          ('offices', 'outdoor'): 6,
#          ('outdoor', 'areas'): 6,
#          ('areas', 'etclet'): 6,
#          ('etclet', 'feet'): 6,
#          ('feet', 'get'): 6,
#          ('rid', 'shackles'): 6,
#          ('shackles', 'high'): 6,
#          ('heels', 'relaxsince'): 6,
#          ('relaxsince', 'shoes'): 6,
#          ('shoes', 'foldable'): 6,
#          ('foldable', 'carry'): 6,
#          ('carry', 'used'): 6,
#          ('used', 'gift'): 6,
#          ('gift', 'christmas'): 6,
#          ('christmas', 'holidays'): 6,
#          ('holidays', 'shoe'): 6,
#          ('shoe', 'suitable'): 6,
#          ('suitable', 'women'): 6,
#          ('women', 'age'): 6,
#          ('age', 'styleyou'): 6,
#          ('styleyou', 'give'): 6,
#          ('give', 'gifts'): 6,
#          ('gifts', 'family'): 6,
#          ('family', 'friends'): 6,
#          ('friends', 'festivalevery'): 6,
#          ('festivalevery', 'girl'): 6,
#          ('girl', 'good'): 6,
#          ('good', 'pair'): 6,
#          ('shoes', 'take'): 6,
#          ('take', 'want'): 6,
#          ('want', 'variety'): 6,
#          ('variety', 'colors'): 6,
#          ('colors', 'choose'): 6,
#          ('choose', 'easy'): 6,
#          ('care', 'shoes'): 6,
#          ('shoes', 'available'): 6,
#          ('available', 'four'): 6,
#          ('four', 'colors'): 6,
#          ('colors', 'pink'): 6,
#          ('pink', 'black'): 6,
#          ('black', 'light'): 6,
#          ('light', 'yellow'): 6,
#          ('yellow', 'leopard'): 6,
#          ('leopard', 'suitable'): 6,
#          ('suitable', 'seasonmaintenance'): 6,
#          ('seasonmaintenance', 'easy'): 6,
#          ('easy', 'machine'): 6,
#          ('washable', 'stains'): 6,
#          ('stains', 'easy'): 6,
#          ('easy', 'remove'): 6,
#          ('remove', 'away'): 6,
#          ('away', 'heat'): 6,
#          ('lace', 'closure'): 6,
#          ('insole', 'breathable'): 6,
#          ('foam', 'footbed'): 6,
#          ('fabric', 'textile'): 6,
#          ('midsole', 'outsole'): 6,
#          ('textile', 'upper'): 6,
#          ('faux', 'leather'): 6,
#          ('ultra', 'go'): 6,
#          ('footbed', 'smooth'): 6,
#          ('lining', 'durable'): 6,
#          ('premium', 'leather'): 6,
#          ('beibestcoat', 'please'): 6,
#          ('please', 'refer'): 6,
#          ('refer', 'left'): 6,
#          ('left', 'size'): 6,
#          ('size', 'table'): 6,
#          ('table', 'select'): 6,
#          ('select', 'corresponding'): 6,
#          ('corresponding', 'size'): 6,
#          ('size', 'according'): 6,
#          ('according', 'feet'): 6,
#          ('feet', 'length'): 6,
#          ('length', 'wide'): 6,
#          ('wide', 'thick'): 6,
#          ('thick', 'feet'): 6,
#          ('feet', 'please'): 6,
#          ('please', 'choose'): 6,
#          ('choose', 'larger'): 6,
#          ('larger', 'size'): 6,
#          ('size', 'shoes'): 6,
#          ('made', 'environmentally'): 6,
#          ('environmentally', 'friendly'): 6,
#          ('friendly', 'materials'): 6,
#          ('materials', 'please'): 6,
#          ('please', 'feel'): 6,
#          ('feel', 'rest'): 6,
#          ('rest', 'assured'): 6,
#          ('assured', 'wearing'): 6,
#          ('wearing', 'normal'): 6,
#          ('normal', 'new'): 6,
#          ('new', 'leather'): 6,
#          ('leather', 'shoes'): 6,
#          ('shoes', 'little'): 6,
#          ('little', 'pungent'): 6,
#          ('pungent', 'smell'): 6,
#          ('smell', 'smell'): 6,
#          ('smell', 'disappear'): 6,
#          ('disappear', 'naturally'): 6,
#          ('naturally', 'one'): 6,
#          ('one', 'two'): 6,
#          ('two', 'days'): 6,
#          ('days', 'ventilation'): 6,
#          ('ventilation', 'beibestcoat'): 6,
#          ('beibestcoat', 'split'): 6,
#          ('sole', 'design'): 6,
#          ('design', 'provide'): 6,
#          ('provide', 'ultimate'): 6,
#          ('ultimate', 'flexibility'): 6,
#          ('flexibility', 'point'): 6,
#          ('point', 'full'): 6,
#          ('full', 'toe'): 6,
#          ('box', 'heel'): 6,
#          ('counter', 'provide'): 6,
#          ('provide', 'additional'): 6,
#          ('support', 'beibestcoat'): 6,
#          ('beibestcoat', 'extra'): 6,
#          ('extra', 'steel'): 6,
#          ('steel', 'plate'): 6,
#          ('plate', 'insole'): 6,
#          ('insole', 'outsole'): 6,
#          ('outsole', 'ensure'): 6,
#          ('ensure', 'tap'): 6,
#          ('tap', 'security'): 6,
#          ('security', 'sleek'): 6,
#          ('sleek', 'outlook'): 6,
#          ('outlook', 'appropriate'): 6,
#          ('appropriate', 'modern'): 6,
#          ('modern', 'life'): 6,
#          ('life', 'enjoy'): 6,
#          ('enjoy', 'attitude'): 6,
#          ('attitude', 'beibestcoat'): 6,
#          ('beibestcoat', 'made'): 6,
#          ('made', 'synthetic'): 6,
#          ('outsole', 'taps'): 6,
#          ('taps', 'proper'): 6,
#          ('proper', 'mounting'): 6,
#          ('mounting', 'great'): 6,
#          ('great', 'sound'): 6,
#          ('sound', 'beibestcoat'): 6,
#          ('beibestcoat', 'maximum'): 6,
#          ('maximum', 'order'): 6,
#          ('order', 'quantity'): 6,
#          ('quantity', 'pair'): 6,
#          ('pair', 'need'): 6,
#          ('need', 'please'): 6,
#          ('please', 'place'): 6,
#          ('place', 'another'): 6,
#          ('another', 'order'): 6,
#          ('insole', 'maximum'): 6,
#          ('inches', 'ortholite'): 6,
#          ('leather', 'upper'): 5,
#          ('sole', 'lightweight'): 5,
#          ('running', 'shoes'): 5,
#          ('weight', 'ounces'): 5,
#          ('ounces', 'size'): 5,
#          ('size', 'midsole'): 5,
#          ('midsole', 'drop'): 5,
#          ('drop', 'mm'): 5,
#          ('mm', 'heel'): 5,
#          ('heel', 'mm'): 5,
#          ('mm', 'forefoot'): 5,
#          ('forefoot', 'mm'): 5,
#          ('mesh', 'imported'): 5,
#          ('regular', 'fit'): 5,
#          ('fit', 'lace'): 5,
#          ('cushioning', 'system'): 5,
#          ('rebound', 'insole'): 5,
#          ('height', 'approximately'): 5,
#          ('cushioned', 'midsole'): 5,
#          ('outsole', 'leather'): 5,
#          ('padded', 'tongue'): 5,
#          ('comfort', 'insole'): 5,
#          ('arch', 'slipon'): 5,
#          ('slipon', 'providing'): 5,
#          ('providing', 'easy'): 5,
#          ('runtrain', 'performance'): 5,
#          ('performance', 'sneaker'): 5,
#          ('ball', 'foot'): 5,
#          ('cushioned', 'insole'): 5,
#          ('foam', 'padded'): 5,
#          ('inch', 'heel'): 5,
#          ('energizes', 'every'): 5,
#          ('arch', 'flexible'): 5,
#          ('removable', 'sockliner'): 5,
#          ('sole', 'textile'): 5,
#          ('go', 'cushioning'): 5,
#          ('flywire', 'cables'): 5,
#          ('comfort', 'extra'): 5,
#          ('extra', 'support'): 5,
#          ('support', 'toe'): 5,
#          ('toe', 'highrecovery'): 5,
#          ('highrecovery', 'foam'): 5,
#          ('foam', 'ball'): 5,
#          ('dense', 'foam'): 5,
#          ('foam', 'cradling'): 5,
#          ('cradling', 'heel'): 5,
#          ('inches', 'inches'): 5,
#          ('breathable', 'knit'): 5,
#          ('superior', 'cushioning'): 5,
#          ('flexible', 'outsole'): 5,
#          ('heel', 'leather'): 5,
#          ('stacked', 'heel'): 5,
#          ('technology', 'ortholite'): 5,
#          ('soft', 'comfort'): 5,
#          ('relaxed', 'fit'): 5,
#          ('size', 'chart'): 5,
#          ('lining', 'leather'): 5,
#          ('large', 'us'): 5,
#          ('leather', 'uppers'): 5,
#          ('energy', 'return'): 4,
#          ('full', 'grain'): 4,
#          ('grain', 'leather'): 4,
#          ('fashion', 'sneaker'): 4,
#          ('sneaker', 'featuring'): 4,
#          ('rubber', 'cupsole'): 4,
#          ('traction', 'durability'): 4,
#          ('neutral', 'runners'): 4,
#          ('runners', 'need'): 4,
#          ('flexibility', 'cushioning'): 4,
#          ('removable', 'comfort'): 4,
#          ('comfort', 'lightweight'): 4,
#          ('sole', 'charitable'): 4,
#          ('heat', 'textile'): 4,
#          ('aircooled', 'memory'): 4,
#          ('suede', 'upper'): 4,
#          ('enjoy', 'comfort'): 4,
#          ('comfort', 'performance'): 4,
#          ('performance', 'ortholite'): 4,
#          ('approximately', 'midtop'): 4,
#          ('hillo', 'heel'): 4,
#          ('heel', 'cushions'): 4,
#          ('cushions', 'designed'): 4,
#          ('designed', 'reduce'): 4,
#          ('reduce', 'slip'): 4,
#          ('slip', 'improve'): 4,
#          ('improve', 'fit'): 4,
#          ('fit', 'flexible'): 4,
#          ('round', 'toe'): 4,
#          ('na', 'imported'): 4,
#          ('arch', 'rearfoot'): 4,
#          ('rearfoot', 'gel'): 4,
#          ('system', 'attenuates'): 4,
#          ('attenuates', 'shock'): 4,
#          ('shock', 'impact'): 4,
#          ('impact', 'phase'): 4,
#          ('phase', 'allows'): 4,
#          ('allows', 'smooth'): 4,
#          ('smooth', 'transition'): 4,
#          ('transition', 'midstance'): 4,
#          ('feet', 'wide'): 4,
#          ('wide', 'suggest'): 4,
#          ('suggest', 'foot'): 4,
#          ('foot', 'choose'): 4,
#          ('choose', 'bigger'): 4,
#          ('bigger', 'size'): 4,
#          ('foam', 'cushioned'): 4,
#          ('upper', 'provides'): 4,
#          ('skechers', 'performance'): 4,
#          ('performance', 'fitknit'): 4,
#          ('fabric', 'upper'): 4,
#          ('fit', 'design'): 4,
#          ('goga', 'pillars'): 4,
#          ('offer', 'flexibility'): 4,
#          ('sole', 'radically'): 4,
#          ('arch', 'support'): 4,
#          ('innovative', 'highly'): 4,
#          ('highly', 'responsive'): 4,
#          ('responsive', 'midsole'): 4,
#          ('step', 'soft'): 4,
#          ('soft', 'mesh'): 4,
#          ('seamless', 'construction'): 4,
#          ('flexible', 'responsive'): 4,
#          ('added', 'comfort'): 4,
#          ('arch', 'textile'): 4,
#          ('sockliner', 'sockliner'): 4,
#          ('sockliner', 'removed'): 4,
#          ('removed', 'accommodate'): 4,
#          ('accommodate', 'medical'): 4,
#          ('medical', 'orthotic'): 4,
#          ('rubber', 'traction'): 4,
#          ('shock', 'absorption'): 4,
#          ('responsive', 'ultra'): 4,
#          ('upper', 'featuring'): 4,
#          ('midsole', 'foam'): 4,
#          ('comfort', 'insert'): 4,
#          ('removable', 'insert'): 4,
#          ('light', 'weight'): 4,
#          ('women', 'running'): 4,
#          ('lightweight', 'cushioning'): 4,
#          ('removable', 'ortholite'): 4,
#          ('ortholite', 'molded'): 4,
#          ('molded', 'footbed'): 4,
#          ('tpr', 'outsole'): 4,
#          ('upper', 'delivers'): 4,
#          ('leather', 'textile'): 4,
#          ('optimal', 'durability'): 4,
#          ('inches', 'clarks'): 4,
#          ('durable', 'rubber'): 4,
#          ('padded', 'footbed'): 4,
#          ('cloudfoam', 'midsole'): 4,
#          ('comfort', 'superior'): 4,
#          ('lightweight', 'eva'): 4,
#          ('eva', 'outsole'): 4,
#          ('lifestride', 'soft'): 4,
#          ('soft', 'system'): 4,
#          ('traction', 'outsole'): 4,
#          ('clarks', 'cushion'): 4,
#          ('available', 'medium'): 4,
#          ('medium', 'wide'): 4,
#          ('slip', 'resistant'): 4,
#          ('technology', 'flexible'): 4,
#          ('flexible', 'rubber'): 4,
#          ('support', 'comfort'): 4,
#          ('comfort', 'soft'): 4,
#          ('wide', 'feet'): 4,
#          ('air', 'dry'): 4,
#          ('features', 'sam'): 4,
#          ('sam', 'edelman'): 4,
#          ('edelman', 'design'): 4,
#          ('design', 'x'): 4,
#          ('x', 'technology'): 4,
#          ('technology', 'millimeter'): 4,
#          ('millimeter', 'cushioning'): 4,
#          ('cushioning', 'technology'): 4,
#          ('technology', 'skechers'): 4,
#          ('insole', 'soft'): 4,
#          ('synthetic', 'leather'): 4,
#          ('stretch', 'gore'): 4,
#          ('imported', 'na'): 3,
#          ('na', 'rubber'): 3,
#          ('removable', 'insole'): 3,
#          ('water', 'resistant'): 3,
#          ('cloud', 'foam'): 3,
#          ('laceup', 'closure'): 3,
#          ('hexagonal', 'flex'): 3,
#          ('performance', 'textile'): 3,
#          ('arch', 'neutral'): 3,
#          ('need', 'flexibility'): 3,
#          ('cushioning', 'versatility'): 3,
#          ('molded', 'foam'): 3,
#          ('sockliner', 'provides'): 3,
#          ('syntheticmesh', 'upper'): 3,
#          ('womensspecific', 'fit'): 3,
#          ('upper', 'breathability'): 3,
#          ('bounce', 'cushioning'): 3,
#          ('cushioning', 'provides'): 3,
#          ('provides', 'enhanced'): 3,
#          ('enhanced', 'comfort'): 3,
#          ('comfort', 'flexibility'): 3,
#          ('foam', 'flexible'): 3,
#          ('offers', 'stable'): 3,
#          ('fit', 'leather'): 3,
#          ('comfort', 'hillo'): 3,
#          ('sole', 'round'): 3,
#          ('size', 'suede'): 3,
#          ('lacing', 'system'): 3,
#          ('fit', 'textile'): 3,
#          ('heel', 'pull'): 3,
#          ('cushioned', 'comfort'): 3,
#          ('shock', 'absorbing'): 3,
#          ('easy', 'wear'): 3,
#          ('wear', 'ability'): 3,
#          ('midtop', 'arch'): 3,
#          ('comfort', 'foam'): 3,
#          ('padded', 'insole'): 3,
#          ('technology', 'heel'): 3,
#          ('superior', 'comfort'): 3,
#          ('look', 'feel'): 3,
#          ('arch', 'type'): 3,
#          ('type', 'normal'): 3,
#          ('casual', 'slipon'): 3,
#          ('insole', 'leather'): 3,
#          ('upper', 'memory'): 3,
#          ('memory', 'form'): 3,
#          ('form', 'fit'): 3,
#          ('foam', 'padding'): 3,
#          ('stabilizing', 'heel'): 3,
#          ('women', 'size'): 3,
#          ('cushioning', 'new'): 3,
#          ('new', 'goga'): 3,
#          ('rebound', 'footbed'): 3,
#          ('footbed', 'energizes'): 3,
#          ('upper', 'virtually'): 3,
#          ('virtually', 'seamless'): 3,
#          ('construction', 'comfortable'): 3,
#          ('fit', 'bamboo'): 3,
#          ('bamboo', 'lined'): 3,
#          ('lined', 'foot'): 3,
#          ('bed', 'antibacterial'): 3,
#          ('antibacterial', 'odor'): 3,
#          ('odor', 'control'): 3,
#          ('padded', 'collar'): 3,
#          ('lining', 'material'): 3,
#          ('nonmarking', 'outsole'): 3,
#          ('lightweight', 'innovative'): 3,
#          ('toe', 'cap'): 3,
#          ('lining', 'comfort'): 3,
#          ('wedge', 'synthetic'): 3,
#          ('gel', 'cushioning'): 3,
#          ('midstance', 'removable'): 3,
#          ('designed', 'allday'): 3,
#          ('gore', 'panels'): 3,
#          ('pull', 'tab'): 3,
#          ('sole', 'fashion'): 3,
#          ('comfortable', 'textile'): 3,
#          ('vulcanized', 'rubber'): 3,
#          ('sock', 'liner'): 3,
#          ('knit', 'fabric'): 3,
#          ('nb', 'memory'): 3,
#          ('memory', 'sole'): 3,
#          ('sole', 'comfort'): 3,
#          ('cables', 'integrate'): 3,
#          ('integrate', 'laces'): 3,
#          ('foot', 'move'): 3,
#          ('move', 'naturally'): 3,
#          ('heel', 'memory'): 3,
#          ('leather', 'rubber'): 3,
#          ('durable', 'tpr'): 3,
#          ('sole', 'breathable'): 3,
#          ('arch', 'eva'): 3,
#          ('heel', 'flexible'): 3,
#          ('foam', 'foot'): 3,
#          ('outsole', 'premium'): 3,
#          ('order', 'synthetic'): 3,
#          ('foot', 'dense'): 3,
#          ('adiwear', 'outsole'): 3,
#          ('outsole', 'offers'): 3,
#          ('offers', 'ultimate'): 3,
#          ('ultimate', 'highwear'): 3,
#          ('highwear', 'durability'): 3,
#          ('provides', 'comfortable'): 3,
#          ('system', 'flexible'): 3,
#          ('genuine', 'leather'): 3,
#          ('highrebound', 'ultra'): 3,
#          ('ultra', 'pillars'): 3,
#          ('pillars', 'energize'): 3,
#          ('energize', 'every'): 3,
#          ('imported', 'fabric'): 3,
#          ('fabric', 'sole'): 3,
#          ('technology', 'ultralightweight'): 3,
#          ('outsole', 'fabric'): 3,
#          ('foam', 'cushioning'): 3,
#          ('insole', 'heel'): 3,
#          ('heel', 'comfort'): 3,
#          ('synthetic', 'overlays'): 3,
#          ('outsole', 'textile'): 3,
#          ('walking', 'shoe'): 3,
#          ('shoes', 'offer'): 3,
#          ('back', 'heel'): 3,
#          ('wide', 'widths'): 3,
#          ('arch', 'light'): 3,
#          ('weight', 'flexible'): 3,
#          ('slipon', 'sneaker'): 3,
#          ('height', 'clarks'): 3,
#          ('comfort', 'ortholite'): 3,
#          ('comfort', 'cloudfoam'): 3,
#          ('molds', 'foot'): 3,
#          ('foot', 'superior'): 3,
#          ('superior', 'stepin'): 3,
#          ('cushioning', 'rubber'): 3,
#          ('bottom', 'sole'): 3,
#          ('high', 'heel'): 3,
#          ('sole', 'classic'): 3,
#          ('ballet', 'flat'): 3,
#          ('flexible', 'tpr'): 3,
#          ('outsole', 'heel'): 3,
#          ('size', 'small'): 3,
#          ('small', 'us'): 3,
#          ('us', 'medium'): 3,
#          ('medium', 'us'): 3,
#          ('us', 'large'): 3,
#          ('us', 'extra'): 3,
#          ('extra', 'large'): 3,
#          ('slipper', 'narrow'): 3,
#          ('narrow', 'width'): 3,
#          ('width', 'wide'): 3,
#          ('feet', 'recommend'): 3,
#          ('recommend', 'buying'): 3,
#          ('buying', 'size'): 3,
#          ('foam', 'cushion'): 3,
#          ('anti', 'slip'): 3,
#          ('slip', 'sole'): 3,
#          ('sole', 'textured'): 3,
#          ('textured', 'bottom'): 3,
#          ('grips', 'floor'): 3,
#          ('care', 'hand'): 3,
#          ('hand', 'wash'): 3,
#          ('wash', 'cold'): 3,
#          ('cold', 'water'): 3,
#          ('dry', 'dry'): 3,
#          ('dry', 'flat'): 3,
#          ('leather', 'suede'): 3,
#          ('canvas', 'upper'): 3,
#          ('outsole', 'toe'): 3,
#          ('max', 'highrebound'): 3,
#          ('highrebound', 'insole'): 3,
#          ('arch', 'runtrain'): 3,
#          ('leather', 'lining'): 3,
#          ('insole', 'durable'): 3,
#          ('cotton', 'laces'): 3,
#          ('arch', 'ortholite'): 3,
#          ('arch', 'cushion'): 3,
#          ('durable', 'composition'): 3,
#          ('composition', 'rubber'): 3,
#          ('excellent', 'grip'): 3,
#          ('clarks', 'cloudsteppers'): 3,
#          ('cloudsteppers', 'removable'): 3,
#          ('full', 'length'): 3,
#          ('fit', 'memory'): 3,
#          ('jersey', 'lining'): 3,
#          ('mesh', 'lining'): 2,
#          ('sole', 'flexible'): 2,
#          ('insole', 'provides'): 2,
#          ('provides', 'ultralight'): 2,
#          ('ultralight', 'cushioning'): 2,
#          ('outsole', 'adiwear'): 2,
#          ('abrasion', 'resistance'): 2,
#          ('fit', 'feel'): 2,
#          ('low', 'profile'): 2,
#          ('approximately', 'laceup'): 2,
#          ('strategicallyplaced', 'rubber'): 2,
#          ('promote', 'natural'): 2,
#          ('footbed', 'satin'): 2,
#          ('versatility', 'engineered'): 2,
#          ('upper', 'extremely'): 2,
#          ('extremely', 'lightweight'): 2,
#          ('breathable', 'strategic'): 2,
#          ('strategic', 'support'): 2,
#          ('support', 'need'): 2,
#          ('need', 'lightweight'): 2,
#          ('lightweight', 'external'): 2,
#          ('external', 'heel'): 2,
#          ('counter', 'additional'): 2,
#          ('support', 'keeps'): 2,
#          ('keeps', 'back'): 2,
#          ('back', 'foot'): 2,
#          ('foot', 'locked'): 2,
#          ('locked', 'place'): 2,
#          ('place', 'charged'): 2,
#          ('charged', 'cushioning'): 2,
#          ('cushioning', 'midsole'): 2,
#          ('midsole', 'uses'): 2,
#          ('uses', 'compression'): 2,
#          ('compression', 'molded'): 2,
#          ('foam', 'even'): 2,
#          ('even', 'greater'): 2,
#          ('greater', 'responsiveness'): 2,
#          ('responsiveness', 'durability'): 2,
#          ('durability', 'providing'): 2,
#          ('providing', 'optimal'): 2,
#          ('optimal', 'cushioning'): 2,
#          ('cushioning', 'energy'): 2,
#          ('return', 'removable'): 2,
#          ('comfort', 'sockliner'): 2,
#          ('provides', 'textile'): 2,
#          ('bootie', 'construction'): 2,
#          ('nb', 'response'): 2,
#          ('response', 'performance'): 2,
#          ('performance', 'insert'): 2,
#          ('easy', 'clean'): 2,
#          ('secure', 'fit'): 2,
#          ('crocs', 'comfort'): 2,
#          ('rounded', 'toe'): 2,
#          ('lightweight', 'running'): 2,
#          ('comfort', 'womensspecific'): 2,
#          ('stretch', 'mesh'): 2,
#          ('comfort', 'wide'): 2,
#          ('excellent', 'traction'): 2,
#          ('arch', 'leather'): 2,
#          ('padded', 'sock'): 2,
#          ('suedemesh', 'upper'): 2,
#          ('charitable', 'imported'): 2,
#          ('molded', 'eva'): 2,
#          ('upper', 'helps'): 2,
#          ('imported', 'shaft'): 2,
#          ('detail', 'side'): 2,
#          ('side', 'lace'): 2,
#          ('mary', 'jane'): 2,
#          ('arch', 'regular'): 2,
#          ('closure', 'suede'): 2,
#          ('lining', 'reinforced'): 2,
#          ('reinforced', 'toe'): 2,
#          ('toe', 'gum'): 2,
#          ('gum', 'rubber'): 2,
#          ('cupsole', 'vulcanized'): 2,
#          ('vulcanized', 'look'): 2,
#          ('look', 'enjoy'): 2,
#          ('ortholite', 'float'): 2,
#          ('float', 'sockliner'): 2,
#          ('foam', 'lightweight'): 2,
#          ('resistant', 'textile'): 2,
#          ('system', 'technology'): 2,
#          ('fluidfit', 'upper'): 2,
#          ('comfort', 'providing'): 2,
#          ('enhanced', 'cushioning'): 2,
#          ('pu', 'leather'): 2,
#          ('leather', 'feet'): 2,
#          ('suede', 'heel'): 2,
#          ('inches', 'nonslip'): 2,
#          ('balance', 'extremely'): 2,
#          ('situable', 'amateur'): 2,
#          ('amateur', 'professionals'): 2,
#          ('professionals', 'latin'): 2,
#          ('performance', 'quality'): 2,
#          ('quality', 'guaranteed'): 2,
#          ('guaranteed', 'great'): 2,
#          ('great', 'service'): 2,
#          ('service', 'questions'): 2,
#          ('questions', 'please'): 2,
#          ('please', 'hesitate'): 2,
#          ('hesitate', 'contact'): 2,
#          ('us', 'time'): 2,
#          ('performance', 'synthetic'): 2,
#          ('synthetic', 'fabric'): 2,
#          ('lightweight', 'resalyte'): 2,
#          ('resalyte', 'cushioning'): 2,
#          ('cushioning', 'w'): 2,
#          ('w', 'stands'): 2,
#          ('stands', 'women'): 2,
#          ('soft', 'synthetic'): 2,
#          ('cushioned', 'outsole'): 2,
#          ('rawhide', 'laces'): 2,
#          ('laceup', 'sneaker'): 2,
#          ('fabric', 'shoe'): 2,
#          ('ability', 'available'): 2,
#          ('available', 'multiple'): 2,
#          ('multiple', 'colorways'): 2,
#          ('colorways', 'materials'): 2,
#          ('strong', 'girl'): 2,
#          ('arch', 'style'): 2,
#          ('comfort', 'quality'): 2,
#          ('quality', 'comfort'): 2,
#          ('footbed', 'sumptuous'): 2,
#          ('sumptuous', 'padded'): 2,
#          ('insole', 'soothe'): 2,
#          ('soothe', 'pamper'): 2,
#          ('pamper', 'feet'): 2,
#          ('feet', 'built'): 2,
#          ('built', 'leather'): 2,
#          ('synthetic', 'material'): 2,
#          ('material', 'provide'): 2,
#          ('provide', 'exceptional'): 2,
#          ('exceptional', 'comfort'): 2,
#          ('comfort', 'detail'): 2,
#          ('detail', 'strong'): 2,
#          ('strong', 'durable'): 2,
#          ('durable', 'manufactured'): 2,
#          ('manufactured', 'high'): 2,
#          ('materials', 'stitched'): 2,
#          ('stitched', 'precision'): 2,
#          ('precision', 'allowing'): 2,
#          ('allowing', 'strong'): 2,
#          ('strong', 'robust'): 2,
#          ('robust', 'inseams'): 2,
#          ('inseams', 'sturdy'): 2,
#          ('sturdy', 'resilient'): 2,
#          ('resilient', 'soles'): 2,
#          ('soles', 'advanced'): 2,
#          ('advanced', 'technology'): 2,
#          ('heel', 'rest'): 2,
#          ('rest', 'design'): 2,
#          ('design', 'patent'): 2,
#          ('patent', 'pending'): 2,
#          ('pending', 'technology'): 2,
#          ('technology', 'found'): 2,
#          ('found', 'aerosoles'): 2,
#          ('aerosoles', 'custom'): 2,
#          ('custom', 'design'): 2,
#          ('design', 'distributes'): 2,
#          ('distributes', 'body'): 2,
#          ('body', 'weight'): 2,
#          ('weight', 'toward'): 2,
#          ('toward', 'heel'): 2,
#          ('heel', 'away'): 2,
#          ('away', 'ball'): 2,
#          ('foot', 'result'): 2,
#          ('result', 'superior'): 2,
#          ('comfort', 'high'): 2,
#          ('heels', 'wedges'): 2,
#          ('wedges', 'look'): 2,
#          ('great', 'satisfaction'): 2,
#          ('satisfaction', 'guarantee'): 2,
#          ('guarantee', 'return'): 2,
#          ('return', 'item'): 2,
#          ('item', 'reason'): 2,
#          ('reason', 'get'): 2,
#          ('get', 'full'): 2,
#          ('full', 'refund'): 2,
#          ('refund', 'shipping'): 2,
#          ('shipping', 'charges'): 2,
#          ('charges', 'item'): 2,
#          ('item', 'must'): 2,
#          ('must', 'returned'): 2,
#          ('returned', 'new'): 2,
#          ('new', 'unused'): 2,
#          ('unused', 'condition'): 2,
#          ('mm', 'recommended'): 2,
#          ('return', 'energy'): 2,
#          ('arch', 'casual'): 2,
#          ('upper', 'antimicrobial'): 2,
#          ('antimicrobial', 'cushioned'): 2,
#          ('insole', 'custom'): 2,
#          ('custom', 'toms'): 2,
#          ('toms', 'molded'): 2,
#          ('molded', 'rubber'): 2,
#          ('mess', 'fabricsynthetic'): 2,
#          ('fabricsynthetic', 'imported'): 2,
#          ('sole', 'skechers'): 2,
#          ('fitknit', 'structured'): 2,
#          ('structured', 'breathable'): 2,
#          ('mesh', 'cooling'): 2,
#          ('cooling', 'comfort'): 2,
#          ('lightweight', 'skechers'): 2,
#          ('fitknit', 'mesh'): 2,
#          ('design', 'memory'): 2,
#          ('padding', 'around'): 2,
#          ('around', 'heel'): 2,
#          ('heel', 'customfeel'): 2,
#          ('customfeel', 'fit'): 2,
#          ('fit', 'fabric'): 2,
#          ('fabric', 'edging'): 2,
#          ('edging', 'trim'): 2,
#          ('trim', 'synthetic'): 2,
#          ('synthetic', 'stabilizing'): 2,
#          ('heel', 'panel'): 2,
#          ('panel', 'side'): 2,
#          ('side', 'logo'): 2,
#          ('logo', 'independent'): 2,
#          ('independent', 'goimpulse'): 2,
#          ('goimpulse', 'integrated'): 2,
#          ('integrated', 'goga'): 2,
#          ('pillars', 'sensors'): 2,
#          ('sensors', 'offer'): 2,
#          ('flexibility', 'feedback'): 2,
#          ('feedback', 'responsive'): 2,
#          ('responsive', 'walking'): 2,
#          ('walking', 'experience'): 2,
#          ('experience', 'ever'): 2,
#          ('ever', 'memory'): 2,
#          ('padded', 'heel'): 2,
#          ('heel', 'cup'): 2,
#          ('cup', 'stayput'): 2,
#          ('stayput', 'fit'): 2,
#          ('fit', 'walking'): 2,
#          ('walking', 'comfort'): 2,
#          ('comfort', 'goga'): 2,
#          ('pillars', 'technology'): 2,
#          ('technology', 'midsole'): 2,
#          ('outsole', 'goga'): 2,
#          ('mat', 'technology'): 2,
#          ('technology', 'weight'): 2,
#          ('weight', 'radically'): 2,
#          ('lightweight', 'oz'): 2,
#          ('oz', 'women'): 2,
#          ('heel', 'fabric'): 2,
#          ('heel', 'easy'): 2,
#          ('easy', 'pull'): 2,
#          ('comfort', 'textile'): 2,
#          ('upper', 'laceup'): 2,
#          ('sole', 'nonmarking'): 2,
#          ('support', 'durability'): 2,
#          ('durability', 'textile'): 2,
#          ('arch', 'fashion'): 2,
#          ('fashion', 'lifestyle'): 2,
#          ('lifestyle', 'sneaker'): 2,
#          ('ahar', 'outsole'): 2,
#          ('outsole', 'acronym'): 2,
#          ('acronym', 'asics'): 2,
#          ('asics', 'high'): 2,
#          ('high', 'abrasion'): 2,
#          ('abrasion', 'rubber'): 2,
#          ('rubber', 'placed'): 2,
#          ('placed', 'critical'): 2,
#          ('critical', 'areas'): 2,
#          ('areas', 'outsole'): 2,
#          ('outsole', 'exceptional'): 2,
#          ('exceptional', 'durability'): 2,
#          ('durability', 'leather'): 2,
#          ('eva', 'foam'): 2,
#          ('gel', 'cushion'): 2,
#          ('comfort', 'rubber'): 2,
#          ('traction', 'sole'): 2,
#          ('leather', 'mesh'): 2,
#          ('arch', 'energized'): 2,
#          ('energized', 'insole'): 2,
#          ('insole', 'allday'): 2,
#          ('comfort', 'cushioning'): 2,
#          ('cushioning', 'shock'): 2,
#          ('absorption', 'reduces'): 2,
#          ('reduces', 'foot'): 2,
#          ('foot', 'pressure'): 2,
#          ('pressure', 'fatigue'): 2,
#          ('twin', 'gore'): 2,
#          ('extra', 'flexibility'): 2,
#          ('laceup', 'front'): 2,
#          ('sole', 'synthetic'): 2,
#          ('insole', 'energizes'): 2,
#          ('sneaker', 'suede'): 2,
#          ('featuring', 'contrastcolor'): 2,
#          ('contrastcolor', 'threestripes'): 2,
#          ('threestripes', 'branding'): 2,
#          ('branding', 'lacefront'): 2,
#          ('lacefront', 'closure'): 2,
#          ('closure', 'comfortable'): 2,
#          ('lining', 'vulcanized'): 2,
#          ('arch', 'revlite'): 2,
#          ('revlite', 'midsole'): 2,
#          ('foam', 'nb'): 2,
#          ('insert', 'removable'): 2,
#          ('insert', 'slip'): 2,
#          ('slip', 'upper'): 2,
#          ('upper', 'additional'): 2,
#          ('additional', 'lace'): 2,
#          ('lace', 'support'): 2,
#          ('original', 'packaging'): 2,
#          ('provides', 'lightweight'): 2,
#          ('ball', 'foo'): 2,
#          ('foo', 'dense'): 2,
#          ('inches', 'covered'): 2,
#          ('covered', 'heel'): 2,
#          ('fabric', 'manmade'): 2,
#          ('classic', 'look'): 2,
#          ('true', 'size'): 2,
#          ('upper', 'smooth'): 2,
#          ('soft', 'knit'): 2,
#          ('natural', 'flexibility'): 2,
#          ('women', 'shoes'): 2,
#          ('women', 'nike'): 2,
#          ('nike', 'shoes'): 2,
#          ('shoes', 'women'): 2,
#          ('shoe', 'heel'): 2,
#          ('comfort', 'system'): 2,
#          ('upper', 'durability'): 2,
#          ('ortholite', 'sockliner'): 2,
#          ('arch', 'removable'): 2,
#          ('added', 'durability'): 2,
#          ('around', 'ankle'): 2,
#          ('ankle', 'collar'): 2,
#          ('provides', 'cushioning'): 2,
#          ('insole', 'decorative'): 2,
#          ('decorative', 'buckle'): 2,
#          ('buckle', 'detail'): 2,
#          ('detail', 'toe'): 2,
#          ('toe', 'flexible'): 2,
#          ('relax', 'fit'): 2,
#          ('fit', 'rubber'): 2,
#          ('foam', 'leather'): 2,
#          ('delivers', 'optimal'): 2,
#          ('durability', 'flywire'): 2,
#          ('laces', 'dynamic'): 2,
#          ('dynamic', 'fit'): 2,
#          ('fit', 'dropin'): 2,
#          ('dropin', 'midsole'): 2,
#          ('midsole', 'offers'): 2,
#          ('flexible', 'forefoot'): 2,
#          ('thin', 'web'): 2,
#          ('web', 'rubber'): 2,
#          ('rubber', 'stretches'): 2,
#          ('stretches', 'outsole'): 2,
#          ('outsole', 'wrap'): 2,
#          ('wrap', 'midfoot'): 2,
#          ('midfoot', 'optimal'): 2,
#          ('inches', 'stretch'): 2,
#          ('bed', 'textile'): 2,
#          ('footbed', 'durable'): 2,
#          ('pull', 'loop'): 2,
#          ('pointed', 'toe'): 2,
#          ('recommended', 'multisport'): 2,
#          ('multisport', 'training'): 2,
#          ('midsole', 'stepin'): 2,
#          ('arch', 'classic'): 2,
#          ('construction', 'better'): 2,
#          ('socklike', 'fit'): 2,
#          ('outsole', 'lightweight'): 2,
#          ('strategically', 'placed'): 2,
#          ('comfortable', 'leather'): 2,
#          ('soft', 'lining'): 2,
#          ('wedge', 'heel'): 2,
#          ('sole', 'perforated'): 2,
#          ('style', 'breathability'): 2,
#          ('sole', 'flymesh'): 2,
#          ('flymesh', 'upper'): 2,
#          ('upper', 'construction'): 2,
#          ('construction', 'reflectivity'): 2,
#          ('reflectivity', 'heel'): 2,
#          ('heel', 'fitsole'): 2,
#          ('fitsole', 'sockliner'): 2,
#          ('sockliner', 'conforms'): 2,
#          ('conforms', 'shape'): 2,
#          ('shape', 'foot'): 2,
#          ('zoom', 'air'): 2,
#          ('premium', 'cushlon'): 2,
#          ('cushlon', 'st'): 2,
#          ('st', 'foam'): 2,
#          ('foam', 'synthetic'): 2,
#          ('soft', 'breathable'): 2,
#          ('ultralightweight', 'eva'): 2,
#          ('insole', 'designed'): 2,
#          ('zip', 'closure'): 2,
#          ('sole', 'fabric'): 2,
#          ('foam', 'heel'): 2,
#          ('designed', 'stability'): 2,
#          ('stability', 'balance'): 2,
#          ('highly', 'flexible'): 2,
#          ('outsole', 'man'): 2,
#          ('day', 'comfort'): 2,
#          ('cushioning', 'highrebound'): 2,
#          ('step', 'skechers'): 2,
#          ('easy', 'wearability'): 2,
#          ('insole', 'synthetic'): 2,
#          ('heel', 'cushion'): 2,
#          ('upper', 'imported'): 2,
#          ('insert', 'leather'): 2,
#          ('suede', 'leather'): 2,
#          ('inches', 'lifestride'): 2,
#          ('comfort', 'flexible'): 2,
#          ('fabric', 'synthetic'): 2,
#          ('insole', 'nonmarking'): 2,
#          ('bootee', 'construction'): 2,
#          ('construction', 'provides'): 2,
#          ('air', 'unit'): 2,
#          ('unit', 'provides'): 2,
#          ('performance', 'leather'): 2,
#          ('plush', 'foam'): 2,
#          ('imported', 'pieced'): 2,
#          ('pieced', 'dyed'): 2,
#          ('dyed', 'calf'): 2,
#          ('calf', 'fur'): 2,
#          ('fur', 'origin'): 2,
#          ('origin', 'china'): 2,
#          ('china', 'leather'): 2,
#          ('footbed', 'textile'): 2,
#          ('arch', 'runner'): 2,
#          ('runner', 'type'): 2,
#          ('type', 'neutral'): 2,
#          ('neutral', 'shoes'): 2,
#          ('flexibility', 'versatility'): 2,
#          ('versatility', 'premium'): 2,
#          ('premium', 'cushioning'): 2,
#          ('flexibility', 'engineered'): 2,
#          ('providing', 'supportive'): 2,
#          ('supportive', 'comfortable'): 2,
#          ('durability', 'man'): 2,
#          ('workplace', 'standards'): 2,
#          ('standards', 'fit'): 2,
#          ('fit', 'relaxed'): 2,
#          ('enhanced', 'arch'): 2,
#          ('support', 'adds'): 2,
#          ('adds', 'comfort'): 2,
#          ('crocs', 'lock'): 2,
#          ('lock', 'slipresistant'): 2,
#          ('slipresistant', 'tread'): 2,
#          ('astm', 'tested'): 2,
#          ('tested', 'ce'): 2,
#          ('ce', 'certified'): 2,
#          ('hazard', 'memory'): 2,
#          ('arch', 'armour'): 2,
#          ('armour', 'mission'): 2,
#          ('mission', 'make'): 2,
#          ('make', 'athletes'): 2,
#          ('athletes', 'better'): 2,
#          ('better', 'passion'): 2,
#          ('passion', 'design'): 2,
#          ('design', 'relentless'): 2,
#          ('relentless', 'pursuit'): 2,
#          ('pursuit', 'innovation'): 2,
#          ('innovation', 'started'): 2,
#          ('started', 'started'): 2,
#          ('started', 'idea'): 2,
#          ('idea', 'build'): 2,
#          ('build', 'superior'): 2,
#          ('superior', 'tshirt'): 2,
#          ('tshirt', 'armour'): 2,
#          ('armour', 'assortment'): 2,
#          ('assortment', 'men'): 2,
#          ('men', 'women'): 2,
#          ('women', 'youth'): 2,
#          ('youth', 'complex'): 2,
#          ('complex', 'reaping'): 2,
#          ('reaping', 'benefits'): 2,
#          ('benefits', 'simple'): 2,
#          ('simple', 'wear'): 2,
#          ('wear', 'heatgear'): 2,
#          ('heatgear', 'hot'): 2,
#          ('hot', 'coldgear'): 2,
#          ('coldgear', 'cold'): 2,
#          ('cold', 'season'): 2,
#          ('season', 'gear'): 2,
#          ('gear', 'extremes'): 2,
#          ('arch', 'lifestride'): 2,
#          ('lifestride', 'softsystem'): 2,
#          ('sole', 'material'): 2,
#          ('may', 'vary'): 2,
#          ('sole', 'faux'): 2,
#          ('leather', 'material'): 2,
#          ('material', 'high'): 2,
#          ('quality', 'sequin'): 2,
#          ('sequin', 'wearresisting'): 2,
#          ('wearresisting', 'comfortable'): 2,
#          ('comfortable', 'durable'): 2,
#          ('durable', 'wool'): 2,
#          ('wool', 'bottom'): 2,
#          ('indoor', 'good'): 2,
#          ('balance', 'superior'): 2,
#          ('superior', 'resistance'): 2,
#          ('resistance', 'compression'): 2,
#          ('compression', 'deformation'): 2,
#          ('deformation', 'twists'): 2,
#          ('twists', 'withstand'): 2,
#          ('withstand', 'long'): 2,
#          ('long', 'time'): 2,
#          ('time', 'high'): 2,
#          ('high', 'frequent'): 2,
#          ('frequent', 'strength'): 2,
#          ('strength', 'treading'): 2,
#          ('treading', 'without'): 2,
#          ('without', 'deformation'): 2,
#          ('deformation', 'inch'): 2,
#          ('inch', 'high'): 2,
#          ('heel', 'shows'): 2,
#          ('shows', 'graceful'): 2,
#          ('graceful', 'figure'): 2,
#          ('figure', 'ladies'): 2,
#          ('ladies', 'expressing'): 2,
#          ('expressing', 'extreme'): 2,
#          ('extreme', 'charm'): 2,
#          ('charm', 'dancersdance'): 2,
#          ('dancersdance', 'shoes'): 2,
#          ('performance', 'tips'): 2,
#          ('tips', 'feet'): 2,
#          ('size', 'please'): 2,
#          ('please', 'reference'): 2,
#          ('reference', 'size'): 2,
#          ('chart', 'last'): 2,
#          ('last', 'picture'): 2,
#          ('picture', 'carefully'): 2,
#          ('carefully', 'choose'): 2,
#          ('choose', 'size'): 2,
# ...
#          ('fit', 'stylish'): 1,
#          ('stylish', 'allday'): 1,
#          ('fit', 'roomy'): 1,
#          ('roomy', 'toe'): 1,
#          ('box', 'lace'): 1,
#          ('closure', 'lightweight'): 1,
#          ('midsole', 'rubber'): 1,
#          ('grip', 'synthetic'): 1,
#          ('sole', 'imported'): 1,
#          ('height', 'textile'): 1,
#          ('sneaker', 'fierce'): 1,
#          ('fierce', 'textile'): 1,
#          ('sole', 'puremotion'): 1,
#          ('puremotion', 'rubber'): 1,
#          ('outsole', 'cloud'): 1,
#          ('foam', 'sock'): 1,
#          ('liner', 'boost'): 1,
#          ('boost', 'cushioning'): 1,
#          ('system', 'torsion'): 1,
#          ('torsion', 'system'): 1,
#          ('system', 'traxion'): 1,
#          ('traxion', 'system'): 1,
#          ('system', 'leather'): 1,
#          ('outsole', 'nubuck'): 1,
#          ('nubuck', 'imported'): 1,
#          ('sole', 'relax'): 1,
#          ('tongue', 'man'): 1,
#          ('inches', 'sporty'): 1,
#          ('sporty', 'style'): 1,
#          ('style', 'lightweight'): 1,
#          ('lightweight', 'sports'): 1,
#          ('sports', 'slide'): 1,
#          ('slide', 'sandal'): 1,
#          ('men', 'bold'): 1,
#          ('bold', 'nike'): 1,
#          ('nike', 'logo'): 1,
#          ('logo', 'embellished'): 1,
#          ('embellished', 'strap'): 1,
#          ('strap', 'plush'): 1,
#          ('comfort', 'athletic'): 1,
#          ('athletic', 'look'): 1,
#          ('look', 'casual'): 1,
#          ('comfort', 'sandal'): 1,
#          ('sandal', 'injected'): 1,
#          ('phylon', 'midsole'): 1,
#          ('midsole', 'doubles'): 1,
#          ('doubles', 'outsole'): 1,
#          ('cushioning', 'soft'): 1,
#          ('soft', 'midsole'): 1,
#          ('foam', 'jersey'): 1,
#          ('lining', 'provide'): 1,
#          ('provide', 'comfort'): 1,
#          ('comfort', 'enjoy'): 1,
#          ('enjoy', 'relaxed'): 1,
#          ('relaxed', 'premium'): 1,
#          ('premium', 'experience'): 1,
#          ('experience', 'natural'): 1,
#          ('natural', 'motion'): 1,
#          ('motion', 'men'): 1,
#          ('men', 'nike'): 1,
#          ('slides', 'flex'): 1,
#          ('grooves', 'help'): 1,
#          ('help', 'slide'): 1,
#          ('slide', 'move'): 1,
#          ('move', 'foot'): 1,
#          ('foot', 'foam'): 1,
#          ('foam', 'outsole'): 1,
#          ('provides', 'impact'): 1,
#          ('impact', 'protection'): 1,
#          ('protection', 'sport'): 1,
#          ('sport', 'sandal'): 1,
#          ('men', 'slides'): 1,
#          ('slides', 'onepiece'): 1,
#          ('onepiece', 'synthetic'): 1,
#          ('leather', 'strap'): 1,
#          ('strap', 'durability'): 1,
#          ('durability', 'jersey'): 1,
#          ('soft', 'feel'): 1,
#          ('feel', 'nike'): 1,
#          ('slides', 'imported'): 1,
#          ('wearability', 'bit'): 1,
#          ('bit', 'detailing'): 1,
#          ('detailing', 'offering'): 1,
#          ('offering', 'fashionable'): 1,
#          ('fashionable', 'update'): 1,
#          ('update', 'classic'): 1,
#          ('classic', 'slide'): 1,
#          ('slide', 'loafer'): 1,
#          ('loafer', 'leather'): 1,
#          ('synthetic', 'sneaker'): 1,
#          ('sneaker', 'nylon'): 1,
#          ('cushioning', 'iconic'): 1,
#          ('iconic', 'nike'): 1,
#          ('nike', 'swoosh'): 1,
#          ('swoosh', 'sides'): 1,
#          ('sides', 'style'): 1,
#          ('style', 'outsole'): 1,
#          ('rubber', 'herringbone'): 1,
#          ('herringbone', 'tread'): 1,
#          ('tread', 'stop'): 1,
#          ('stop', 'go'): 1,
#          ('go', 'traction'): 1,
#          ('traction', 'leather'): 1,
#          ('comfortable', 'midheel'): 1,
#          ('midheel', 'height'): 1,
#          ('height', 'sleek'): 1,
#          ('sleek', 'ankle'): 1,
#          ('closure', 'satin'): 1,
#          ('satin', 'suede'): 1,
#          ('sole', 'comfortable'): 1,
#          ('comfortable', 'ballet'): 1,
#          ('ballet', 'shoes'): 1,
#          ('made', 'comfortable'): 1,
#          ('comfortable', 'breathable'): 1,
#          ('breathable', 'satin'): 1,
#          ('satin', 'split'): 1,
#          ('sole', 'basic'): 1,
#          ('basic', 'color'): 1,
#          ('color', 'suits'): 1,
#          ('suits', 'wedding'): 1,
#          ('wedding', 'party'): 1,
#          ('party', 'performance'): 1,
#          ('performance', 'ballet'): 1,
#          ('ballet', 'class'): 1,
#          ('class', 'daily'): 1,
#          ('daily', 'wear'): 1,
#          ('wear', 'safety'): 1,
#          ('safety', 'elastic'): 1,
#          ('elastic', 'drawstrings'): 1,
#          ('drawstrings', 'dance'): 1,
#          ('dance', 'flat'): 1,
#          ('flat', 'adjusted'): 1,
#          ('adjusted', 'tight'): 1,
#          ('tight', 'loose'): 1,
#          ('loose', 'bring'): 1,
#          ('bring', 'comfortable'): 1,
#          ('comfortable', 'tightness'): 1,
#          ('tightness', 'feet'): 1,
#          ('feet', 'hurt'): 1,
#          ('hurt', 'feetpadded'): 1,
#          ('feetpadded', 'antislip'): 1,
#          ('antislip', 'suede'): 1,
#          ('sole', 'add'): 1,
#          ('add', 'secure'): 1,
#          ('secure', 'traction'): 1,
#          ('traction', 'prevent'): 1,
#          ('prevent', 'slips'): 1,
#          ('slips', 'falls'): 1,
#          ('falls', 'size'): 1,
#          ('size', 'attention'): 1,
#          ('attention', 'nt'): 1,
#          ('nt', 'supposed'): 1,
#          ('supposed', 'fit'): 1,
#          ('fit', 'like'): 1,
#          ('like', 'regular'): 1,
#          ('regular', 'street'): 1,
#          ('street', 'shoes'): 1,
#          ('shoes', 'wide'): 1,
#          ('feet', 'must'): 1,
#          ('must', 'order'): 1,
#          ('order', 'one'): 1,
#          ('size', 'uprefer'): 1,
#          ('uprefer', 'size'): 1,
#          ('chart', 'image'): 1,
#          ('image', 'proper'): 1,
#          ('proper', 'sizing'): 1,
#          ('sizing', 'according'): 1,
#          ('according', 'buyer'): 1,
#          ('buyer', 'experience'): 1,
#          ('experience', 'order'): 1,
#          ('order', 'half'): 1,
#          ('half', 'one'): 1,
#          ('size', 'great'): 1,
#          ('great', 'gift'): 1,
#          ('gift', 'perfect'): 1,
#          ('perfect', 'ballet'): 1,
#          ('ballet', 'dance'): 1,
#          ('dance', 'gymnastics'): 1,
#          ('gymnastics', 'yoga'): 1,
#          ('yoga', 'modern'): 1,
#          ('modern', 'ballroom'): 1,
#          ('ballroom', 'normal'): 1,
#          ('normal', 'practice'): 1,
#          ('practice', 'class'): 1,
#          ('class', 'show'): 1,
#          ('show', 'performance'): 1,
#          ('performance', 'wedding'): 1,
#          ('wedding', 'etc'): 1,
#          ('etc', 'provide'): 1,
#          ('provide', 'enough'): 1,
#          ('enough', 'support'): 1,
#          ('support', 'beginners'): 1,
#          ('beginners', 'professional'): 1,
#          ('professional', 'dancer'): 1,
#          ('dancer', 'perfect'): 1,
#          ('perfect', 'birthday'): 1,
#          ('birthday', 'christmas'): 1,
#          ('christmas', 'back'): 1,
#          ('back', 'school'): 1,
#          ('school', 'gift'): 1,
#          ('gift', 'complete'): 1,
#          ('complete', 'color'): 1,
#          ('color', 'size'): 1,
#          ('size', 'different'): 1,
#          ('different', 'colors'): 1,
#          ('colors', 'complete'): 1,
#          ('complete', 'sizes'): 1,
#          ('sizes', 'reference'): 1,
#          ('reference', 'textile'): 1,
#          ('imported', 'man'): 1,
#          ('made', 'textile'): 1,
#          ('textile', 'sole'): 1,
#          ('technology', 'eva'): 1,
#          ('eva', 'sole'): 1,
#          ('uppers', 'contrast'): 1,
#          ('contrast', 'stitiching'): 1,
#          ('stitiching', 'lace'): 1,
#          ('lace', 'accents'): 1,
#          ('accents', 'smooth'): 1,
#          ('smooth', 'leather'): 1,
#          ('lining', 'abrasion'): 1,
#          ('abrasion', 'free'): 1,
#          ('free', 'foot'): 1,
#          ('foot', 'environment'): 1,
#          ('environment', 'gel'): 1,
#          ('gel', 'foam'): 1,
#          ('cushioned', 'footbed'): 1,
#          ('outsole', 'added'): 1,
#          ('technology', 'mesh'): 1,
#          ('mesh', 'shaft'): 1,
#          ('lowtop', 'upper'): 1,
#          ('forefoot', 'firm'): 1,
#          ('firm', 'rubber'): 1,
#          ('rubber', 'heel'): 1,
#          ('heel', 'provides'): 1,
#          ('provides', 'durable'): 1,
#          ('durable', 'stability'): 1,
#          ('stability', 'highintensity'): 1,
#          ('highintensity', 'intervals'): 1,
#          ('intervals', 'thin'): 1,
#          ('heel', 'textile'): 1,
#          ('comfort', 'ez'): 1,
#          ('ez', 'fit'): 1,
#          ('fit', 'closure'): 1,
#          ('closure', 'easy'): 1,
#          ('easy', 'easy'): 1,
#          ('easy', 'soft'): 1,
#          ('sockliner', 'leather'): 1,
#          ('leather', 'made'): 1,
#          ('sole', 'shockwave'): 1,
#          ('shockwave', 'tap'): 1,
#          ('tap', 'plates'): 1,
#          ('plates', 'leather'): 1,
#          ('leather', 'stacked'): 1,
#          ('heel', 'kashmir'): 1,
#          ('kashmir', 'lining'): 1,
#          ('comfort', 'reduce'): 1,
#          ('reduce', 'moisture'): 1,
#          ('moisture', 'heel'): 1,
#          ('heel', 'notch'): 1,
#          ('notch', 'reduce'): 1,
#          ('reduce', 'pressure'): 1,
#          ('pressure', 'achilles'): 1,
#          ('achilles', 'tendon'): 1,
#          ('tendon', 'leather'): 1,
#          ('leather', 'split'): 1,
#          ('sole', 'allows'): 1,
#          ('allows', 'dancer'): 1,
#          ('dancer', 'greater'): 1,
#          ('greater', 'freedom'): 1,
#          ('freedom', 'movement'): 1,
#          ('movement', 'whilst'): 1,
#          ('whilst', 'maintaining'): 1,
#          ('maintaining', 'support'): 1,
#          ('arch', 'super'): 1,
#          ('super', 'comfort'): 1,
#          ('comfort', 'padding'): 1,
#          ('padding', 'faux'): 1,
#          ('faux', 'laces'): 1,
#          ('laces', 'ealstic'): 1,
#          ('ealstic', 'gor'): 1,
#          ('gor', 'easy'): 1,
#          ('pull', 'synthetic'): 1,
#          ('sole', 'neutral'): 1,
#          ('need', 'balance'): 1,
#          ('balance', 'flexibility'): 1,
#          ('lightweight', 'mesh'): 1,
#          ('delivers', 'complete'): 1,
#          ('complete', 'breathability'): 1,
#          ('breathability', 'foam'): 1,
#          ('padding', 'placed'): 1,
#          ('placed', 'around'): 1,
#          ('tongue', 'incredibly'): 1,
#          ('incredibly', 'comfortable'): 1,
#          ('feel', 'high'): 1,
#          ('rebound', 'diecut'): 1,
#          ('eva', 'sockliner'): 1,
#          ('sockliner', 'built'): 1,
#          ('built', 'extended'): 1,
#          ('extended', 'arch'): 1,
#          ('support', 'onepiece'): 1,
#          ('onepiece', 'micro'): 1,
#          ('micro', 'g'): 1,
#          ('g', 'foam'): 1,
#          ('midsole', 'turns'): 1,
#          ('turns', 'cushioned'): 1,
#          ('cushioned', 'landings'): 1,
#          ('landings', 'explosive'): 1,
#          ('explosive', 'takeoffs'): 1,
#          ('takeoffs', 'leather'): 1,
#          ('approximately', 'oilresistant'): 1,
#          ('oilresistant', 'slipresistant'): 1,
#          ('slipresistant', 'lock'): 1,
#          ('lock', 'step'): 1,
#          ('step', 'outsoletm'): 1,
#          ('outsoletm', 'meets'): 1,
#          ('meets', 'satra'): 1,
#          ('satra', 'standards'): 1,
#          ('standards', 'independent'): 1,
#          ('independent', 'lab'): 1,
#          ('lab', 'testing'): 1,
#          ('testing', 'shoes'): 1,
#          ('shoes', 'beat'): 1,
#          ('beat', 'industry'): 1,
#          ('industry', 'average'): 1,
#          ('average', 'comfort'): 1,
#          ('comfort', 'cushionig'): 1,
#          ('cushionig', 'heeluxetm'): 1,
#          ('heeluxetm', 'occupational'): 1,
#          ('occupational', 'shoe'): 1,
#          ('shoe', 'research'): 1,
#          ('research', 'april'): 1,
#          ('april', 'memory'): 1,
#          ('fit', 'anticompression'): 1,
#          ('anticompression', 'insole'): 1,
#          ('outsole', 'drilex'): 1,
#          ('drilex', 'moisturewicking'): 1,
#          ('moisturewicking', 'lining'): 1,
#          ('lining', 'aegis'): 1,
#          ('aegis', 'microbe'): 1,
#          ('microbe', 'shield'): 1,
#          ('shield', 'control'): 1,
#          ('control', 'odor'): 1,
#          ('odor', 'suede'): 1,
#          ('sole', 'comfortincluded'): 1,
#          ('comfortincluded', 'authentic'): 1,
#          ('authentic', 'brand'): 1,
#          ('new', 'durable'): 1,
#          ('durable', 'original'): 1,
#          ('packaging', 'leather'): 1,
#          ('design', 'roomy'): 1,
#          ('roomy', 'comfortable'): 1,
#          ('fit', 'manmade'): 1,
#          ('sole', 'walk'): 1,
#          ('walk', 'tall'): 1,
#          ('tall', 'showing'): 1,
#          ('showing', 'pedicured'): 1,
#          ('pedicured', 'toes'): 1,
#          ('toes', 'wearing'): 1,
#          ('wearing', 'circus'): 1,
#          ('circus', 'sam'): 1,
#          ('sam', 'stephanie'): 1,
#          ('stephanie', 'wedge'): 1,
#          ('wedge', 'sandal'): 1,
#          ('sandal', 'comfortable'): 1,
#          ('comfortable', 'soft'): 1,
#          ('soft', 'satin'): 1,
#          ('satin', 'latin'): 1,
#          ('salsa', 'ballroom'): 1,
#          ('women', 'suede'): 1,
#          ('sole', 'materials'): 1,
#          ('materials', 'satin'): 1,
#          ('satin', 'mesh'): 1,
#          ('upper', 'dance'): 1,
#          ('shoes', 'full'): 1,
#          ('full', 'insole'): 1,
#          ('sole', 'salsa'): 1,
#          ('salsa', 'latin'): 1,
#          ('ballroom', 'heel'): 1,
#          ('approximately', 'dance'): 1,
#          ('shoes', 'feature'): 1,
#          ('feature', 'dance'): 1,
#          ('shoes', 'excellent'): 1,
#          ('excellent', 'ballroom'): 1,
#          ('dancing', 'comfortable'): 1,
#          ('comfortable', 'shoe'): 1,
#          ('shoe', 'adjustable'): 1,
#          ('adjustable', 'crisscross'): 1,
#          ('crisscross', 'ankle'): 1,
#          ('strap', 'salsa'): 1,
#          ('salsa', 'shoes'): 1,
#          ('nonslip', 'latin'): 1,
#          ('shoes', 'stable'): 1,
#          ('stable', 'heels'): 1,
#          ('heels', 'salsa'): 1,
#          ('salsa', 'dancing'): 1,
#          ('dancing', 'dance'): 1,
#          ('ballroom', 'salsa'): 1,
#          ('practicing', 'swing'): 1,
#          ('swing', 'practiceperfomance'): 1,
#          ('practiceperfomance', 'ture'): 1,
#          ('ture', 'size'): 1,
#          ('size', 'sizing'): 1,
#          ('flat', 'unknown'): 1,
#          ('unknown', 'textile'): 1,
#          ('ultralightweight', 'outsole'): 1,
#          ('inches', 'stand'): 1,
#          ('stand', 'office'): 1,
#          ('office', 'pretty'): 1,
#          ('pretty', 'polished'): 1,
#          ('polished', 'un'): 1,
#          ('un', 'cosmo'): 1,
#          ('cosmo', 'step'): 1,
#          ('step', 'pump'): 1,
#          ('pump', 'leather'): 1,
#          ('arch', 'full'): 1,
#          ('provides', 'supremely'): 1,
#          ('supremely', 'comfortable'): 1,
#          ('lining', 'perfect'): 1,
#          ('perfect', 'inner'): 1,
#          ('inner', 'climate'): 1,
#          ('climate', 'directinjected'): 1,
#          ('directinjected', 'onecomponent'): 1,
#          ('onecomponent', 'pu'): 1,
#          ('pu', 'outsole'): 1,
#          ('outsole', 'highly'): 1,
#          ('highly', 'comfortable'): 1,
#          ('flexible', 'shoe'): 1,
#          ('shoe', 'removable'): 1,
#          ('removable', 'textile'): 1,
#          ('textile', 'insole'): 1,
#          ('insole', 'airport'): 1,
#          ('airport', 'friendly'): 1,
#          ('friendly', 'leather'): 1,
#          ('imported', 'flaunt'): 1,
#          ('flaunt', 'comfort'): 1,
#          ('comfort', 'ashland'): 1,
#          ('ashland', 'lily'): 1,
#          ('lily', 'leather'): 1,
#          ('soft', 'button'): 1,
#          ('button', 'trims'): 1,
#          ('trims', 'minimum'): 1,
#          ('minimum', 'compression'): 1,
#          ('compression', 'man'): 1,
#          ('outsole', 'available'): 1,
#          ('width', 'man'): 1,
#          ('lightweight', 'dualdensity'): 1,
#          ('dualdensity', 'ultra'): 1,
#          ('go', 'outsole'): 1,
#          ('outsole', 'comfort'): 1,
#          ('comfort', 'pillar'): 1,
#          ('pillar', 'technology'): 1,
#          ('breathable', 'seamless'): 1,
#          ('seamless', 'flat'): 1,
#          ('flat', 'knit'): 1,
#          ('upper', 'machine'): 1,
#          ('washable', 'air'): 1,
#          ('dry', 'leather'): 1,
#          ('panels', 'ortholite'): 1})

# %%
bigrams_df = pd.DataFrame.from_dict(bigrams, orient='index').reset_index()
bigrams_df = bigrams_df.rename(columns={'index':'bigram', 0:'count'})
bigrams_df = bigrams_df.sort_values(by=['count'], ascending = False)
bigrams_df_top10 = bigrams_df.head(10)
bigrams_df_top10
# Out:
#                              bigram  count
# 21        (measures, approximately)    296
# 20                (shaft, measures)    208
# 19                    (sole, shaft)    204
# 2                    (rubber, sole)    166
# 1                (imported, rubber)    150
# 101               (synthetic, sole)    127
# 100           (imported, synthetic)    125
# 342  (approximately, notapplicable)    105
# 343           (notapplicable, arch)    104
# 22          (approximately, lowtop)     91

# %%
trigrams = Counter(zip(words,words[1:], words[2:]))
pprint(trigrams)
# Out:
# Counter({('shaft', 'measures', 'approximately'): 208,
#          ('sole', 'shaft', 'measures'): 204,
#          ('imported', 'rubber', 'sole'): 150,
#          ('imported', 'synthetic', 'sole'): 125,
#          ('rubber', 'sole', 'shaft'): 105,
#          ('measures', 'approximately', 'notapplicable'): 105,
#          ('approximately', 'notapplicable', 'arch'): 104,
#          ('synthetic', 'sole', 'shaft'): 93,
#          ('measures', 'approximately', 'lowtop'): 91,
#          ('approximately', 'lowtop', 'arch'): 90,
#          ('heel', 'measures', 'approximately'): 51,
#          ('measures', 'approximately', 'inches'): 45,
#          ('synthetic', 'imported', 'rubber'): 43,
#          ('platform', 'measures', 'approximately'): 36,
#          ('textile', 'imported', 'synthetic'): 35,
#          ('leather', 'imported', 'rubber'): 33,
#          ('textile', 'imported', 'rubber'): 31,
#          ('leather', 'imported', 'synthetic'): 30,
#          ('salsa', 'tango', 'rumba'): 29,
#          ('suitable', 'latin', 'salsa'): 28,
#          ('latin', 'salsa', 'tango'): 28,
#          ('high', 'quality', 'satin'): 24,
#          ('notapplicable', 'arch', 'heel'): 21,
#          ('shoes', 'suitable', 'latin'): 20,
#          ('arch', 'heel', 'measures'): 20,
#          ('arch', 'platform', 'measures'): 20,
#          ('notapplicable', 'arch', 'platform'): 17,
#          ('man', 'made', 'imported'): 17,
#          ('ankle', 'strap', 'buckle'): 16,
#          ('strap', 'buckle', 'closure'): 16,
#          ('textile', 'synthetic', 'imported'): 16,
#          ('synthetic', 'imported', 'synthetic'): 16,
#          ('cushion', 'soft', 'technology'): 16,
#          ('sole', 'heel', 'measures'): 15,
#          ('footbed', 'cushion', 'soft'): 15,
#          ('satin', 'upper', 'soft'): 15,
#          ('upper', 'soft', 'suede'): 15,
#          ('soft', 'suede', 'sole'): 15,
#          ('suede', 'sole', 'elegant'): 15,
#          ('sole', 'elegant', 'exterior'): 15,
#          ('elegant', 'exterior', 'allure'): 15,
#          ('exterior', 'allure', 'onlookers'): 15,
#          ('allure', 'onlookers', 'hit'): 15,
#          ('onlookers', 'hit', 'dance'): 15,
#          ('hit', 'dance', 'floor'): 15,
#          ('dance', 'floor', 'skoex'): 15,
#          ('floor', 'skoex', 'dance'): 15,
#          ('skoex', 'dance', 'shoes'): 15,
#          ('dance', 'shoes', 'rhinestonesembellished'): 15,
#          ('shoes', 'rhinestonesembellished', 'bring'): 15,
#          ('rhinestonesembellished', 'bring', 'dazzling'): 15,
#          ('bring', 'dazzling', 'element'): 15,
#          ('dazzling', 'element', 'dancing'): 15,
#          ('element', 'dancing', 'ensemble'): 15,
#          ('dancing', 'ensemble', 'comfortable'): 15,
#          ('ensemble', 'comfortable', 'material'): 15,
#          ('comfortable', 'material', 'women'): 15,
#          ('material', 'women', 'dance'): 15,
#          ('women', 'dance', 'shoes'): 15,
#          ('dance', 'shoes', 'features'): 15,
#          ('shoes', 'features', 'high'): 15,
#          ('features', 'high', 'quality'): 15,
#          ('quality', 'satin', 'upper'): 15,
#          ('satin', 'upper', 'fine'): 15,
#          ('upper', 'fine', 'sweat'): 15,
#          ('fine', 'sweat', 'absorption'): 15,
#          ('sweat', 'absorption', 'suede'): 15,
#          ('absorption', 'suede', 'insole'): 15,
#          ('suede', 'insole', 'high'): 15,
#          ('insole', 'high', 'elastic'): 15,
#          ('high', 'elastic', 'latex'): 15,
#          ('elastic', 'latex', 'midsole'): 15,
#          ('latex', 'midsole', 'thick'): 15,
#          ('midsole', 'thick', 'durable'): 15,
#          ('thick', 'durable', 'suede'): 15,
#          ('durable', 'suede', 'outsole'): 15,
#          ('suede', 'outsole', 'feel'): 15,
#          ('outsole', 'feel', 'flexible'): 15,
#          ('feel', 'flexible', 'comfort'): 15,
#          ('flexible', 'comfort', 'classic'): 15,
#          ('comfort', 'classic', 'design'): 15,
#          ('classic', 'design', 'simple'): 15,
#          ('design', 'simple', 'generous'): 15,
#          ('simple', 'generous', 'style'): 15,
#          ('generous', 'style', 'design'): 15,
#          ('style', 'design', 'lowkey'): 15,
#          ('design', 'lowkey', 'luxury'): 15,
#          ('lowkey', 'luxury', 'opentoe'): 15,
#          ('luxury', 'opentoe', 'design'): 15,
#          ('opentoe', 'design', 'ankle'): 15,
#          ('design', 'ankle', 'strap'): 15,
#          ('buckle', 'closure', 'stable'): 15,
#          ('closure', 'stable', 'heel'): 15,
#          ('stable', 'heel', 'protect'): 15,
#          ('heel', 'protect', 'dance'): 15,
#          ('protect', 'dance', 'well'): 15,
#          ('dance', 'well', 'nt'): 15,
#          ('well', 'nt', 'fall'): 15,
#          ('nt', 'fall', 'soft'): 15,
#          ('fall', 'soft', 'lightweight'): 15,
#          ('soft', 'lightweight', 'heeled'): 15,
#          ('lightweight', 'heeled', 'ladies'): 15,
#          ('heeled', 'ladies', 'dance'): 15,
#          ('ladies', 'dance', 'shoe'): 15,
#          ('dance', 'shoe', 'featuring'): 15,
#          ('shoe', 'featuring', 'super'): 15,
#          ('featuring', 'super', 'lightweight'): 15,
#          ('super', 'lightweight', 'flexible'): 15,
#          ('lightweight', 'flexible', 'make'): 15,
#          ('flexible', 'make', 'feel'): 15,
#          ('make', 'feel', 'great'): 15,
#          ('feel', 'great', 'freedom'): 15,
#          ('great', 'freedom', 'comfortable'): 15,
#          ('freedom', 'comfortable', 'wearing'): 15,
#          ('comfortable', 'wearing', 'keep'): 15,
#          ('wearing', 'keep', 'amazing'): 15,
#          ('keep', 'amazing', 'dancing'): 15,
#          ('amazing', 'dancing', 'perfect'): 15,
#          ('dancing', 'perfect', 'occasion'): 15,
#          ('perfect', 'occasion', 'womens'): 15,
#          ('occasion', 'womens', 'ballroom'): 15,
#          ('womens', 'ballroom', 'shoes'): 15,
#          ('ballroom', 'shoes', 'suitable'): 15,
#          ('tango', 'rumba', 'amateur'): 15,
#          ('rumba', 'amateur', 'professional'): 15,
#          ('amateur', 'professional', 'dancers'): 15,
#          ('professional', 'dancers', 'ballroom'): 15,
#          ('dancers', 'ballroom', 'dance'): 15,
#          ('ballroom', 'dance', 'dance'): 15,
#          ('dance', 'dance', 'class'): 15,
#          ('dance', 'class', 'beginner'): 15,
#          ('class', 'beginner', 'practice'): 15,
#          ('beginner', 'practice', 'performance'): 15,
#          ('heel', 'height', 'inches'): 15,
#          ('made', 'imported', 'synthetic'): 15,
#          ('ortholite', 'footbed', 'cushion'): 14,
#          ('tango', 'rumba', 'chacha'): 14,
#          ('rumba', 'chacha', 'practicing'): 14,
#          ('sole', 'suitable', 'indoor'): 13,
#          ('good', 'skid', 'resistance'): 13,
#          ('skid', 'resistance', 'balance'): 13,
#          ('chacha', 'practicing', 'performance'): 13,
#          ('notapplicable', 'arch', 'lightweight'): 13,
#          ('fabric', 'imported', 'synthetic'): 13,
#          ('imported', 'leather', 'sole'): 12,
#          ('latin', 'dance', 'shoes'): 12,
#          ('soft', 'fabric', 'lining'): 12,
#          ('fabric', 'imported', 'rubber'): 11,
#          ('extremely', 'flexible', 'lightweight'): 11,
#          ('flexible', 'lightweight', 'comfortable'): 11,
#          ('lightweight', 'comfortable', 'situable'): 11,
#          ('nonslip', 'suede', 'sole'): 11,
#          ('suede', 'sole', 'suitable'): 11,
#          ('suitable', 'indoor', 'floor'): 11,
#          ('indoor', 'floor', 'good'): 11,
#          ('floor', 'good', 'skid'): 11,
#          ('free', 'energy', 'technology'): 11,
#          ('energy', 'technology', 'insole'): 11,
#          ('technology', 'insole', 'distinct'): 11,
#          ('insole', 'distinct', 'zones'): 11,
#          ('distinct', 'zones', 'designed'): 11,
#          ('zones', 'designed', 'maximum'): 11,
#          ('designed', 'maximum', 'comfort'): 11,
#          ('arch', 'lightweight', 'responsive'): 11,
#          ('sole', 'memory', 'foam'): 11,
#          ('memory', 'foam', 'cool'): 11,
#          ('foam', 'cool', 'fit'): 11,
#          ('leather', 'synthetic', 'imported'): 10,
#          ('rubber', 'sole', 'heel'): 10,
#          ('inches', 'heel', 'height'): 10,
#          ('arch', 'free', 'energy'): 10,
#          ('flexible', 'durable', 'sole'): 10,
#          ('skechers', 'air', 'cooled'): 10,
#          ('air', 'cooled', 'goga'): 10,
#          ('cooled', 'goga', 'mat'): 10,
#          ('approximately', 'inches', 'heel'): 9,
#          ('leather', 'sole', 'high'): 9,
#          ('sole', 'high', 'quality'): 9,
#          ('quality', 'satin', 'smooth'): 9,
#          ('satin', 'smooth', 'exquisite'): 9,
#          ('smooth', 'exquisite', 'extremely'): 9,
#          ('exquisite', 'extremely', 'flexible'): 9,
#          ('comfortable', 'situable', 'professionals'): 9,
#          ('situable', 'professionals', 'standard'): 9,
#          ('professionals', 'standard', 'latin'): 9,
#          ('standard', 'latin', 'dance'): 9,
#          ('dance', 'shoes', 'nonslip'): 9,
#          ('shoes', 'nonslip', 'suede'): 9,
#          ('resistance', 'balance', 'adjustable'): 9,
#          ('balance', 'adjustable', 'buckle'): 9,
#          ('adjustable', 'buckle', 'ankle'): 9,
#          ('buckle', 'ankle', 'foot'): 9,
#          ('ankle', 'foot', 'dancing'): 9,
#          ('foot', 'dancing', 'feel'): 9,
#          ('dancing', 'feel', 'comfortable'): 9,
#          ('feel', 'comfortable', 'stable'): 9,
#          ('comfortable', 'stable', 'heel'): 9,
#          ('stable', 'heel', 'measures'): 9,
#          ('measures', 'approximately', 'model'): 9,
#          ('approximately', 'model', 'suitable'): 9,
#          ('model', 'suitable', 'latin'): 9,
#          ('practicing', 'performance', 'usually'): 9,
#          ('performance', 'usually', 'shows'): 9,
#          ('usually', 'shows', 'indoor'): 9,
#          ('shows', 'indoor', 'wedding'): 9,
#          ('indoor', 'wedding', 'dance'): 9,
#          ('wedding', 'dance', 'performence'): 9,
#          ('dance', 'performence', 'shipping'): 9,
#          ('performence', 'shipping', 'time'): 9,
#          ('shipping', 'time', 'usually'): 9,
#          ('time', 'usually', 'days'): 9,
#          ('usually', 'days', 'need'): 9,
#          ('days', 'need', 'urgntly'): 9,
#          ('need', 'urgntly', 'please'): 9,
#          ('urgntly', 'please', 'contact'): 9,
#          ('please', 'contact', 'us'): 9,
#          ('contact', 'us', 'choose'): 9,
#          ('us', 'choose', 'faster'): 9,
#          ('choose', 'faster', 'shipping'): 9,
#          ('lightweight', 'responsive', 'cushioning'): 9,
#          ('responsive', 'cushioning', 'skechers'): 9,
#          ('goga', 'mat', 'insole'): 9,
#          ('cool', 'fit', 'insole'): 9,
#          ('heel', 'height', 'ortholite'): 8,
#          ('height', 'ortholite', 'footbed'): 8,
#          ('goga', 'max', 'high'): 8,
#          ('max', 'high', 'rebound'): 8,
#          ('arch', 'heel', 'height'): 8,
#          ('measures', 'approximately', 'platform'): 8,
#          ('approximately', 'platform', 'measures'): 8,
#          ('memory', 'foam', 'insole'): 8,
#          ('synthetic', 'sole', 'heel'): 7,
#          ('measures', 'approximately', 'heel'): 7,
#          ('approximately', 'heel', 'height'): 7,
#          ('arch', 'memory', 'foam'): 7,
#          ('cushioning', 'skechers', 'goga'): 7,
#          ('skechers', 'goga', 'max'): 7,
#          ('breathable', 'mesh', 'upper'): 7,
#          ('imported', 'heel', 'measures'): 7,
#          ('measures', 'approximately', 'arch'): 6,
#          ('sole', 'platform', 'measures'): 6,
#          ('made', 'usa', 'imported'): 6,
#          ('quality', 'materials', 'fine'): 6,
#          ('materials', 'fine', 'workmanship'): 6,
#          ('fine', 'workmanship', 'durable'): 6,
#          ('workmanship', 'durable', 'silk'): 6,
#          ('durable', 'silk', 'blends'): 6,
#          ('silk', 'blends', 'leather'): 6,
#          ('blends', 'leather', 'shoelace'): 6,
#          ('leather', 'shoelace', 'design'): 6,
#          ('shoelace', 'design', 'get'): 6,
#          ('design', 'get', 'rid'): 6,
#          ('get', 'rid', 'troubles'): 6,
#          ('rid', 'troubles', 'shoelace'): 6,
#          ('troubles', 'shoelace', 'vamp'): 6,
#          ('shoelace', 'vamp', 'cute'): 6,
#          ('vamp', 'cute', 'delicate'): 6,
#          ('cute', 'delicate', 'bow'): 6,
#          ('delicate', 'bow', 'adds'): 6,
#          ('bow', 'adds', 'sense'): 6,
#          ('adds', 'sense', 'wear'): 6,
#          ('sense', 'wear', 'comfortable'): 6,
#          ('wear', 'comfortable', 'wear'): 6,
#          ('comfortable', 'wear', 'flat'): 6,
#          ('wear', 'flat', 'heel'): 6,
#          ('flat', 'heel', 'makes'): 6,
#          ('heel', 'makes', 'feel'): 6,
#          ('makes', 'feel', 'stable'): 6,
#          ('feel', 'stable', 'comfortable'): 6,
#          ('stable', 'comfortable', 'walk'): 6,
#          ('comfortable', 'walk', 'tired'): 6,
#          ('walk', 'tired', 'put'): 6,
#          ('tired', 'put', 'pressure'): 6,
#          ('put', 'pressure', 'weightthere'): 6,
#          ('pressure', 'weightthere', 'almost'): 6,
#          ('weightthere', 'almost', 'noise'): 6,
#          ('almost', 'noise', 'shoes'): 6,
#          ('noise', 'shoes', 'nt'): 6,
#          ('shoes', 'nt', 'worry'): 6,
#          ('nt', 'worry', 'disturbing'): 6,
#          ('worry', 'disturbing', 'family'): 6,
#          ('disturbing', 'family', 'colleagues'): 6,
#          ('family', 'colleagues', 'giving'): 6,
#          ('colleagues', 'giving', 'quiet'): 6,
#          ('giving', 'quiet', 'variety'): 6,
#          ('quiet', 'variety', 'occasions'): 6,
#          ('variety', 'occasions', 'lightweight'): 6,
#          ('occasions', 'lightweight', 'flexible'): 6,
#          ('lightweight', 'flexible', 'nonslip'): 6,
#          ('flexible', 'nonslip', 'durable'): 6,
#          ('nonslip', 'durable', 'take'): 6,
#          ('durable', 'take', 'care'): 6,
#          ('take', 'care', 'feetsuitable'): 6,
#          ('care', 'feetsuitable', 'daily'): 6,
#          ('feetsuitable', 'daily', 'use'): 6,
#          ('daily', 'use', 'apartments'): 6,
#          ('use', 'apartments', 'bedrooms'): 6,
#          ('apartments', 'bedrooms', 'offices'): 6,
#          ('bedrooms', 'offices', 'outdoor'): 6,
#          ('offices', 'outdoor', 'areas'): 6,
#          ('outdoor', 'areas', 'etclet'): 6,
#          ('areas', 'etclet', 'feet'): 6,
#          ('etclet', 'feet', 'get'): 6,
#          ('feet', 'get', 'rid'): 6,
#          ('get', 'rid', 'shackles'): 6,
#          ('rid', 'shackles', 'high'): 6,
#          ('shackles', 'high', 'heels'): 6,
#          ('high', 'heels', 'relaxsince'): 6,
#          ('heels', 'relaxsince', 'shoes'): 6,
#          ('relaxsince', 'shoes', 'foldable'): 6,
#          ('shoes', 'foldable', 'carry'): 6,
#          ('foldable', 'carry', 'used'): 6,
#          ('carry', 'used', 'gift'): 6,
#          ('used', 'gift', 'christmas'): 6,
#          ('gift', 'christmas', 'holidays'): 6,
#          ('christmas', 'holidays', 'shoe'): 6,
#          ('holidays', 'shoe', 'suitable'): 6,
#          ('shoe', 'suitable', 'women'): 6,
#          ('suitable', 'women', 'age'): 6,
#          ('women', 'age', 'styleyou'): 6,
#          ('age', 'styleyou', 'give'): 6,
#          ('styleyou', 'give', 'gifts'): 6,
#          ('give', 'gifts', 'family'): 6,
#          ('gifts', 'family', 'friends'): 6,
#          ('family', 'friends', 'festivalevery'): 6,
#          ('friends', 'festivalevery', 'girl'): 6,
#          ('festivalevery', 'girl', 'good'): 6,
#          ('girl', 'good', 'pair'): 6,
#          ('good', 'pair', 'shoes'): 6,
#          ('pair', 'shoes', 'take'): 6,
#          ('shoes', 'take', 'want'): 6,
#          ('take', 'want', 'variety'): 6,
#          ('want', 'variety', 'colors'): 6,
#          ('variety', 'colors', 'choose'): 6,
#          ('colors', 'choose', 'easy'): 6,
#          ('choose', 'easy', 'care'): 6,
#          ('easy', 'care', 'shoes'): 6,
#          ('care', 'shoes', 'available'): 6,
#          ('shoes', 'available', 'four'): 6,
#          ('available', 'four', 'colors'): 6,
#          ('four', 'colors', 'pink'): 6,
#          ('colors', 'pink', 'black'): 6,
#          ('pink', 'black', 'light'): 6,
#          ('black', 'light', 'yellow'): 6,
#          ('light', 'yellow', 'leopard'): 6,
#          ('yellow', 'leopard', 'suitable'): 6,
#          ('leopard', 'suitable', 'seasonmaintenance'): 6,
#          ('suitable', 'seasonmaintenance', 'easy'): 6,
#          ('seasonmaintenance', 'easy', 'machine'): 6,
#          ('easy', 'machine', 'washable'): 6,
#          ('machine', 'washable', 'stains'): 6,
#          ('washable', 'stains', 'easy'): 6,
#          ('stains', 'easy', 'remove'): 6,
#          ('easy', 'remove', 'away'): 6,
#          ('remove', 'away', 'heat'): 6,
#          ('notapplicable', 'arch', 'free'): 6,
#          ('fabric', 'textile', 'imported'): 6,
#          ('lowtop', 'arch', 'lightweight'): 6,
#          ('upper', 'soft', 'fabric'): 6,
#          ('footbed', 'smooth', 'textile'): 6,
#          ('smooth', 'textile', 'lining'): 6,
#          ('textile', 'lining', 'durable'): 6,
#          ('beibestcoat', 'please', 'refer'): 6,
#          ('please', 'refer', 'left'): 6,
#          ('refer', 'left', 'size'): 6,
#          ('left', 'size', 'table'): 6,
#          ('size', 'table', 'select'): 6,
#          ('table', 'select', 'corresponding'): 6,
#          ('select', 'corresponding', 'size'): 6,
#          ('corresponding', 'size', 'according'): 6,
#          ('size', 'according', 'feet'): 6,
#          ('according', 'feet', 'length'): 6,
#          ('feet', 'length', 'wide'): 6,
#          ('length', 'wide', 'thick'): 6,
#          ('wide', 'thick', 'feet'): 6,
#          ('thick', 'feet', 'please'): 6,
#          ('feet', 'please', 'choose'): 6,
#          ('please', 'choose', 'larger'): 6,
#          ('choose', 'larger', 'size'): 6,
#          ('larger', 'size', 'shoes'): 6,
#          ('size', 'shoes', 'made'): 6,
#          ('shoes', 'made', 'environmentally'): 6,
#          ('made', 'environmentally', 'friendly'): 6,
#          ('environmentally', 'friendly', 'materials'): 6,
#          ('friendly', 'materials', 'please'): 6,
#          ('materials', 'please', 'feel'): 6,
#          ('please', 'feel', 'rest'): 6,
#          ('feel', 'rest', 'assured'): 6,
#          ('rest', 'assured', 'wearing'): 6,
#          ('assured', 'wearing', 'normal'): 6,
#          ('wearing', 'normal', 'new'): 6,
#          ('normal', 'new', 'leather'): 6,
#          ('new', 'leather', 'shoes'): 6,
#          ('leather', 'shoes', 'little'): 6,
#          ('shoes', 'little', 'pungent'): 6,
#          ('little', 'pungent', 'smell'): 6,
#          ('pungent', 'smell', 'smell'): 6,
#          ('smell', 'smell', 'disappear'): 6,
#          ('smell', 'disappear', 'naturally'): 6,
#          ('disappear', 'naturally', 'one'): 6,
#          ('naturally', 'one', 'two'): 6,
#          ('one', 'two', 'days'): 6,
#          ('two', 'days', 'ventilation'): 6,
#          ('days', 'ventilation', 'beibestcoat'): 6,
#          ('ventilation', 'beibestcoat', 'split'): 6,
#          ('beibestcoat', 'split', 'sole'): 6,
#          ('split', 'sole', 'design'): 6,
#          ('sole', 'design', 'provide'): 6,
#          ('design', 'provide', 'ultimate'): 6,
#          ('provide', 'ultimate', 'flexibility'): 6,
#          ('ultimate', 'flexibility', 'point'): 6,
#          ('flexibility', 'point', 'full'): 6,
#          ('point', 'full', 'toe'): 6,
#          ('full', 'toe', 'box'): 6,
#          ('toe', 'box', 'heel'): 6,
#          ('box', 'heel', 'counter'): 6,
#          ('heel', 'counter', 'provide'): 6,
#          ('counter', 'provide', 'additional'): 6,
#          ('provide', 'additional', 'support'): 6,
#          ('additional', 'support', 'beibestcoat'): 6,
#          ('support', 'beibestcoat', 'extra'): 6,
#          ('beibestcoat', 'extra', 'steel'): 6,
#          ('extra', 'steel', 'plate'): 6,
#          ('steel', 'plate', 'insole'): 6,
#          ('plate', 'insole', 'outsole'): 6,
#          ('insole', 'outsole', 'ensure'): 6,
#          ('outsole', 'ensure', 'tap'): 6,
#          ('ensure', 'tap', 'security'): 6,
#          ('tap', 'security', 'sleek'): 6,
#          ('security', 'sleek', 'outlook'): 6,
#          ('sleek', 'outlook', 'appropriate'): 6,
#          ('outlook', 'appropriate', 'modern'): 6,
#          ('appropriate', 'modern', 'life'): 6,
#          ('modern', 'life', 'enjoy'): 6,
#          ('life', 'enjoy', 'attitude'): 6,
#          ('enjoy', 'attitude', 'beibestcoat'): 6,
#          ('attitude', 'beibestcoat', 'made'): 6,
#          ('beibestcoat', 'made', 'synthetic'): 6,
#          ('made', 'synthetic', 'upper'): 6,
#          ('synthetic', 'upper', 'rubber'): 6,
#          ('upper', 'rubber', 'outsole'): 6,
#          ('rubber', 'outsole', 'taps'): 6,
#          ('outsole', 'taps', 'proper'): 6,
#          ('taps', 'proper', 'mounting'): 6,
#          ('proper', 'mounting', 'great'): 6,
#          ('mounting', 'great', 'sound'): 6,
#          ('great', 'sound', 'beibestcoat'): 6,
#          ('sound', 'beibestcoat', 'maximum'): 6,
#          ('beibestcoat', 'maximum', 'order'): 6,
#          ('maximum', 'order', 'quantity'): 6,
#          ('order', 'quantity', 'pair'): 6,
#          ('quantity', 'pair', 'need'): 6,
#          ('pair', 'need', 'please'): 6,
#          ('need', 'please', 'place'): 6,
#          ('please', 'place', 'another'): 6,
#          ('place', 'another', 'order'): 6,
#          ('insole', 'maximum', 'comfort'): 6,
#          ('height', 'inches', 'ortholite'): 6,
#          ('weight', 'ounces', 'size'): 5,
#          ('ounces', 'size', 'midsole'): 5,
#          ('size', 'midsole', 'drop'): 5,
#          ('midsole', 'drop', 'mm'): 5,
#          ('drop', 'mm', 'heel'): 5,
#          ('mm', 'heel', 'mm'): 5,
#          ('heel', 'mm', 'forefoot'): 5,
#          ('mm', 'forefoot', 'mm'): 5,
#          ('mesh', 'imported', 'rubber'): 5,
#          ('fit', 'lace', 'closure'): 5,
#          ('high', 'rebound', 'insole'): 5,
#          ('heel', 'height', 'approximately'): 5,
#          ('suede', 'imported', 'rubber'): 5,
#          ('padded', 'tongue', 'collar'): 5,
#          ('slipon', 'providing', 'easy'): 5,
#          ('runtrain', 'performance', 'sneaker'): 5,
#          ('memory', 'foam', 'padded'): 5,
#          ('energizes', 'every', 'step'): 5,
#          ('arch', 'lightweight', 'flexible'): 5,
#          ('mesh', 'upper', 'soft'): 5,
#          ('sole', 'textile', 'imported'): 5,
#          ('ultra', 'go', 'cushioning'): 5,
#          ('maximum', 'comfort', 'extra'): 5,
#          ('comfort', 'extra', 'support'): 5,
#          ('extra', 'support', 'toe'): 5,
#          ('support', 'toe', 'highrecovery'): 5,
#          ('toe', 'highrecovery', 'foam'): 5,
#          ('highrecovery', 'foam', 'ball'): 5,
#          ('dense', 'foam', 'cradling'): 5,
#          ('foam', 'cradling', 'heel'): 5,
#          ('inches', 'ortholite', 'footbed'): 5,
#          ('sole', 'leather', 'imported'): 5,
#          ('full', 'grain', 'leather'): 4,
#          ('neutral', 'runners', 'need'): 4,
#          ('engineered', 'mesh', 'upper'): 4,
#          ('synthetic', 'sole', 'lightweight'): 4,
#          ('rubber', 'outsole', 'provides'): 4,
#          ('outsole', 'provides', 'excellent'): 4,
#          ('notapplicable', 'arch', 'memory'): 4,
#          ('flexible', 'sole', 'charitable'): 4,
#          ('away', 'heat', 'textile'): 4,
#          ('aircooled', 'memory', 'foam'): 4,
#          ('regular', 'fit', 'lace'): 4,
#          ('enjoy', 'comfort', 'performance'): 4,
#          ('comfort', 'performance', 'ortholite'): 4,
#          ('measures', 'approximately', 'midtop'): 4,
#          ('hillo', 'heel', 'cushions'): 4,
#          ('heel', 'cushions', 'designed'): 4,
#          ('cushions', 'designed', 'reduce'): 4,
#          ('designed', 'reduce', 'slip'): 4,
#          ('reduce', 'slip', 'improve'): 4,
#          ('slip', 'improve', 'fit'): 4,
#          ('improve', 'fit', 'flexible'): 4,
#          ('fit', 'flexible', 'durable'): 4,
#          ('lowtop', 'arch', 'rearfoot'): 4,
#          ('arch', 'rearfoot', 'gel'): 4,
#          ('cushioning', 'system', 'attenuates'): 4,
#          ('system', 'attenuates', 'shock'): 4,
#          ('attenuates', 'shock', 'impact'): 4,
#          ('shock', 'impact', 'phase'): 4,
#          ('impact', 'phase', 'allows'): 4,
#          ('phase', 'allows', 'smooth'): 4,
#          ('allows', 'smooth', 'transition'): 4,
#          ('smooth', 'transition', 'midstance'): 4,
#          ('rebound', 'insole', 'breathable'): 4,
#          ('insole', 'breathable', 'mesh'): 4,
#          ('feet', 'wide', 'suggest'): 4,
#          ('wide', 'suggest', 'foot'): 4,
#          ('suggest', 'foot', 'choose'): 4,
#          ('foot', 'choose', 'bigger'): 4,
#          ('choose', 'bigger', 'size'): 4,
#          ('outsole', 'leather', 'imported'): 4,
#          ('notapplicable', 'arch', 'slipon'): 4,
#          ('skechers', 'performance', 'fitknit'): 4,
#          ('sole', 'radically', 'lightweight'): 4,
#          ('innovative', 'highly', 'responsive'): 4,
#          ('highly', 'responsive', 'midsole'): 4,
#          ('responsive', 'midsole', 'cushioning'): 4,
#          ('every', 'step', 'soft'): 4,
#          ('lightweight', 'flexible', 'responsive'): 4,
#          ('arch', 'textile', 'upper'): 4,
#          ('removable', 'sockliner', 'sockliner'): 4,
#          ('sockliner', 'sockliner', 'removed'): 4,
#          ('sockliner', 'removed', 'accommodate'): 4,
#          ('removed', 'accommodate', 'medical'): 4,
#          ('accommodate', 'medical', 'orthotic'): 4,
#          ('lightweight', 'responsive', 'ultra'): 4,
#          ('responsive', 'ultra', 'go'): 4,
#          ('cushioning', 'skechers', 'air'): 4,
#          ('lowtop', 'arch', 'free'): 4,
#          ('approximately', 'inches', 'inches'): 4,
#          ('rubber', 'sole', 'memory'): 4,
#          ('ortholite', 'molded', 'footbed'): 4,
#          ('breathable', 'knit', 'upper'): 4,
#          ('height', 'inches', 'clarks'): 4,
#          ('durable', 'rubber', 'outsole'): 4,
#          ('stepin', 'comfort', 'superior'): 4,
#          ('comfort', 'superior', 'cushioning'): 4,
#          ('heel', 'leather', 'imported'): 4,
#          ('lifestride', 'soft', 'system'): 4,
#          ('clarks', 'cushion', 'soft'): 4,
#          ('cushion', 'soft', 'comfort'): 4,
#          ('available', 'medium', 'wide'): 4,
#          ('memory', 'foam', 'footbed'): 4,
#          ('fabric', 'lining', 'leather'): 4,
#          ('features', 'sam', 'edelman'): 4,
#          ('sam', 'edelman', 'design'): 4,
#          ('edelman', 'design', 'x'): 4,
#          ('design', 'x', 'technology'): 4,
#          ('x', 'technology', 'millimeter'): 4,
#          ('technology', 'millimeter', 'cushioning'): 4,
#          ('suede', 'imported', 'synthetic'): 4,
#          ('synthetic', 'sole', 'memory'): 4,
#          ('technology', 'skechers', 'air'): 4,
#          ('lowtop', 'arch', 'platform'): 4,
#          ('soft', 'technology', 'ortholite'): 4,
#          ('technology', 'ortholite', 'footbed'): 4,
#          ('ortholite', 'footbed', 'smooth'): 4,
#          ('premium', 'leather', 'uppers'): 4,
#          ('imported', 'na', 'rubber'): 3,
#          ('na', 'rubber', 'sole'): 3,
#          ('hexagonal', 'flex', 'grooves'): 3,
#          ('practice', 'performance', 'textile'): 3,
#          ('performance', 'textile', 'imported'): 3,
#          ('lowtop', 'arch', 'neutral'): 3,
#          ('arch', 'neutral', 'runners'): 3,
#          ('runners', 'need', 'flexibility'): 3,
#          ('need', 'flexibility', 'cushioning'): 3,
#          ('flexibility', 'cushioning', 'versatility'): 3,
#          ('bounce', 'cushioning', 'provides'): 3,
#          ('cushioning', 'provides', 'enhanced'): 3,
#          ('provides', 'enhanced', 'comfort'): 3,
#          ('enhanced', 'comfort', 'flexibility'): 3,
#          ('usa', 'imported', 'rubber'): 3,
#          ('upper', 'textile', 'imported'): 3,
#          ('memory', 'foam', 'flexible'): 3,
#          ('foam', 'flexible', 'sole'): 3,
#          ('heat', 'textile', 'imported'): 3,
#          ('maximum', 'comfort', 'hillo'): 3,
#          ('comfort', 'hillo', 'heel'): 3,
#          ('sole', 'round', 'toe'): 3,
#          ('dance', 'shoes', 'suitable'): 3,
#          ('lowtop', 'arch', 'heel'): 3,
#          ('memory', 'foam', 'cushioned'): 3,
#          ('arch', 'slipon', 'providing'): 3,
#          ('providing', 'easy', 'wear'): 3,
#          ('easy', 'wear', 'ability'): 3,
#          ('approximately', 'midtop', 'arch'): 3,
#          ('arch', 'type', 'normal'): 3,
#          ('mesh', 'fabric', 'upper'): 3,
#          ('memory', 'form', 'fit'): 3,
#          ('mesh', 'fabric', 'imported'): 3,
#          ('rubber', 'sole', 'radically'): 3,
#          ('midsole', 'cushioning', 'new'): 3,
#          ('cushioning', 'new', 'goga'): 3,
#          ('new', 'goga', 'max'): 3,
#          ('high', 'rebound', 'footbed'): 3,
#          ('rebound', 'footbed', 'energizes'): 3,
#          ('footbed', 'energizes', 'every'): 3,
#          ('step', 'soft', 'mesh'): 3,
#          ('soft', 'mesh', 'upper'): 3,
#          ('mesh', 'upper', 'virtually'): 3,
#          ('upper', 'virtually', 'seamless'): 3,
#          ('virtually', 'seamless', 'construction'): 3,
#          ('seamless', 'construction', 'comfortable'): 3,
#          ('construction', 'comfortable', 'fit'): 3,
#          ('comfortable', 'fit', 'bamboo'): 3,
#          ('fit', 'bamboo', 'lined'): 3,
#          ('bamboo', 'lined', 'foot'): 3,
#          ('lined', 'foot', 'bed'): 3,
#          ('foot', 'bed', 'antibacterial'): 3,
#          ('bed', 'antibacterial', 'odor'): 3,
#          ('antibacterial', 'odor', 'control'): 3,
#          ('mesh', 'upper', 'provides'): 3,
#          ('flexible', 'responsive', 'cushioning'): 3,
#          ('notapplicable', 'arch', 'flexible'): 3,
#          ('arch', 'flexible', 'sole'): 3,
#          ('radically', 'lightweight', 'innovative'): 3,
#          ('lightweight', 'innovative', 'highly'): 3,
#          ('manmade', 'imported', 'heel'): 3,
#          ('wedge', 'synthetic', 'imported'): 3,
#          ('rearfoot', 'gel', 'cushioning'): 3,
#          ('gel', 'cushioning', 'system'): 3,
#          ('transition', 'midstance', 'removable'): 3,
#          ('midstance', 'removable', 'sockliner'): 3,
#          ('designed', 'allday', 'comfort'): 3,
#          ('sole', 'fashion', 'sneaker'): 3,
#          ('comfortable', 'textile', 'lining'): 3,
#          ('nb', 'memory', 'sole'): 3,
#          ('memory', 'sole', 'comfort'): 3,
#          ('sole', 'comfort', 'insert'): 3,
#          ('flywire', 'cables', 'integrate'): 3,
#          ('cables', 'integrate', 'laces'): 3,
#          ('foot', 'move', 'naturally'): 3,
#          ('heel', 'memory', 'foam'): 3,
#          ('memory', 'foam', 'midsole'): 3,
#          ('durable', 'tpr', 'outsole'): 3,
#          ('flexible', 'sole', 'breathable'): 3,
#          ('leather', 'textile', 'imported'): 3,
#          ('lowtop', 'arch', 'eva'): 3,
#          ('outsole', 'premium', 'leather'): 3,
#          ('approximately', 'arch', 'heel'): 3,
#          ('another', 'order', 'synthetic'): 3,
#          ('order', 'synthetic', 'imported'): 3,
#          ('foam', 'ball', 'foot'): 3,
#          ('ball', 'foot', 'dense'): 3,
#          ('foot', 'dense', 'foam'): 3,
#          ('adiwear', 'outsole', 'offers'): 3,
#          ('outsole', 'offers', 'ultimate'): 3,
#          ('offers', 'ultimate', 'highwear'): 3,
#          ('ultimate', 'highwear', 'durability'): 3,
#          ('system', 'flexible', 'sole'): 3,
#          ('mat', 'insole', 'maximum'): 3,
#          ('highrebound', 'ultra', 'pillars'): 3,
#          ('ultra', 'pillars', 'energize'): 3,
#          ('pillars', 'energize', 'every'): 3,
#          ('energize', 'every', 'step'): 3,
#          ('imported', 'fabric', 'sole'): 3,
#          ('soft', 'technology', 'ultralightweight'): 3,
#          ('medium', 'wide', 'widths'): 3,
#          ('lowtop', 'arch', 'light'): 3,
#          ('arch', 'light', 'weight'): 3,
#          ('light', 'weight', 'flexible'): 3,
#          ('weight', 'flexible', 'sole'): 3,
#          ('soft', 'technology', 'flexible'): 3,
#          ('technology', 'flexible', 'rubber'): 3,
#          ('flexible', 'rubber', 'outsole'): 3,
#          ('rubber', 'outsole', 'leather'): 3,
#          ('heel', 'height', 'clarks'): 3,
#          ('height', 'clarks', 'cushion'): 3,
#          ('soft', 'comfort', 'ortholite'): 3,
#          ('comfort', 'ortholite', 'footbed'): 3,
#          ('molds', 'foot', 'superior'): 3,
#          ('foot', 'superior', 'stepin'): 3,
#          ('superior', 'stepin', 'comfort'): 3,
#          ('sole', 'heel', 'height'): 3,
#          ('lining', 'leather', 'imported'): 3,
#          ('size', 'small', 'us'): 3,
#          ('small', 'us', 'medium'): 3,
#          ('us', 'medium', 'us'): 3,
#          ('medium', 'us', 'large'): 3,
#          ('us', 'large', 'us'): 3,
#          ('large', 'us', 'extra'): 3,
#          ('us', 'extra', 'large'): 3,
#          ('slipper', 'narrow', 'width'): 3,
#          ('narrow', 'width', 'wide'): 3,
#          ('width', 'wide', 'feet'): 3,
#          ('wide', 'feet', 'recommend'): 3,
#          ('feet', 'recommend', 'buying'): 3,
#          ('recommend', 'buying', 'size'): 3,
#          ('memory', 'foam', 'cushion'): 3,
#          ('anti', 'slip', 'sole'): 3,
#          ('slip', 'sole', 'textured'): 3,
#          ('sole', 'textured', 'bottom'): 3,
#          ('care', 'hand', 'wash'): 3,
#          ('hand', 'wash', 'cold'): 3,
#          ('wash', 'cold', 'water'): 3,
#          ('air', 'dry', 'dry'): 3,
#          ('dry', 'dry', 'flat'): 3,
#          ('rubber', 'traction', 'outsole'): 3,
#          ('cushioning', 'technology', 'skechers'): 3,
#          ('maximum', 'comfort', 'soft'): 3,
#          ('goga', 'max', 'highrebound'): 3,
#          ('max', 'highrebound', 'insole'): 3,
#          ('highrebound', 'insole', 'maximum'): 3,
#          ('arch', 'runtrain', 'performance'): 3,
#          ('mat', 'insole', 'soft'): 3,
#          ('insole', 'soft', 'fabric'): 3,
#          ('notapplicable', 'arch', 'ortholite'): 3,
#          ('arch', 'ortholite', 'molded'): 3,
#          ('notapplicable', 'arch', 'cushion'): 3,
#          ('arch', 'cushion', 'soft'): 3,
#          ('lining', 'durable', 'composition'): 3,
#          ('durable', 'composition', 'rubber'): 3,
#          ('composition', 'rubber', 'outsole'): 3,
#          ('provides', 'excellent', 'grip'): 3,
#          ('clarks', 'cloudsteppers', 'removable'): 3,
#          ('cloudsteppers', 'removable', 'ortholite'): 3,
#          ('removable', 'ortholite', 'footbed'): 3,
#          ('fit', 'memory', 'foam'): 3,
#          ('cloud', 'foam', 'insole'): 2,
#          ('foam', 'insole', 'provides'): 2,
#          ('insole', 'provides', 'ultralight'): 2,
#          ('provides', 'ultralight', 'cushioning'): 2,
#          ('rubber', 'sole', 'platform'): 2,
#          ('measures', 'approximately', 'laceup'): 2,
#          ('ortholite', 'footbed', 'satin'): 2,
#          ('footbed', 'satin', 'upper'): 2,
#          ('cushioning', 'versatility', 'engineered'): 2,
#          ('versatility', 'engineered', 'mesh'): 2,
#          ('mesh', 'upper', 'extremely'): 2,
#          ('upper', 'extremely', 'lightweight'): 2,
#          ('extremely', 'lightweight', 'breathable'): 2,
#          ('lightweight', 'breathable', 'strategic'): 2,
#          ('breathable', 'strategic', 'support'): 2,
#          ('strategic', 'support', 'need'): 2,
#          ('support', 'need', 'lightweight'): 2,
#          ('need', 'lightweight', 'external'): 2,
#          ('lightweight', 'external', 'heel'): 2,
#          ('external', 'heel', 'counter'): 2,
#          ('heel', 'counter', 'additional'): 2,
#          ('counter', 'additional', 'support'): 2,
#          ('additional', 'support', 'keeps'): 2,
#          ('support', 'keeps', 'back'): 2,
#          ('keeps', 'back', 'foot'): 2,
#          ('back', 'foot', 'locked'): 2,
#          ('foot', 'locked', 'place'): 2,
#          ('locked', 'place', 'charged'): 2,
#          ('place', 'charged', 'cushioning'): 2,
#          ('charged', 'cushioning', 'midsole'): 2,
#          ('cushioning', 'midsole', 'uses'): 2,
#          ('midsole', 'uses', 'compression'): 2,
#          ('uses', 'compression', 'molded'): 2,
#          ('compression', 'molded', 'foam'): 2,
#          ('molded', 'foam', 'even'): 2,
#          ('foam', 'even', 'greater'): 2,
#          ('even', 'greater', 'responsiveness'): 2,
#          ('greater', 'responsiveness', 'durability'): 2,
#          ('responsiveness', 'durability', 'providing'): 2,
#          ('durability', 'providing', 'optimal'): 2,
#          ('providing', 'optimal', 'cushioning'): 2,
#          ('optimal', 'cushioning', 'energy'): 2,
#          ('cushioning', 'energy', 'return'): 2,
#          ('energy', 'return', 'removable'): 2,
#          ('return', 'removable', 'comfort'): 2,
#          ('removable', 'comfort', 'sockliner'): 2,
#          ('comfort', 'sockliner', 'provides'): 2,
#          ('sockliner', 'provides', 'textile'): 2,
#          ('nb', 'response', 'performance'): 2,
#          ('response', 'performance', 'insert'): 2,
#          ('sole', 'lightweight', 'running'): 2,
#          ('lightweight', 'running', 'shoes'): 2,
#          ('allday', 'comfort', 'womensspecific'): 2,
#          ('comfort', 'womensspecific', 'fit'): 2,
#          ('mesh', 'upper', 'breathability'): 2,
#          ('provides', 'excellent', 'traction'): 2,
#          ('sole', 'charitable', 'imported'): 2,
#          ('charitable', 'imported', 'leather'): 2,
#          ('radically', 'lightweight', 'flexible'): 2,
#          ('imported', 'shaft', 'measures'): 2,
#          ('detail', 'side', 'lace'): 2,
#          ('lowtop', 'arch', 'regular'): 2,
#          ('arch', 'regular', 'fit'): 2,
#          ('lace', 'closure', 'suede'): 2,
#          ('closure', 'suede', 'upper'): 2,
#          ('suede', 'upper', 'textile'): 2,
#          ('upper', 'textile', 'lining'): 2,
#          ('textile', 'lining', 'reinforced'): 2,
#          ('lining', 'reinforced', 'toe'): 2,
#          ('reinforced', 'toe', 'gum'): 2,
#          ('toe', 'gum', 'rubber'): 2,
#          ('gum', 'rubber', 'cupsole'): 2,
#          ('rubber', 'cupsole', 'vulcanized'): 2,
#          ('cupsole', 'vulcanized', 'look'): 2,
#          ('vulcanized', 'look', 'enjoy'): 2,
#          ('look', 'enjoy', 'comfort'): 2,
#          ('performance', 'ortholite', 'float'): 2,
#          ('ortholite', 'float', 'sockliner'): 2,
#          ('water', 'resistant', 'textile'): 2,
#          ('resistant', 'textile', 'imported'): 2,
#          ('durable', 'sole', 'round'): 2,
#          ('pu', 'leather', 'feet'): 2,
#          ('leather', 'feet', 'wide'): 2,
#          ('bigger', 'size', 'suede'): 2,
#          ('size', 'suede', 'heel'): 2,
#          ('suede', 'heel', 'height'): 2,
#          ('height', 'approximately', 'inches'): 2,
#          ('approximately', 'inches', 'nonslip'): 2,
#          ('inches', 'nonslip', 'suede'): 2,
#          ('resistance', 'balance', 'extremely'): 2,
#          ('balance', 'extremely', 'flexible'): 2,
#          ('comfortable', 'situable', 'amateur'): 2,
#          ('situable', 'amateur', 'professionals'): 2,
#          ('amateur', 'professionals', 'latin'): 2,
#          ('professionals', 'latin', 'dance'): 2,
#          ('practicing', 'performance', 'quality'): 2,
#          ('performance', 'quality', 'guaranteed'): 2,
#          ('quality', 'guaranteed', 'great'): 2,
#          ('guaranteed', 'great', 'service'): 2,
#          ('great', 'service', 'questions'): 2,
#          ('service', 'questions', 'please'): 2,
#          ('questions', 'please', 'hesitate'): 2,
#          ('please', 'hesitate', 'contact'): 2,
#          ('hesitate', 'contact', 'us'): 2,
#          ('contact', 'us', 'time'): 2,
#          ('practice', 'performance', 'synthetic'): 2,
#          ('synthetic', 'fabric', 'imported'): 2,
#          ('sole', 'lightweight', 'resalyte'): 2,
#          ('lightweight', 'resalyte', 'cushioning'): 2,
#          ('resalyte', 'cushioning', 'w'): 2,
#          ('cushioning', 'w', 'stands'): 2,
#          ('w', 'stands', 'women'): 2,
#          ('manmade', 'imported', 'rubber'): 2,
#          ('fit', 'textile', 'imported'): 2,
#          ('soft', 'fabric', 'shoe'): 2,
#          ('foam', 'cushioned', 'comfort'): 2,
#          ('cushioned', 'comfort', 'insole'): 2,
#          ('wear', 'ability', 'available'): 2,
#          ('ability', 'available', 'multiple'): 2,
#          ('available', 'multiple', 'colorways'): 2,
#          ('multiple', 'colorways', 'materials'): 2,
#          ('notapplicable', 'arch', 'style'): 2,
#          ('arch', 'style', 'design'): 2,
#          ('comfort', 'quality', 'comfort'): 2,
#          ('quality', 'comfort', 'foam'): 2,
#          ('comfort', 'foam', 'footbed'): 2,
#          ('foam', 'footbed', 'sumptuous'): 2,
#          ('footbed', 'sumptuous', 'padded'): 2,
#          ('sumptuous', 'padded', 'insole'): 2,
#          ('padded', 'insole', 'soothe'): 2,
#          ('insole', 'soothe', 'pamper'): 2,
#          ('soothe', 'pamper', 'feet'): 2,
#          ('pamper', 'feet', 'built'): 2,
#          ('feet', 'built', 'leather'): 2,
#          ('built', 'leather', 'synthetic'): 2,
#          ('leather', 'synthetic', 'material'): 2,
#          ('synthetic', 'material', 'provide'): 2,
#          ('material', 'provide', 'exceptional'): 2,
#          ('provide', 'exceptional', 'comfort'): 2,
#          ('exceptional', 'comfort', 'detail'): 2,
#          ('comfort', 'detail', 'strong'): 2,
#          ('detail', 'strong', 'durable'): 2,
#          ('strong', 'durable', 'manufactured'): 2,
#          ('durable', 'manufactured', 'high'): 2,
#          ('manufactured', 'high', 'quality'): 2,
#          ('high', 'quality', 'materials'): 2,
#          ('quality', 'materials', 'stitched'): 2,
#          ('materials', 'stitched', 'precision'): 2,
#          ('stitched', 'precision', 'allowing'): 2,
#          ('precision', 'allowing', 'strong'): 2,
#          ('allowing', 'strong', 'robust'): 2,
#          ('strong', 'robust', 'inseams'): 2,
#          ('robust', 'inseams', 'sturdy'): 2,
#          ('inseams', 'sturdy', 'resilient'): 2,
#          ('sturdy', 'resilient', 'soles'): 2,
#          ('resilient', 'soles', 'advanced'): 2,
#          ('soles', 'advanced', 'technology'): 2,
#          ('advanced', 'technology', 'heel'): 2,
#          ('technology', 'heel', 'rest'): 2,
#          ('heel', 'rest', 'design'): 2,
#          ('rest', 'design', 'patent'): 2,
#          ('design', 'patent', 'pending'): 2,
#          ('patent', 'pending', 'technology'): 2,
#          ('pending', 'technology', 'found'): 2,
#          ('technology', 'found', 'aerosoles'): 2,
#          ('found', 'aerosoles', 'custom'): 2,
#          ('aerosoles', 'custom', 'design'): 2,
#          ('custom', 'design', 'distributes'): 2,
#          ('design', 'distributes', 'body'): 2,
#          ('distributes', 'body', 'weight'): 2,
#          ('body', 'weight', 'toward'): 2,
#          ('weight', 'toward', 'heel'): 2,
#          ('toward', 'heel', 'away'): 2,
#          ('heel', 'away', 'ball'): 2,
#          ('away', 'ball', 'foot'): 2,
#          ('ball', 'foot', 'result'): 2,
#          ('foot', 'result', 'superior'): 2,
#          ('result', 'superior', 'comfort'): 2,
#          ('superior', 'comfort', 'high'): 2,
#          ('comfort', 'high', 'heels'): 2,
#          ('high', 'heels', 'wedges'): 2,
#          ('heels', 'wedges', 'look'): 2,
#          ('wedges', 'look', 'feel'): 2,
#          ('look', 'feel', 'great'): 2,
#          ('feel', 'great', 'satisfaction'): 2,
#          ('great', 'satisfaction', 'guarantee'): 2,
#          ('satisfaction', 'guarantee', 'return'): 2,
#          ('guarantee', 'return', 'item'): 2,
#          ('return', 'item', 'reason'): 2,
#          ('item', 'reason', 'get'): 2,
#          ('reason', 'get', 'full'): 2,
#          ('get', 'full', 'refund'): 2,
#          ('full', 'refund', 'shipping'): 2,
#          ('refund', 'shipping', 'charges'): 2,
#          ('shipping', 'charges', 'item'): 2,
#          ('charges', 'item', 'must'): 2,
#          ('item', 'must', 'returned'): 2,
#          ('must', 'returned', 'new'): 2,
#          ('returned', 'new', 'unused'): 2,
#          ('new', 'unused', 'condition'): 2,
#          ('forefoot', 'mm', 'recommended'): 2,
#          ('notapplicable', 'arch', 'casual'): 2,
#          ('arch', 'casual', 'slipon'): 2,
#          ('upper', 'antimicrobial', 'cushioned'): 2,
#          ('antimicrobial', 'cushioned', 'insole'): 2,
#          ('cushioned', 'insole', 'custom'): 2,
#          ('insole', 'custom', 'toms'): 2,
#          ('custom', 'toms', 'molded'): 2,
#          ('toms', 'molded', 'rubber'): 2,
#          ('molded', 'rubber', 'outsole'): 2,
#          ('textile', 'imported', 'leather'): 2,
#          ('leather', 'sole', 'shaft'): 2,
#          ('mess', 'fabricsynthetic', 'imported'): 2,
#          ('fabricsynthetic', 'imported', 'rubber'): 2,
#          ('rubber', 'sole', 'skechers'): 2,
#          ('sole', 'skechers', 'performance'): 2,
#          ('performance', 'fitknit', 'structured'): 2,
#          ('fitknit', 'structured', 'breathable'): 2,
#          ('structured', 'breathable', 'mesh'): 2,
#          ('breathable', 'mesh', 'cooling'): 2,
#          ('mesh', 'cooling', 'comfort'): 2,
#          ('cooling', 'comfort', 'lightweight'): 2,
#          ('comfort', 'lightweight', 'skechers'): 2,
#          ('lightweight', 'skechers', 'performance'): 2,
#          ('performance', 'fitknit', 'mesh'): 2,
#          ('fitknit', 'mesh', 'fabric'): 2,
#          ('fabric', 'upper', 'memory'): 2,
#          ('upper', 'memory', 'form'): 2,
#          ('form', 'fit', 'design'): 2,
#          ('fit', 'design', 'memory'): 2,
#          ('design', 'memory', 'foam'): 2,
#          ('memory', 'foam', 'padding'): 2,
#          ('foam', 'padding', 'around'): 2,
#          ('padding', 'around', 'heel'): 2,
#          ('around', 'heel', 'customfeel'): 2,
#          ('heel', 'customfeel', 'fit'): 2,
#          ('customfeel', 'fit', 'fabric'): 2,
#          ('fit', 'fabric', 'edging'): 2,
#          ('fabric', 'edging', 'trim'): 2,
#          ('edging', 'trim', 'synthetic'): 2,
#          ('trim', 'synthetic', 'stabilizing'): 2,
#          ('synthetic', 'stabilizing', 'heel'): 2,
#          ('stabilizing', 'heel', 'panel'): 2,
#          ('heel', 'panel', 'side'): 2,
#          ('panel', 'side', 'logo'): 2,
#          ('side', 'logo', 'independent'): 2,
#          ('logo', 'independent', 'goimpulse'): 2,
#          ('independent', 'goimpulse', 'integrated'): 2,
#          ('goimpulse', 'integrated', 'goga'): 2,
#          ('integrated', 'goga', 'pillars'): 2,
#          ('goga', 'pillars', 'sensors'): 2,
#          ('pillars', 'sensors', 'offer'): 2,
#          ('sensors', 'offer', 'flexibility'): 2,
#          ('offer', 'flexibility', 'feedback'): 2,
#          ('flexibility', 'feedback', 'responsive'): 2,
#          ('feedback', 'responsive', 'walking'): 2,
#          ('responsive', 'walking', 'experience'): 2,
#          ('walking', 'experience', 'ever'): 2,
#          ('experience', 'ever', 'memory'): 2,
#          ('ever', 'memory', 'foam'): 2,
#          ('foam', 'padded', 'heel'): 2,
#          ('padded', 'heel', 'cup'): 2,
#          ('heel', 'cup', 'stayput'): 2,
#          ('cup', 'stayput', 'fit'): 2,
#          ('stayput', 'fit', 'walking'): 2,
#          ('fit', 'walking', 'comfort'): 2,
#          ('walking', 'comfort', 'goga'): 2,
#          ('comfort', 'goga', 'pillars'): 2,
#          ('goga', 'pillars', 'technology'): 2,
#          ('pillars', 'technology', 'midsole'): 2,
#          ('technology', 'midsole', 'outsole'): 2,
#          ('midsole', 'outsole', 'goga'): 2,
#          ('outsole', 'goga', 'mat'): 2,
#          ('goga', 'mat', 'technology'): 2,
#          ('mat', 'technology', 'weight'): 2,
#          ('technology', 'weight', 'radically'): 2,
#          ('weight', 'radically', 'lightweight'): 2,
#          ('radically', 'lightweight', 'oz'): 2,
#          ('lightweight', 'oz', 'women'): 2,
#          ('oz', 'women', 'size'): 2,
#          ('comfort', 'textile', 'imported'): 2,
#          ('lowtop', 'arch', 'textile'): 2,
#          ('textile', 'lining', 'comfort'): 2,
#          ('lowtop', 'arch', 'fashion'): 2,
#          ('arch', 'fashion', 'lifestyle'): 2,
#          ('fashion', 'lifestyle', 'sneaker'): 2,
#          ('ahar', 'outsole', 'acronym'): 2,
#          ('outsole', 'acronym', 'asics'): 2,
#          ('acronym', 'asics', 'high'): 2,
#          ('asics', 'high', 'abrasion'): 2,
#          ('high', 'abrasion', 'rubber'): 2,
#          ('abrasion', 'rubber', 'placed'): 2,
#          ('rubber', 'placed', 'critical'): 2,
#          ('placed', 'critical', 'areas'): 2,
#          ('critical', 'areas', 'outsole'): 2,
#          ('areas', 'outsole', 'exceptional'): 2,
#          ('outsole', 'exceptional', 'durability'): 2,
#          ('durability', 'leather', 'imported'): 2,
#          ('comfort', 'rubber', 'traction'): 2,
#          ('faux', 'leather', 'mesh'): 2,
#          ('notapplicable', 'arch', 'energized'): 2,
#          ('arch', 'energized', 'insole'): 2,
#          ('energized', 'insole', 'allday'): 2,
#          ('insole', 'allday', 'comfort'): 2,
#          ('allday', 'comfort', 'cushioning'): 2,
#          ('comfort', 'cushioning', 'shock'): 2,
#          ('cushioning', 'shock', 'absorption'): 2,
#          ('shock', 'absorption', 'reduces'): 2,
#          ('absorption', 'reduces', 'foot'): 2,
#          ('reduces', 'foot', 'pressure'): 2,
#          ('foot', 'pressure', 'fatigue'): 2,
#          ('durable', 'sole', 'textile'): 2,
# ...
#          ('complete', 'sizes', 'reference'): 1,
#          ('sizes', 'reference', 'textile'): 1,
#          ('reference', 'textile', 'imported'): 1,
#          ('textile', 'imported', 'man'): 1,
#          ('imported', 'man', 'made'): 1,
#          ('man', 'made', 'textile'): 1,
#          ('made', 'textile', 'sole'): 1,
#          ('textile', 'sole', 'shaft'): 1,
#          ('inches', 'inches', 'heel'): 1,
#          ('height', 'inches', 'cushion'): 1,
#          ('soft', 'technology', 'eva'): 1,
#          ('technology', 'eva', 'sole'): 1,
#          ('eva', 'sole', 'leather'): 1,
#          ('sole', 'leather', 'synthetic'): 1,
#          ('leather', 'synthetic', 'sole'): 1,
#          ('sole', 'leather', 'uppers'): 1,
#          ('leather', 'uppers', 'contrast'): 1,
#          ('uppers', 'contrast', 'stitiching'): 1,
#          ('contrast', 'stitiching', 'lace'): 1,
#          ('stitiching', 'lace', 'accents'): 1,
#          ('lace', 'accents', 'smooth'): 1,
#          ('accents', 'smooth', 'leather'): 1,
#          ('smooth', 'leather', 'lining'): 1,
#          ('leather', 'lining', 'abrasion'): 1,
#          ('lining', 'abrasion', 'free'): 1,
#          ('abrasion', 'free', 'foot'): 1,
#          ('free', 'foot', 'environment'): 1,
#          ('foot', 'environment', 'gel'): 1,
#          ('environment', 'gel', 'foam'): 1,
#          ('gel', 'foam', 'cushioned'): 1,
#          ('foam', 'cushioned', 'footbed'): 1,
#          ('cushioned', 'footbed', 'added'): 1,
#          ('added', 'comfort', 'rubber'): 1,
#          ('traction', 'outsole', 'added'): 1,
#          ('outsole', 'added', 'durability'): 1,
#          ('added', 'durability', 'leather'): 1,
#          ('soft', 'technology', 'mesh'): 1,
#          ('technology', 'mesh', 'shaft'): 1,
#          ('mesh', 'shaft', 'measures'): 1,
#          ('approximately', 'lowtop', 'upper'): 1,
#          ('lowtop', 'upper', 'delivers'): 1,
#          ('flexible', 'forefoot', 'firm'): 1,
#          ('forefoot', 'firm', 'rubber'): 1,
#          ('firm', 'rubber', 'heel'): 1,
#          ('rubber', 'heel', 'provides'): 1,
#          ('heel', 'provides', 'durable'): 1,
#          ('provides', 'durable', 'stability'): 1,
#          ('durable', 'stability', 'highintensity'): 1,
#          ('stability', 'highintensity', 'intervals'): 1,
#          ('highintensity', 'intervals', 'thin'): 1,
#          ('intervals', 'thin', 'web'): 1,
#          ('optimal', 'durability', 'man'): 1,
#          ('stack', 'heel', 'textile'): 1,
#          ('heel', 'textile', 'imported'): 1,
#          ('maximum', 'comfort', 'ez'): 1,
#          ('comfort', 'ez', 'fit'): 1,
#          ('ez', 'fit', 'closure'): 1,
#          ('fit', 'closure', 'easy'): 1,
#          ('closure', 'easy', 'easy'): 1,
#          ('easy', 'easy', 'soft'): 1,
#          ('easy', 'soft', 'fabric'): 1,
#          ('lining', 'leather', 'synthetic'): 1,
#          ('float', 'sockliner', 'leather'): 1,
#          ('sockliner', 'leather', 'made'): 1,
#          ('leather', 'made', 'usa'): 1,
#          ('usa', 'imported', 'leather'): 1,
#          ('leather', 'sole', 'shockwave'): 1,
#          ('sole', 'shockwave', 'tap'): 1,
#          ('shockwave', 'tap', 'plates'): 1,
#          ('tap', 'plates', 'leather'): 1,
#          ('plates', 'leather', 'stacked'): 1,
#          ('leather', 'stacked', 'heel'): 1,
#          ('stacked', 'heel', 'kashmir'): 1,
#          ('heel', 'kashmir', 'lining'): 1,
#          ('kashmir', 'lining', 'comfort'): 1,
#          ('lining', 'comfort', 'reduce'): 1,
#          ('comfort', 'reduce', 'moisture'): 1,
#          ('reduce', 'moisture', 'heel'): 1,
#          ('moisture', 'heel', 'notch'): 1,
#          ('heel', 'notch', 'reduce'): 1,
#          ('notch', 'reduce', 'pressure'): 1,
#          ('reduce', 'pressure', 'achilles'): 1,
#          ('pressure', 'achilles', 'tendon'): 1,
#          ('achilles', 'tendon', 'leather'): 1,
#          ('tendon', 'leather', 'split'): 1,
#          ('leather', 'split', 'sole'): 1,
#          ('split', 'sole', 'allows'): 1,
#          ('sole', 'allows', 'dancer'): 1,
#          ('allows', 'dancer', 'greater'): 1,
#          ('dancer', 'greater', 'freedom'): 1,
#          ('greater', 'freedom', 'movement'): 1,
#          ('freedom', 'movement', 'whilst'): 1,
#          ('movement', 'whilst', 'maintaining'): 1,
#          ('whilst', 'maintaining', 'support'): 1,
#          ('maintaining', 'support', 'textile'): 1,
#          ('lowtop', 'arch', 'super'): 1,
#          ('arch', 'super', 'comfort'): 1,
#          ('super', 'comfort', 'padding'): 1,
#          ('comfort', 'padding', 'faux'): 1,
#          ('padding', 'faux', 'laces'): 1,
#          ('faux', 'laces', 'ealstic'): 1,
#          ('laces', 'ealstic', 'gor'): 1,
#          ('ealstic', 'gor', 'easy'): 1,
#          ('gor', 'easy', 'pull'): 1,
#          ('easy', 'pull', 'synthetic'): 1,
#          ('pull', 'synthetic', 'imported'): 1,
#          ('rubber', 'sole', 'neutral'): 1,
#          ('sole', 'neutral', 'runners'): 1,
#          ('runners', 'need', 'balance'): 1,
#          ('need', 'balance', 'flexibility'): 1,
#          ('balance', 'flexibility', 'cushioning'): 1,
#          ('flexibility', 'cushioning', 'lightweight'): 1,
#          ('cushioning', 'lightweight', 'mesh'): 1,
#          ('lightweight', 'mesh', 'upper'): 1,
#          ('upper', 'delivers', 'complete'): 1,
#          ('delivers', 'complete', 'breathability'): 1,
#          ('complete', 'breathability', 'foam'): 1,
#          ('breathability', 'foam', 'padding'): 1,
#          ('foam', 'padding', 'placed'): 1,
#          ('padding', 'placed', 'around'): 1,
#          ('placed', 'around', 'ankle'): 1,
#          ('ankle', 'collar', 'tongue'): 1,
#          ('collar', 'tongue', 'incredibly'): 1,
#          ('tongue', 'incredibly', 'comfortable'): 1,
#          ('incredibly', 'comfortable', 'fit'): 1,
#          ('comfortable', 'fit', 'feel'): 1,
#          ('fit', 'feel', 'high'): 1,
#          ('feel', 'high', 'rebound'): 1,
#          ('high', 'rebound', 'diecut'): 1,
#          ('rebound', 'diecut', 'eva'): 1,
#          ('diecut', 'eva', 'sockliner'): 1,
#          ('eva', 'sockliner', 'built'): 1,
#          ('sockliner', 'built', 'extended'): 1,
#          ('built', 'extended', 'arch'): 1,
#          ('extended', 'arch', 'support'): 1,
#          ('arch', 'support', 'onepiece'): 1,
#          ('support', 'onepiece', 'micro'): 1,
#          ('onepiece', 'micro', 'g'): 1,
#          ('micro', 'g', 'foam'): 1,
#          ('g', 'foam', 'midsole'): 1,
#          ('foam', 'midsole', 'turns'): 1,
#          ('midsole', 'turns', 'cushioned'): 1,
#          ('turns', 'cushioned', 'landings'): 1,
#          ('cushioned', 'landings', 'explosive'): 1,
#          ('landings', 'explosive', 'takeoffs'): 1,
#          ('explosive', 'takeoffs', 'leather'): 1,
#          ('takeoffs', 'leather', 'imported'): 1,
#          ('measures', 'approximately', 'oilresistant'): 1,
#          ('approximately', 'oilresistant', 'slipresistant'): 1,
#          ('oilresistant', 'slipresistant', 'lock'): 1,
#          ('slipresistant', 'lock', 'step'): 1,
#          ('lock', 'step', 'outsoletm'): 1,
#          ('step', 'outsoletm', 'meets'): 1,
#          ('outsoletm', 'meets', 'satra'): 1,
#          ('meets', 'satra', 'standards'): 1,
#          ('satra', 'standards', 'independent'): 1,
#          ('standards', 'independent', 'lab'): 1,
#          ('independent', 'lab', 'testing'): 1,
#          ('lab', 'testing', 'shoes'): 1,
#          ('testing', 'shoes', 'beat'): 1,
#          ('shoes', 'beat', 'industry'): 1,
#          ('beat', 'industry', 'average'): 1,
#          ('industry', 'average', 'comfort'): 1,
#          ('average', 'comfort', 'cushionig'): 1,
#          ('comfort', 'cushionig', 'heeluxetm'): 1,
#          ('cushionig', 'heeluxetm', 'occupational'): 1,
#          ('heeluxetm', 'occupational', 'shoe'): 1,
#          ('occupational', 'shoe', 'research'): 1,
#          ('shoe', 'research', 'april'): 1,
#          ('research', 'april', 'memory'): 1,
#          ('april', 'memory', 'foam'): 1,
#          ('cool', 'fit', 'anticompression'): 1,
#          ('fit', 'anticompression', 'insole'): 1,
#          ('anticompression', 'insole', 'nonmarking'): 1,
#          ('nonmarking', 'outsole', 'drilex'): 1,
#          ('outsole', 'drilex', 'moisturewicking'): 1,
#          ('drilex', 'moisturewicking', 'lining'): 1,
#          ('moisturewicking', 'lining', 'aegis'): 1,
#          ('lining', 'aegis', 'microbe'): 1,
#          ('aegis', 'microbe', 'shield'): 1,
#          ('microbe', 'shield', 'control'): 1,
#          ('shield', 'control', 'odor'): 1,
#          ('control', 'odor', 'suede'): 1,
#          ('odor', 'suede', 'imported'): 1,
#          ('rubber', 'sole', 'comfortincluded'): 1,
#          ('sole', 'comfortincluded', 'authentic'): 1,
#          ('comfortincluded', 'authentic', 'brand'): 1,
#          ('authentic', 'brand', 'new'): 1,
#          ('brand', 'new', 'durable'): 1,
#          ('new', 'durable', 'original'): 1,
#          ('durable', 'original', 'packaging'): 1,
#          ('original', 'packaging', 'leather'): 1,
#          ('packaging', 'leather', 'imported'): 1,
#          ('fit', 'design', 'roomy'): 1,
#          ('design', 'roomy', 'comfortable'): 1,
#          ('roomy', 'comfortable', 'fit'): 1,
#          ('comfortable', 'fit', 'manmade'): 1,
#          ('fit', 'manmade', 'imported'): 1,
#          ('synthetic', 'sole', 'walk'): 1,
#          ('sole', 'walk', 'tall'): 1,
#          ('walk', 'tall', 'showing'): 1,
#          ('tall', 'showing', 'pedicured'): 1,
#          ('showing', 'pedicured', 'toes'): 1,
#          ('pedicured', 'toes', 'wearing'): 1,
#          ('toes', 'wearing', 'circus'): 1,
#          ('wearing', 'circus', 'sam'): 1,
#          ('circus', 'sam', 'stephanie'): 1,
#          ('sam', 'stephanie', 'wedge'): 1,
#          ('stephanie', 'wedge', 'sandal'): 1,
#          ('wedge', 'sandal', 'comfortable'): 1,
#          ('sandal', 'comfortable', 'soft'): 1,
#          ('comfortable', 'soft', 'satin'): 1,
#          ('soft', 'satin', 'latin'): 1,
#          ('satin', 'latin', 'salsa'): 1,
#          ('latin', 'salsa', 'ballroom'): 1,
#          ('salsa', 'ballroom', 'dance'): 1,
#          ('ballroom', 'dance', 'shoes'): 1,
#          ('dance', 'shoes', 'women'): 1,
#          ('shoes', 'women', 'suede'): 1,
#          ('women', 'suede', 'sole'): 1,
#          ('suede', 'sole', 'materials'): 1,
#          ('sole', 'materials', 'satin'): 1,
#          ('materials', 'satin', 'mesh'): 1,
#          ('satin', 'mesh', 'upper'): 1,
#          ('mesh', 'upper', 'dance'): 1,
#          ('upper', 'dance', 'shoes'): 1,
#          ('dance', 'shoes', 'full'): 1,
#          ('shoes', 'full', 'insole'): 1,
#          ('full', 'insole', 'suede'): 1,
#          ('insole', 'suede', 'sole'): 1,
#          ('suede', 'sole', 'salsa'): 1,
#          ('sole', 'salsa', 'latin'): 1,
#          ('salsa', 'latin', 'ballroom'): 1,
#          ('latin', 'ballroom', 'heel'): 1,
#          ('ballroom', 'heel', 'height'): 1,
#          ('height', 'approximately', 'dance'): 1,
#          ('approximately', 'dance', 'shoes'): 1,
#          ('dance', 'shoes', 'feature'): 1,
#          ('shoes', 'feature', 'dance'): 1,
#          ('feature', 'dance', 'shoes'): 1,
#          ('dance', 'shoes', 'excellent'): 1,
#          ('shoes', 'excellent', 'ballroom'): 1,
#          ('excellent', 'ballroom', 'dancing'): 1,
#          ('ballroom', 'dancing', 'comfortable'): 1,
#          ('dancing', 'comfortable', 'shoe'): 1,
#          ('comfortable', 'shoe', 'adjustable'): 1,
#          ('shoe', 'adjustable', 'crisscross'): 1,
#          ('adjustable', 'crisscross', 'ankle'): 1,
#          ('crisscross', 'ankle', 'strap'): 1,
#          ('ankle', 'strap', 'salsa'): 1,
#          ('strap', 'salsa', 'shoes'): 1,
#          ('salsa', 'shoes', 'nonslip'): 1,
#          ('shoes', 'nonslip', 'latin'): 1,
#          ('nonslip', 'latin', 'dance'): 1,
#          ('dance', 'shoes', 'stable'): 1,
#          ('shoes', 'stable', 'heels'): 1,
#          ('stable', 'heels', 'salsa'): 1,
#          ('heels', 'salsa', 'dancing'): 1,
#          ('salsa', 'dancing', 'dance'): 1,
#          ('dancing', 'dance', 'shoes'): 1,
#          ('suitable', 'latin', 'ballroom'): 1,
#          ('latin', 'ballroom', 'salsa'): 1,
#          ('ballroom', 'salsa', 'tango'): 1,
#          ('chacha', 'practicing', 'swing'): 1,
#          ('practicing', 'swing', 'practiceperfomance'): 1,
#          ('swing', 'practiceperfomance', 'ture'): 1,
#          ('practiceperfomance', 'ture', 'size'): 1,
#          ('ture', 'size', 'sizing'): 1,
#          ('size', 'sizing', 'available'): 1,
#          ('dry', 'flat', 'unknown'): 1,
#          ('flat', 'unknown', 'textile'): 1,
#          ('unknown', 'textile', 'imported'): 1,
#          ('technology', 'ultralightweight', 'outsole'): 1,
#          ('ultralightweight', 'outsole', 'leather'): 1,
#          ('approximately', 'inches', 'stand'): 1,
#          ('inches', 'stand', 'office'): 1,
#          ('stand', 'office', 'pretty'): 1,
#          ('office', 'pretty', 'polished'): 1,
#          ('pretty', 'polished', 'un'): 1,
#          ('polished', 'un', 'cosmo'): 1,
#          ('un', 'cosmo', 'step'): 1,
#          ('cosmo', 'step', 'pump'): 1,
#          ('step', 'pump', 'leather'): 1,
#          ('pump', 'leather', 'imported'): 1,
#          ('lowtop', 'arch', 'full'): 1,
#          ('arch', 'full', 'anatomical'): 1,
#          ('shape', 'provides', 'supremely'): 1,
#          ('provides', 'supremely', 'comfortable'): 1,
#          ('supremely', 'comfortable', 'fit'): 1,
#          ('comfortable', 'fit', 'textile'): 1,
#          ('fit', 'textile', 'lining'): 1,
#          ('textile', 'lining', 'perfect'): 1,
#          ('lining', 'perfect', 'inner'): 1,
#          ('perfect', 'inner', 'climate'): 1,
#          ('inner', 'climate', 'directinjected'): 1,
#          ('climate', 'directinjected', 'onecomponent'): 1,
#          ('directinjected', 'onecomponent', 'pu'): 1,
#          ('onecomponent', 'pu', 'outsole'): 1,
#          ('pu', 'outsole', 'highly'): 1,
#          ('outsole', 'highly', 'comfortable'): 1,
#          ('highly', 'comfortable', 'hardwearing'): 1,
#          ('light', 'flexible', 'shoe'): 1,
#          ('flexible', 'shoe', 'removable'): 1,
#          ('shoe', 'removable', 'textile'): 1,
#          ('removable', 'textile', 'insole'): 1,
#          ('textile', 'insole', 'airport'): 1,
#          ('insole', 'airport', 'friendly'): 1,
#          ('airport', 'friendly', 'leather'): 1,
#          ('friendly', 'leather', 'imported'): 1,
#          ('leather', 'imported', 'flaunt'): 1,
#          ('imported', 'flaunt', 'comfort'): 1,
#          ('flaunt', 'comfort', 'ashland'): 1,
#          ('comfort', 'ashland', 'lily'): 1,
#          ('ashland', 'lily', 'leather'): 1,
#          ('lily', 'leather', 'imported'): 1,
#          ('cushion', 'soft', 'button'): 1,
#          ('soft', 'button', 'trims'): 1,
#          ('button', 'trims', 'minimum'): 1,
#          ('trims', 'minimum', 'compression'): 1,
#          ('minimum', 'compression', 'man'): 1,
#          ('compression', 'man', 'made'): 1,
#          ('arch', 'flexible', 'outsole'): 1,
#          ('flexible', 'outsole', 'available'): 1,
#          ('outsole', 'available', 'medium'): 1,
#          ('medium', 'wide', 'width'): 1,
#          ('wide', 'width', 'man'): 1,
#          ('width', 'man', 'made'): 1,
#          ('stack', 'heel', 'fabric'): 1,
#          ('heel', 'fabric', 'imported'): 1,
#          ('arch', 'lightweight', 'dualdensity'): 1,
#          ('lightweight', 'dualdensity', 'ultra'): 1,
#          ('dualdensity', 'ultra', 'go'): 1,
#          ('ultra', 'go', 'outsole'): 1,
#          ('go', 'outsole', 'comfort'): 1,
#          ('outsole', 'comfort', 'pillar'): 1,
#          ('comfort', 'pillar', 'technology'): 1,
#          ('pillar', 'technology', 'skechers'): 1,
#          ('mat', 'insole', 'breathable'): 1,
#          ('insole', 'breathable', 'seamless'): 1,
#          ('breathable', 'seamless', 'flat'): 1,
#          ('seamless', 'flat', 'knit'): 1,
#          ('flat', 'knit', 'upper'): 1,
#          ('knit', 'upper', 'machine'): 1,
#          ('upper', 'machine', 'washable'): 1,
#          ('machine', 'washable', 'air'): 1,
#          ('washable', 'air', 'dry'): 1,
#          ('air', 'dry', 'leather'): 1,
#          ('dry', 'leather', 'imported'): 1,
#          ('height', 'inches', 'stretch'): 1,
#          ('inches', 'stretch', 'gore'): 1,
#          ('gore', 'panels', 'ortholite'): 1,
#          ('panels', 'ortholite', 'footbed'): 1})

# %%
trigrams_df = pd.DataFrame.from_dict(trigrams, orient='index').reset_index()
trigrams_df = trigrams_df.rename(columns={'index':'trigrams', 0:'count'})
trigrams_df = trigrams_df.sort_values(by=['count'], ascending = False)
trigrams_df_top10 = trigrams_df.head(10)

# %%
trigrams_df_top10
# Out:
#                                      trigrams  count
# 21           (shaft, measures, approximately)    208
# 20                    (sole, shaft, measures)    204
# 1                    (imported, rubber, sole)    150
# 104               (imported, synthetic, sole)    125
# 365  (measures, approximately, notapplicable)    105
# 19                      (rubber, sole, shaft)    105
# 366      (approximately, notapplicable, arch)    104
# 301                  (synthetic, sole, shaft)     93
# 22          (measures, approximately, lowtop)     91
# 23              (approximately, lowtop, arch)     90

# %%
import seaborn as sns
zx = sns.barplot(bigrams_df_top10['bigram'], bigrams_df_top10['count'])
zx.set_xticklabels(zx.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
import seaborn as sns
yx = sns.barplot(trigrams_df_top10['trigrams'], trigrams_df_top10['count'])
yx.set_xticklabels(yx.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
dataset
# Out:
#     product_asin                                       product_name  \
# 0     B07D3G9ZNG                          Brooks Women's Levitate 2
# 1     B07VKQWZR4                    Nike Women's Viale Running Shoe
# 2     B07X92DWVM         adidas Originals Women's Superstar Sneaker
# 3     B077GB5R7R     ECCO Women?s, Biom Fjuel Blaze Lace up Sneaker
# 4     B01KLTBMLA           adidas Women's W Tech Response Golf Shoe
# 5     B07GSVDPST                    CLARKS Women's Leisa Sadie Clog
# 6     B072F85JCB  Nike Women's Flex Experience RN 7 Black/Black ...
# 7     B00FLO35HU              Clarks Women's Ashland Bubble Slip-On
# 8     B07SD1MSBB  SKOEX Women Rhinestone Ballroom Dance Shoes La...
# 9     B07V69KHHZ    Under Armour Women's Charged Rogue Running Shoe
# 10    B07NY3H37K  New Balance Women's Coast V4 FuelCore Running ...
# 11    B07X8RQXJZ                 Crocs Classic Tie Dye Graphic Clog
# 12    B01MZ23SY6                 CLARKS Women's Emslie Warbler Pump
# 13    B07D9DMJWJ             adidas Women's Edge Lux 3 Running Shoe
# 14    B07RR6BCJG                 Cole Haan Women's Nantucket Loafer
# 15    B00F5VE0A0          New Balance Women's WW877-SB Walking Shoe
# 16    B07L5XLGW8    Skechers Women's Beach Bingo-Woof Pack Platform
# 17    B07H8SLQX9  HROYL Women Satin Ballroom Dance Shoes Latin S...
# 18    B01HSMYV8E           Saucony Women's Cohesion 10 Running Shoe
# 19    B01IIBA0G6  Skechers Performance Women's Go Step Lite-Agil...
# 20    B07NF73DCN                    PUMA Radiate XT Women's Sneaker
# 21    B0756PHKPR              Tommy Hilfiger Women's Luster Sneaker
# 22    B07PPYH6BN  SOVIKER Women Indoor Ballerina Yoga Shoes Hous...
# 23    B079HM3CDY  Skechers Women's Rumbler Wave-Filigree-Laser-C...
# 24    B06XPFG2HK          Skechers Women's Cleo Bewitch Ballet Flat
# 25    B07X3ZKB8Q                    adidas Women's Courtset Sneaker
# 26    B07DL4NVR5         Skechers Women's Eagle Spikeless Golf Shoe
# 27    B07QNS9YL9   Dr. Scholl's Shoes Women's Friendly2 Ballet Flat
# 28    B07BLM51QN  ASICS Gel-Quantum 360 Knit 2 Women's Running Shoe
# 29    B07QF8PNWB         Skechers Women's Go Walk Joy-Loved Sneaker
# ..           ...                                                ...
# 343   B07FHBG8SM                  CLARKS Women's Linvale Edyth Pump
# 344   B07FD3SCZJ  MSMAX Womens Pointe Shoes Ballet Dance Perform...
# 345   B01FGOE8DY               Clarks Women's Arla Glison Flip Flop
# 346   B004OQ1KW8         Women's Earth Origins, Norah Slip on Shoes
# 347   B01N0T6FC2          CLARKS Women's Raisie Eletta Penny Loafer
# 348   B079C77MMK                 Nike Metcon 4 Womens Running Shoes
# 349   B07K2P56JR       Dr. Scholl's Shoes Women's Aston Ballet Flat
# 350   B078WHW9P3      Skechers Women's Go Walk Lite-15433 Boat Shoe
# 351   B07WZRR5BZ                   adidas Women's Courtset Sneakers
# 352   B0041HYZR2      Bloch Dance Women's Tap-Flex Leather Tap Shoe
# 353   B07B5RGY2N              Blowfish Malibu Women's Fruit Sneaker
# 354   B07R5D6LC3  Under Armour Women's Micro G Pursuit Running Shoe
# 355   B01LZWPSFM              Dr. Scholl's Women's Dynamo Work Shoe
# 356   B01MQKBHVJ  Skechers Sport Women's Relaxation Breathe Easy...
# 357   B07GN8WKFG                 Nike Women's Air Force 1 Jester XX
# 358   B01N6ECIJ1        CLARKS Women's Everlay Heidi Slip-On Loafer
# 359   B00VWR8SHC              Skechers for Work Women's Eldred Shoe
# 360   B07NBJSZ77            Circus by Sam Edelman Women's Stephanie
# 361   B07JW9LJGW  2018 Evkoo Dance Shoes Girls Satin Latin Ballr...
# 362   B07D2LQ2DT  Jessica Simpson Comfy Faux Fur Womens House Sl...
# 363   B07KDWMJ1S  DLisiting Latin Shoes for Women Adult Brown Sa...
# 364   B078HD3SV8                   CLARKS Women's Sillian Free Clog
# 365   B07F1CK6J7                   CLARKS Womens Un Cosmo Step Pump
# 366   B077537J1R        ECCO Women's Gillian Casual Slip on Sneaker
# 367   B07J2T1VRC              CLARKS Womens Ashland Lily Moc Loafer
# 368   B07DDK42RF                       Clarks Women's Emslie Warren
# 369   B07DD5VZWW                   LifeStride Women's Trixie Loafer
# 370   B07K2P56JR       Dr. Scholl's Shoes Women's Aston Ballet Flat
# 371   B07N165RHL          Skechers Women's Go Walk 5-Prized Sneaker
# 372   B078GW8JS4                 CLARKS Women's Hope Roxanne Loafer
#
#                                     product_sale_price  \
# 0    $99.80 - $249.95Lower price available on selec...
# 1                                     $33.39 - $133.00
# 2                                     $38.55 - $169.76
# 3    $69.68 - $159.06Lower price available on selec...
# 4    $29.99 - $140.34Lower price available on selec...
# 5    $36.14 - $109.99Lower price available on selec...
# 6                                               $59.94
# 7    $28.22 - $89.97Lower price available on select...
# 8                                      $19.99 - $39.99
# 9    $39.97 - $80.00Lower price available on select...
# 10   $20.00 - $116.62Lower price available on selec...
# 11                                     $30.23 - $84.99
# 12   $56.61 - $85.00Lower price available on select...
# 13                                    $47.27 - $131.51
# 14   $41.97 - $142.01Lower price available on selec...
# 15                                    $57.60 - $171.25
# 16                                    $25.00 - $112.62
# 17                                     $21.99 - $24.99
# 18                                     $32.96 - $90.00
# 19                                     $29.89 - $80.00
# 20                                    $32.25 - $110.48
# 21                                    $28.99 - $105.91
# 22   $7.99 - $10.99Lower price available on select ...
# 23                                     $36.78 - $91.81
# 24   $32.07 - $110.94Lower price available on selec...
# 25                                    $38.95 - $109.00
# 26   $24.02 - $162.41Lower price available on selec...
# 27   $20.76 - $100.00Lower price available on selec...
# 28   $87.95 - $273.24Lower price available on selec...
# 29                                     $33.99 - $95.62
# ..                                                 ...
# 343  $53.87 - $85.00Lower price available on select...
# 344                                    $14.99 - $21.99
# 345  $23.48 - $89.99Lower price available on select...
# 346                                    $49.95 - $49.99
# 347  $65.99 - $94.99Lower price available on select...
# 348                                   $85.00 - $408.55
# 349                                    $14.00 - $80.85
# 350  $43.49 - $131.19Lower price available on selec...
# 351                                   $39.95 - $118.29
# 352                                    $60.69 - $94.17
# 353  $22.09 - $65.00Lower price available on select...
# 354  $26.39 - $84.99Lower price available on select...
# 355                                    $30.99 - $54.95
# 356  $44.95 - $125.63Lower price available on selec...
# 357                                   $61.22 - $270.00
# 358  $27.59 - $122.33Lower price available on selec...
# 359  $49.00 - $147.71Lower price available on selec...
# 360                                    $18.99 - $53.99
# 361                                    $36.66 - $39.99
# 362                                    $18.94 - $23.88
# 363                                    $31.99 - $36.99
# 364  $37.76 - $85.00Lower price available on select...
# 365                                   $63.18 - $125.00
# 366                                   $58.25 - $125.63
# 367                                    $38.98 - $75.95
# 368  $32.35 - $89.95Lower price available on select...
# 369                                   $43.90 - $130.84
# 370                                    $14.00 - $80.85
# 371  $48.90 - $145.63Lower price available on selec...
# 372  $35.73 - $98.92Lower price available on select...
#
#                                       product_category          product_brand  \
# 0            Women,Shoes,Athletic,Running,Road Running                    NaN
# 1            Women,Shoes,Athletic,Running,Road Running                    NaN
# 2                         Women,Shoes,Fashion Sneakers                    NaN
# 3                         Women,Shoes,Athletic,Walking                    NaN
# 4                            Women,Shoes,Athletic,Golf                 adidas
# 5                            Women,Shoes,Mules & Clogs                    NaN
# 6            Women,Shoes,Athletic,Running,Road Running                    NaN
# 7                       Women,Shoes,Loafers & Slip-Ons                    NaN
# 8                  Women,Shoes,Athletic,Ballet & Dance                  SKOEX
# 9            Women,Shoes,Athletic,Running,Road Running                    NaN
# 10                                         Women,Shoes                    NaN
# 11                           Women,Shoes,Mules & Clogs                    NaN
# 12                                   Women,Shoes,Pumps                    NaN
# 13           Women,Shoes,Athletic,Running,Road Running                 adidas
# 14                      Women,Shoes,Loafers & Slip-Ons                    NaN
# 15                        Women,Shoes,Athletic,Walking                    NaN
# 16                        Women,Shoes,Fashion Sneakers                    NaN
# 17                 Women,Shoes,Athletic,Ballet & Dance                  HROYL
# 18                        Women,Shoes,Fashion Sneakers                Saucony
# 19                        Women,Shoes,Athletic,Walking                    NaN
# 20        Women,Shoes,Athletic,Tennis & Racquet Sports                    NaN
# 21                        Women,Shoes,Fashion Sneakers                    NaN
# 22                 Women,Shoes,Athletic,Ballet & Dance                SOVIKER
# 23                                   Women,Shoes,Flats                    NaN
# 24                                   Women,Shoes,Flats                    NaN
# 25                        Women,Shoes,Fashion Sneakers                 adidas
# 26                           Women,Shoes,Athletic,Golf                    NaN
# 27                                   Women,Shoes,Flats     Dr. Scholl's Shoes
# 28           Women,Shoes,Athletic,Running,Road Running                    NaN
# 29                        Women,Shoes,Athletic,Walking                    NaN
# ..                                                 ...                    ...
# 343                                  Women,Shoes,Pumps                    NaN
# 344                Women,Shoes,Athletic,Ballet & Dance                  MSMAX
# 345                                        Women,Shoes                    NaN
# 346                     Women,Shoes,Loafers & Slip-Ons          Earth Origins
# 347                     Women,Shoes,Loafers & Slip-Ons                    NaN
# 348          Women,Shoes,Athletic,Running,Road Running                    NaN
# 349                                  Women,Shoes,Flats     Dr. Scholl's Shoes
# 350                       Women,Shoes,Athletic,Walking                    NaN
# 351                       Women,Shoes,Fashion Sneakers                 adidas
# 352                Women,Shoes,Athletic,Ballet & Dance                    NaN
# 353                       Women,Shoes,Fashion Sneakers        Blowfish Malibu
# 354          Women,Shoes,Athletic,Running,Road Running                    NaN
# 355                                        Women,Shoes     Dr. Scholl's Shoes
# 356                       Women,Shoes,Athletic,Walking                    NaN
# 357                       Women,Shoes,Fashion Sneakers                    NaN
# 358                                        Women,Shoes                    NaN
# 359  Women,Uniforms, Work & Safety,Shoes,Health Car...                    NaN
# 360                 Women,Shoes,Sandals,Heeled Sandals  Circus by Sam Edelman
# 361                Women,Shoes,Athletic,Ballet & Dance             evkoodance
# 362                               Women,Shoes,Slippers                    NaN
# 363                Women,Shoes,Athletic,Ballet & Dance              DLisiting
# 364                          Women,Shoes,Mules & Clogs                    NaN
# 365                                  Women,Shoes,Pumps                    NaN
# 366                       Women,Shoes,Fashion Sneakers                    NaN
# 367                     Women,Shoes,Loafers & Slip-Ons                    NaN
# 368                                  Women,Shoes,Pumps                    NaN
# 369                                  Women,Shoes,Pumps             LifeStride
# 370                                  Women,Shoes,Flats     Dr. Scholl's Shoes
# 371                       Women,Shoes,Athletic,Walking                    NaN
# 372                                        Women,Shoes                    NaN
#
#      product_rating  num_ratings  \
# 0               4.4          163
# 1               4.0          109
# 2               4.5          392
# 3               4.1           26
# 4               4.4          222
# 5               4.4          481
# 6               4.0            1
# 7               4.5         1309
# 8               4.4           14
# 9               4.6           40
# 10              4.1          471
# 11              4.5          332
# 12              4.2          249
# 13              3.9           41
# 14              4.5           65
# 15              4.2         1043
# 16              4.9           64
# 17              4.2            6
# 18              4.5         2108
# 19              4.4          700
# 20              4.7           24
# 21              4.3           85
# 22              5.0            5
# 23              4.1           77
# 24              4.1          430
# 25              4.5          174
# 26              4.6           65
# 27              2.6           78
# 28              4.3           29
# 29              4.7           21
# ..              ...          ...
# 343             4.3           33
# 344             3.7           28
# 345             4.7         1978
# 346             4.1          163
# 347             4.3          149
# 348             4.5          102
# 349             2.9            8
# 350             4.7          281
# 351             4.7          352
# 352             4.6          372
# 353             4.5          394
# 354             4.5           49
# 355             3.3          162
# 356             4.3         1132
# 357             4.1           12
# 358             4.3          357
# 359             4.1         1099
# 360             4.1           15
# 361             3.7            2
# 362             4.3          701
# 363             3.8           16
# 364             4.5          118
# 365             4.2           20
# 366             3.8           26
# 367             4.2           70
# 368             4.5          799
# 369             4.5           23
# 370             2.9            8
# 371             4.4           42
# 372             4.3          159
#
#                                          product_sizes  \
# 0       5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 1     5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 2    1,1.5,2,2.5,3,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10...
# 3    4-4.5,5-5.5,7-7.5,8-8.5,9-9.5,10-10.5,11-11.5,...
# 4         5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11,9.5 M US
# 5    5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 6                                                  NaN
# 7    5,5.5,6,6 Wide,6 X-Wide,6.5,6.5 Wide,6.5 X-Wid...
# 8                  5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5
# 9          5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,12
# 10   5,5 Wide,5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,...
# 11   6 Women/4 Men,7 Women/5 Men,8 Women/6 Men,9 Wo...
# 12   5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Narrow,7 Wide,...
# 13    5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 14   4,4.5,5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11...
# 15   5,5 Wide,5 X-Wide,5.5,5.5 Wide,5.5 X-Wide,6,6 ...
# 16                 5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11
# 17                         5.5,6,6.5,7,7.5,8,8.5,9,9.5
# 18   5,5.5,6,6.5,7,7 Wide,7.5,7.5 Wide,8,8.5,9,9.5,...
# 19   5,5 Wide,5.5,5.5 W US,5.5 Wide,6,6 Wide,6.5,6....
# 20              5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11
# 21              6,6.5,7,7.5,8,8.5,9,9.5,10,11,9.5 M US
# 22                                 4-5,5-6,6-7,7-8,8-9
# 23                 5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11
# 24   5,5 Wide,5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,...
# 25            5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11
# 26   5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7....
# 27   6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 Wide,8,...
# 28    5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12
# 29      5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,12,13
# ..                                                 ...
# 343  5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 344  5 M Women,6 M Women,6.5 M Women,7.5 M Women,8 ...
# 345                                 5,6,7,8,9,10,11,12
# 346  6,6 Wide,6.5,6.5 Wide,7,7.5,7.5 Wide,8,8.5,9,9...
# 347  5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 348  5,5.5,6,6.5,6.5 US,7 M US,7,7.5 M US,7.5,8,8.5...
# 349  5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 350             5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11,12
# 351                5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11
# 352  4,4 Narrow,4.5,4.5 Narrow,5,5 Narrow,5.5,5.5 N...
# 353                          6,6.5,7,7.5,8,8.5,9,10,11
# 354  5,5 Wide,5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,...
# 355  5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 356                5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11
# 357  5,6,6.5,7,7.5,8,8.5,9,9.5,10,10.5,11,11.5,12,W...
# 358  5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Narrow,7 Wide,...
# 359  5,5 X-Wide,5.5,5.5 X-Wide,6,6 X-Wide,6-1/2,6.5...
# 360                5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10,11
# 361                        5.5,6,6.5,7,7.5,8,8.5,9,9.5
# 362                         Large,Medium,Small,X-Large
# 363                   5,5.5,6,6.5,7,7.5,8,8.5,9,9.5,10
# 364  5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 365  5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 366  4-4.5,5-5.5,6-6.5,7-7.5,8-8.5,9-9.5,10-10.5,11...
# 367  5,5.5,6,6 Wide,6 X-Wide,6.5,6.5 Wide,6.5 X-Wid...
# 368  5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Narrow,7 Wide,...
# 369  5,5 Wide,5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,...
# 370  5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Wide,7.5,7.5 W...
# 371  5,5 Wide,5.5,5.5 Wide,6,6 Wide,6.5,6.5 Wide,7,...
# 372  5,5.5,6,6 Wide,6.5,6.5 Wide,7,7 Narrow,7 Wide,...
#
#                                         product_colors  \
# 0    Coral/Blue/Black,Aster/Purple/Blue,Pink/Black/...
# 1    Light Cream/Pure Platinum - White,Wolf Grey/Wh...
# 2    Scarlet/Scarlet/White,White/Ash Green/Silver M...
# 3    Black/Black,Concrete/White,Dark Shadow/Dark Sh...
# 4    Black/Silver Metallic/Grey Five,Clear/Grey,Whi...
# 5    Black Leather,Dark Tan Leather,Navy Leather,Da...
# 6                                                  NaN
# 7    Black,Brown Multi,Tan Leather,Black Interest,M...
# 8    Black-2.5inch Heel,Black-3inch Heel,Tan-3inch ...
# 9    Black (002)/White,Blue Heights (400)/Breathtak...
# 10   Black/Grey/White Peach,Mineral Sage/Ocean Air/...
# 11                                   Multi,White/Multi
# 12                            Black,Dark Brown Leather
# 13   Legend Purple/Raw Indigo/Shock Red,St Pale Nud...
# 14   Black Leather,British Tan Embossed Weave/Optic...
# 15                                              Silver
# 16                          Blue Multi,Blue/Pink,Multi
# 17   Beige-1.96inch Heels,Beige-2.75inch Heels,Blac...
# 18   Grey Blue,Grey Coral,Grey Mint,Navy Blue,Grey/...
# 19   Black Mesh,Navy/Pink Mesh,Navy/Pink,Black/Whit...
# 20   Black/White,Gray Violet-puma White,Ponderosa P...
# 21                                         Blush,White
# 22                     Light Yellow,Pink,Black,Leopard
# 23                                      Black,Burgundy
# 24                                 Black,Navy,Red,Rose
# 25   Black/White/Matte Silver,Trace Maroon/Mystery ...
# 26   Black/White,Gray/Blue Floral,White/Gray,White/...
# 27   Caravan Sands Patent,Saddle Smooth,Black Paten...
# 28   Glacier Grey/Orange Pop/Aruba,Birch/Feather Gr...
# 29                              Black/White,Navy/White
# ..                                                 ...
# 343                         Black Leather,Nude Leather
# 344                                               Pink
# 345  Aqua Solid Textile,Black Fabric,Black Printed ...
# 346                                    Bark,Black,Grey
# 347  Black Synthetic Patent,Black Leather,Black Twe...
# 348  White / Metallic Silver,White/Metallic Silver-...
# 349  Black Patent,Black Smooth,Hydrangea Crocodile ...
# 350                        Black/White,Grey,Navy,Taupe
# 351  Collegiate Navy/White/Metallic Gold,Light Onix...
# 352                                          Black,Tan
# 353  Dirty Pink Smoked Canvas,Earth Camo,Pure Navy ...
# 354  Anthracite (100)/Black,Black (001)/Anthracite,...
# 355                                              Black
# 356       Black Suede,Taupe,Navy,Black,Light Grey/Pink
# 357  Bio Beige / Pink Force-white,White/Black,Black...
# 358  Black Leather,Navy Leather,Dark Brown Leather,...
# 359                                        Black,White
# 360  Light Gold Metallic Crackle,Soft Silver Metall...
# 361                                        Black,Brown
# 362  Black,Black/Leopard,Burgundy,Grey,Ivory,Pink,P...
# 363                                                NaN
# 364  Black Synthetic Combi,Dark Brown Synthetic Com...
# 365  Dark Tan Leather,Navy Leather,Black Leather,Bl...
# 366                             Black,Powder,Warm Grey
# 367  Pewter Leather,Navy Leather,Black Leather,Dark...
# 368        Black Leather,Dark Brown,Navy Leather,Black
# 369                       Black,Dark Tan,Lux Navy,Navy
# 370  Black Patent,Black Smooth,Hydrangea Crocodile ...
# 371         Black,Navy,Black/Pink,Gray/Blue,Pink/Black
# 372  Navy Leather,Black Leather,Brown Leather,Burgu...
#
#                                       product_features  ... product_qa  \
# 0    Fabric,Imported,Rubber sole,The Brooks® Levita...  ...         22
# 1    100% Leather and Synthetic,Imported,Rubber sol...  ...         13
# 2    100% full grain leather,Imported,N/A,Rubber so...  ...         81
# 3    Synthetic,Imported,Rubber sole,The flexible Bi...  ...          5
# 4    Microfiber Leather/Climastorm,Imported,Synthet...  ...         21
# 5    100% Leather,Imported,Rubber sole,Heel measure...  ...         13
# 6    Fabric-And-Synthetic,Rubber sole,Platform meas...  ...          0
# 7    100% Leather,Imported,Synthetic sole,Heel meas...  ...         70
# 8    Satin upper,Soft suede sole,Elegant Exterior: ...  ...          0
# 9    100% Textile,Imported,Synthetic sole,Shaft mea...  ...         10
# 10   100% Textile and Synthetic,Imported,Rubber sol...  ...         44
# 11   100% Synthetic,Imported,Synthetic sole,Shaft m...  ...         13
# 12   100% leather,Imported,Rubber sole,Shaft measur...  ...         12
# 13   Textile,Imported,Synthetic sole,Lightweight ru...  ...          8
# 14   fabric,Imported,Rubber sole,Shaft measures app...  ...          9
# 15   100% Suede/mesh upper,Made in the USA and Impo...  ...        101
# 16   Textile,Imported,Synthetic sole,Shaft measures...  ...          8
# 17   Imported,Leather sole,High quality Satin,smoot...  ...          0
# 18   100% Mesh,Imported,Rubber sole,GRID, Injection...  ...        110
# 19   100% Knit Mesh/Fabric,Imported,Rubber sole,Sha...  ...         73
# 20   Textile,Imported,Shaft measures approximately ...  ...          0
# 21   100% Synthetic,Imported,Rubber sole,Shaft meas...  ...         43
# 22   Imported,1.High quality materials and fine wor...  ...          5
# 23   100% Textile,Imported,Synthetic sole,Shaft mea...  ...          3
# 24   100% Textile,Imported,Rubber sole,Air-cooled m...  ...         23
# 25   100% Leather and Synthetic,Imported,Rubber sol...  ...          7
# 26   Textile and Synthetic,Imported,Rubber sole,Sha...  ...          4
# 27   100% Textile,Imported,Synthetic sole,Shaft mea...  ...          3
# 28   NA,Imported,Shaft measures approximately Low-T...  ...          7
# 29   Fabric,Imported,Rubber sole,Shaft measures app...  ...          0
# ..                                                 ...  ...        ...
# 343  Leather,Imported,Synthetic sole,Shaft measures...  ...         10
# 344  Satin,suede sole,COMFORTABLE:Ballet Shoes is m...  ...         15
# 345  Textile,Imported,Man Made and Textile sole,Sha...  ...         71
# 346  Leather,Synthetic sole,Leather uppers with con...  ...         22
# 347  100% leather,Imported,Rubber sole,Shaft measur...  ...         11
# 348  mesh,Shaft measures approximately Low-Top" fro...  ...         23
# 349  Man Made,Imported,Synthetic sole,Shaft measure...  ...          0
# 350  100% Textile,Imported,Synthetic sole,Shaft mea...  ...         20
# 351  100% Leather and Synthetic,Imported,Rubber sol...  ...         30
# 352  100% Leather,Made in USA or Imported,Leather s...  ...         39
# 353  100% Textile,Imported,Synthetic sole,Shaft mea...  ...         12
# 354  100% Synthetic,Imported,Rubber sole,NEUTRAL: F...  ...          0
# 355  100% Leather,Imported,Rubber sole,Heel measure...  ...         11
# 356    100% Suede,Imported,Rubber sole,Comfortincluded  ...         60
# 357  Synthetic,100% Authentic,Brand New,Durable,Ori...  ...          0
# 358  100% Leather,Imported,Rubber sole,Heel height ...  ...         19
# 359  100% Leather,Imported,Synthetic sole,Memory fo...  ...         78
# 360  Manmade,Imported,Synthetic sole,Walk tall show...  ...          0
# 361  Comfortable&Soft Satin Latin Salsa Ballroom Da...  ...          0
# 362  SIZING: Available in size Small (US 6-7), Medi...  ...         34
# 363                                            unknown  ...          0
# 364  100% Textile,Imported,Rubber sole,Shaft measur...  ...         14
# 365  Leather,Imported,Rubber sole,Heel measures app...  ...          0
# 366  100% Leather,Imported,Synthetic sole,Shaft mea...  ...          7
# 367  Leather,Imported,Flaunt comfort with the Clark...  ...          7
# 368  100% Leather,Imported,Rubber sole,Heel height ...  ...         35
# 369  100% Man Made,Imported,Synthetic sole,Shaft me...  ...          3
# 370  Man Made,Imported,Synthetic sole,Shaft measure...  ...          0
# 371  Fabric,Imported,Rubber sole,Shaft measures app...  ...         16
# 372  100% Leather,Imported,Rubber sole,Shaft measur...  ...         13
#
#      shoe_gender                                shoe_category_fixed  \
# 0          Women           [Shoes, Athletic, Running, Road Running]
# 1          Women           [Shoes, Athletic, Running, Road Running]
# 2          Women                          [Shoes, Fashion Sneakers]
# 3          Women                         [Shoes, Athletic, Walking]
# 4          Women                            [Shoes, Athletic, Golf]
# 5          Women                             [Shoes, Mules & Clogs]
# 6          Women           [Shoes, Athletic, Running, Road Running]
# 7          Women                        [Shoes, Loafers & Slip-Ons]
# 8          Women                  [Shoes, Athletic, Ballet & Dance]
# 9          Women           [Shoes, Athletic, Running, Road Running]
# 10         Women                                            [Shoes]
# 11         Women                             [Shoes, Mules & Clogs]
# 12         Women                                     [Shoes, Pumps]
# 13         Women           [Shoes, Athletic, Running, Road Running]
# 14         Women                        [Shoes, Loafers & Slip-Ons]
# 15         Women                         [Shoes, Athletic, Walking]
# 16         Women                          [Shoes, Fashion Sneakers]
# 17         Women                  [Shoes, Athletic, Ballet & Dance]
# 18         Women                          [Shoes, Fashion Sneakers]
# 19         Women                         [Shoes, Athletic, Walking]
# 20         Women         [Shoes, Athletic, Tennis & Racquet Sports]
# 21         Women                          [Shoes, Fashion Sneakers]
# 22         Women                  [Shoes, Athletic, Ballet & Dance]
# 23         Women                                     [Shoes, Flats]
# 24         Women                                     [Shoes, Flats]
# 25         Women                          [Shoes, Fashion Sneakers]
# 26         Women                            [Shoes, Athletic, Golf]
# 27         Women                                     [Shoes, Flats]
# 28         Women           [Shoes, Athletic, Running, Road Running]
# 29         Women                         [Shoes, Athletic, Walking]
# ..           ...                                                ...
# 343        Women                                     [Shoes, Pumps]
# 344        Women                  [Shoes, Athletic, Ballet & Dance]
# 345        Women                                            [Shoes]
# 346        Women                        [Shoes, Loafers & Slip-Ons]
# 347        Women                        [Shoes, Loafers & Slip-Ons]
# 348        Women           [Shoes, Athletic, Running, Road Running]
# 349        Women                                     [Shoes, Flats]
# 350        Women                         [Shoes, Athletic, Walking]
# 351        Women                          [Shoes, Fashion Sneakers]
# 352        Women                  [Shoes, Athletic, Ballet & Dance]
# 353        Women                          [Shoes, Fashion Sneakers]
# 354        Women           [Shoes, Athletic, Running, Road Running]
# 355        Women                                            [Shoes]
# 356        Women                         [Shoes, Athletic, Walking]
# 357        Women                          [Shoes, Fashion Sneakers]
# 358        Women                                            [Shoes]
# 359        Women  [Uniforms,  Work & Safety, Shoes, Health Care ...
# 360        Women                   [Shoes, Sandals, Heeled Sandals]
# 361        Women                  [Shoes, Athletic, Ballet & Dance]
# 362        Women                                  [Shoes, Slippers]
# 363        Women                  [Shoes, Athletic, Ballet & Dance]
# 364        Women                             [Shoes, Mules & Clogs]
# 365        Women                                     [Shoes, Pumps]
# 366        Women                          [Shoes, Fashion Sneakers]
# 367        Women                        [Shoes, Loafers & Slip-Ons]
# 368        Women                                     [Shoes, Pumps]
# 369        Women                                     [Shoes, Pumps]
# 370        Women                                     [Shoes, Flats]
# 371        Women                         [Shoes, Athletic, Walking]
# 372        Women                                            [Shoes]
#
#             shoe_category_final num_sizes  if_wide if_narrow show_low_price  \
# 0                  Road Running      14.0    False     False          99.80
# 1                  Road Running      15.0    False     False          33.39
# 2              Fashion Sneakers      25.0    False     False          38.55
# 3                       Walking       8.0    False     False          69.68
# 4                          Golf      13.0    False     False          29.99
# 5                 Mules & Clogs      25.0     True     False          36.14
# 6                  Road Running       NaN      NaN       NaN          59.94
# 7            Loafers & Slip-Ons      43.0     True      True          28.22
# 8                Ballet & Dance      11.0    False     False          19.99
# 9                  Road Running      14.0    False     False          39.97
# 10                        Shoes      31.0     True     False          20.00
# 11                Mules & Clogs      10.0    False     False          30.23
# 12                        Pumps      32.0     True      True          56.61
# 13                 Road Running      15.0    False     False          47.27
# 14           Loafers & Slip-Ons      19.0    False     False          41.97
# 15                      Walking      54.0     True      True          57.60
# 16             Fashion Sneakers      12.0    False     False          25.00
# 17               Ballet & Dance       9.0    False     False          21.99
# 18             Fashion Sneakers      16.0     True     False          32.96
# 19                      Walking      25.0     True     False          29.89
# 20      Tennis & Racquet Sports      12.0    False     False          32.25
# 21             Fashion Sneakers      11.0    False     False          28.99
# 22               Ballet & Dance       5.0    False     False           7.99
# 23                        Flats      12.0    False     False          36.78
# 24                        Flats      24.0     True     False          32.07
# 25             Fashion Sneakers      13.0    False     False          38.95
# 26                         Golf      22.0     True     False          24.02
# 27                        Flats      20.0     True     False          20.76
# 28                 Road Running      15.0    False     False          87.95
# 29                      Walking      15.0    False     False          33.99
# ..                          ...       ...      ...       ...            ...
# 343                       Pumps      22.0     True     False          53.87
# 344              Ballet & Dance       9.0    False     False          14.99
# 345                       Shoes       8.0    False     False          23.48
# 346          Loafers & Slip-Ons      18.0     True     False          49.95
# 347          Loafers & Slip-Ons      24.0     True     False          65.99
# 348                Road Running      20.0    False     False          85.00
# 349                       Flats      22.0     True     False          14.00
# 350                     Walking      13.0    False     False          43.49
# 351            Fashion Sneakers      12.0    False     False          39.95
# 352              Ballet & Dance      34.0    False      True          60.69
# 353            Fashion Sneakers       9.0    False     False          22.09
# 354                Road Running      28.0     True     False          26.39
# 355                       Shoes      22.0     True     False          30.99
# 356                     Walking      12.0    False     False          44.95
# 357            Fashion Sneakers      15.0    False     False          61.22
# 358                       Shoes      33.0     True      True          27.59
# 359  Health Care & Food Service      25.0     True     False          49.00
# 360              Heeled Sandals      12.0    False     False          18.99
# 361              Ballet & Dance       9.0    False     False          36.66
# 362                    Slippers       4.0    False     False          18.94
# 363              Ballet & Dance      11.0    False     False          31.99
# 364               Mules & Clogs      24.0     True     False          37.76
# 365                       Pumps      25.0     True     False          63.18
# 366            Fashion Sneakers       8.0    False     False          58.25
# 367          Loafers & Slip-Ons      43.0     True      True          38.98
# 368                       Pumps      33.0     True      True          32.35
# 369                       Pumps      24.0     True     False          43.90
# 370                       Flats      22.0     True     False          14.00
# 371                     Walking      30.0     True     False          48.90
# 372                       Shoes      34.0     True      True          35.73
#
#      show_high_price  num_colors
# 0             249.95        11.0
# 1             133.00        13.0
# 2             169.76        15.0
# 3             159.06         3.0
# 4             140.34         7.0
# 5             109.99         4.0
# 6               0.00         NaN
# 7              89.97         9.0
# 8              39.99         4.0
# 9              80.00        10.0
# 10            116.62        31.0
# 11             84.99         2.0
# 12             85.00         2.0
# 13            131.51         2.0
# 14            142.01         7.0
# 15            171.25         1.0
# 16            112.62         3.0
# 17             24.99        16.0
# 18             90.00        13.0
# 19             80.00         9.0
# 20            110.48         6.0
# 21            105.91         2.0
# 22             10.99         4.0
# 23             91.81         2.0
# 24            110.94         4.0
# 25            109.00         6.0
# 26            162.41         6.0
# 27            100.00         7.0
# 28            273.24        10.0
# 29             95.62         2.0
# ..               ...         ...
# 343            85.00         2.0
# 344            21.99         1.0
# 345            89.99        22.0
# 346            49.99         3.0
# 347            94.99         5.0
# 348           408.55        27.0
# 349            80.85         7.0
# 350           131.19         4.0
# 351           118.29         2.0
# 352            94.17         2.0
# 353            65.00        26.0
# 354            84.99        18.0
# 355            54.95         1.0
# 356           125.63         5.0
# 357           270.00        10.0
# 358           122.33         5.0
# 359           147.71         2.0
# 360            53.99         3.0
# 361            39.99         2.0
# 362            23.88         8.0
# 363            36.99         NaN
# 364            85.00         6.0
# 365           125.00         5.0
# 366           125.63         3.0
# 367            75.95         4.0
# 368            89.95         4.0
# 369           130.84         4.0
# 370            80.85         7.0
# 371           145.63         5.0
# 372            98.92         6.0
#
# [373 rows x 21 columns]

# %%
dataset['shoe_category_final'].value_counts()
# Out:
# Fashion Sneakers              63
# Shoes                         57
# Ballet & Dance                43
# Road Running                  35
# Flats                         32
# Pumps                         31
# Loafers & Slip-Ons            30
# Walking                       28
# Mules & Clogs                  7
# Oxfords                        5
# Golf                           5
# Fitness & Cross-Training       5
# Health Care & Food Service     4
# Platforms & Wedges             3
# Slippers                       3
# Ankle & Bootie                 2
# Industrial & Construction      2
# Running                        2
# Heeled Sandals                 2
# Hiking Shoes                   1
# Sandals                        1
# Tennis & Racquet Sports        1
# Fire & Safety                  1
# Water Shoes                    1
# Slides                         1
# Skateboarding                  1
# Soccer                         1
# Trail Running                  1
# Flip-Flops                     1
# Boots                          1
# Volleyball                     1
# Rain Footwear                  1
# Sneakers                       1
# Name: shoe_category_final, dtype: int64
